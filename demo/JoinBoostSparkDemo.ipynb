# %% [markdown]
# # Install JoinBoost and databases package.
# To run this demo, you'll need to install the JoinBoost and databases packages. We will use Spark as the database in this demo.

# %%
# %pip install joinboost==0.0.1523
# %pip install pyspark
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: joinboost==0.0.1523 in /usr/local/lib/python3.10/dist-packages (0.0.1523)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: pyspark in /usr/local/lib/python3.10/dist-packages (3.4.0)
# Requirement already satisfied: py4j==0.10.9.7 in /usr/local/lib/python3.10/dist-packages (from pyspark) (0.10.9.7)

# %% [markdown]
# # Download and Load Data into a Database
#
# This step is only Necessary for the Demo as pre-existing databases are unavailable. In general, JoinBoost enables direct model training over databases without data downloading or loading.

# %%
import urllib.request
from pyspark.sql import SparkSession

# Download the files
urllib.request.urlretrieve("https://www.dropbox.com/s/kaovdndtevcvt83/holidays.csv?dl=1", "holidays.csv")
urllib.request.urlretrieve("https://www.dropbox.com/s/wh6amz4um7ieyqz/items.csv?dl=1", "items.csv")
urllib.request.urlretrieve("https://www.dropbox.com/s/ze6of1xqwslt8jb/oil.csv?dl=1", "oil.csv")
urllib.request.urlretrieve("https://www.dropbox.com/s/uiojfrc5c20gyrl/sales_small.csv?dl=1", "sales_small.csv")
urllib.request.urlretrieve("https://www.dropbox.com/s/cwy6z0b7rhsnrxb/stores.csv?dl=1", "stores.csv")
urllib.request.urlretrieve("https://www.dropbox.com/s/wwaoga17z70jb6l/train_small.csv?dl=1", "train_small.csv")
urllib.request.urlretrieve("https://www.dropbox.com/s/2bxto9wnetwnvqd/transactions.csv?dl=1", "transactions.csv")

# Initialize SparkSession
spark = SparkSession.builder.appName("demo").getOrCreate()

# Read CSV files into Spark DataFrames and create temporary views
spark.read.csv("holidays.csv", header=True, inferSchema=True).createOrReplaceTempView("holidays")
spark.read.csv("items.csv", header=True, inferSchema=True).createOrReplaceTempView("items")
spark.read.csv("oil.csv", header=True, inferSchema=True).createOrReplaceTempView("oil")
spark.read.csv("sales_small.csv", header=True, inferSchema=True).createOrReplaceTempView("sales")
spark.read.csv("stores.csv", header=True, inferSchema=True).createOrReplaceTempView("stores")
spark.read.csv("train_small.csv", header=True, inferSchema=True).createOrReplaceTempView("train")
spark.read.csv("transactions.csv", header=True, inferSchema=True).createOrReplaceTempView("transactions")

# %% [markdown]
# # Data exploration and Data Transformation
# You can use Spark SQL queries to show all available tables and their schema. You can perform data transformations over these tables.

# %%
# List all available tables
tables = spark.catalog.listTables()
for table in tables:
    print(table.name)

# Print the schema for each table
for table in tables:
    print(f"Schema for {table.name}:")
    spark.table(table.name).printSchema()

# Get a sample of sales
sample_sales = spark.sql("SELECT * FROM sales LIMIT 10")
sample_sales.show()
# Out:
# holidays
# items
# oil
# sales
# stores
# train
# transactions
# Schema for holidays:
# root
#  |-- date: integer (nullable = true)
#  |-- htype: integer (nullable = true)
#  |-- locale: integer (nullable = true)
#  |-- locale_name: integer (nullable = true)
#  |-- transferred: integer (nullable = true)
#  |-- f2: integer (nullable = true)
#
# Schema for items:
# root
#  |-- item_nbr: integer (nullable = true)
#  |-- family: integer (nullable = true)
#  |-- class: integer (nullable = true)
#  |-- perishable: integer (nullable = true)
#  |-- f1: integer (nullable = true)
#
# Schema for oil:
# root
#  |-- date: integer (nullable = true)
#  |-- dcoilwtico: integer (nullable = true)
#  |-- f3: integer (nullable = true)
#
# Schema for sales:
# root
#  |-- item_nbr: integer (nullable = true)
#  |-- unit_sales: double (nullable = true)
#  |-- onpromotion: integer (nullable = true)
#  |-- tid: integer (nullable = true)
#  |-- Y: double (nullable = true)
#
# Schema for stores:
# root
#  |-- store_nbr: integer (nullable = true)
#  |-- city: integer (nullable = true)
#  |-- state: integer (nullable = true)
#  |-- stype: integer (nullable = true)
#  |-- cluster: integer (nullable = true)
#  |-- f4: integer (nullable = true)
#
# Schema for train:
# root
#  |-- Y: double (nullable = true)
#  |-- onpromotion: integer (nullable = true)
#  |-- htype: integer (nullable = true)
#  |-- locale: integer (nullable = true)
#  |-- locale_name: integer (nullable = true)
#  |-- transferred: integer (nullable = true)
#  |-- f2: integer (nullable = true)
#  |-- date: integer (nullable = true)
#  |-- dcoilwtico: integer (nullable = true)
#  |-- f3: integer (nullable = true)
#  |-- tid: integer (nullable = true)
#  |-- transactions: integer (nullable = true)
#  |-- f5: integer (nullable = true)
#  |-- store_nbr: integer (nullable = true)
#  |-- city: integer (nullable = true)
#  |-- state: integer (nullable = true)
#  |-- stype: integer (nullable = true)
#  |-- cluster: integer (nullable = true)
#  |-- f4: integer (nullable = true)
#  |-- item_nbr: integer (nullable = true)
#  |-- family: integer (nullable = true)
#  |-- class: integer (nullable = true)
#  |-- perishable: integer (nullable = true)
#  |-- f1: integer (nullable = true)
#  |-- unit_sales: double (nullable = true)
#
# Schema for transactions:
# root
#  |-- date: integer (nullable = true)
#  |-- store_nbr: integer (nullable = true)
#  |-- transactions: integer (nullable = true)
#  |-- tid: integer (nullable = true)
#  |-- f5: integer (nullable = true)
#
# +--------+----------+-----------+-----+-------------------+
# |item_nbr|unit_sales|onpromotion|  tid|                  Y|
# +--------+----------+-----------+-----+-------------------+
# |     451|       4.0|          2|17298| -5739.103112581849|
# |    1476|       3.0|          0|69606|  872.3485190238571|
# |    2056|       1.0|          0|69653| -7674.674962408274|
# |       4|      14.0|          0|82839| 2542.1098731280003|
# |    1814|       3.0|          0|56901| -5824.012509244241|
# |     522|    35.788|          2| 1694|  -4057.32567323008|
# |    2241|       1.0|          0|73802| -10236.57424820753|
# |     991|       2.0|          1|78953|-3072.8988510905165|
# |    2727|       2.0|          0|33502| -6936.222332066423|
# |     802|       2.0|          0|27743|-10618.292559605285|
# +--------+----------+-----------+-----+-------------------+

# %% [markdown]
# # Building a Join Graph
#
# First, you need to specify the join graph, which includes the relations and features you want to use, as well as how these relations should be joined.
# For example,
#
#
# ```
# dataset.add_join("sales", "items", ["item_nbr"], ["item_nbr"])
# ```
#
# indicates that the join condition between the "sales" and "items" tables is based on the item_nbr attribute, where sales.item_nbr = items.item_nbr. By specifying the join conditions in this manner, you can define how the tables in your dataset are related and should be combined.

# %%
from joinboost.executor import SparkExecutor
from joinboost.joingraph import JoinGraph

# Create SparkExecutor instance 
exe = SparkExecutor(spark)

# Initialize JoinGraph with the SparkExecutor
dataset = JoinGraph(exe=exe)

# Add relations to the JoinGraph with their features
dataset.add_relation("sales", [], y='Y')
dataset.add_relation("holidays", ["htype", "locale", "locale_name", "transferred", "f2"])
dataset.add_relation("oil", ["dcoilwtico", "f3"])
dataset.add_relation("transactions", ["transactions", "f5"])
dataset.add_relation("stores", ["city", "state", "stype", "cluster", "f4"])
dataset.add_relation("items", ["family", "class", "perishable", "f1"])

# Add join conditions to the JoinGraph
# sales.item_nbr = items.item_nbr
dataset.add_join("sales", "items", ["item_nbr"], ["item_nbr"])
# sales.tid = transactions.tid
dataset.add_join("sales", "transactions", ["tid"], ["tid"])
# transactions.store_nbr = stores.store_nbr
dataset.add_join("transactions", "stores", ["store_nbr"], ["store_nbr"])
# transactions.date = holidays.date
dataset.add_join("transactions", "holidays", ["date"], ["date"])
# holidays.date = oil.date
dataset.add_join("holidays", "oil", ["date"], ["date"])

dataset
# Out:
# <!DOCTYPE html>
# <meta charset="utf-8">
# <style>
#     .flex-container {
#       display: flex;
#     }
#
#     .links line {
#         stroke: #aaa;
#         stroke-width: 2px;
#     }
#     .links line.highlight{
#         stroke: black;
#         stroke-width: 4px;
#     }
#     .links line.clickable_edge  {
#         opacity: 0;
#         stroke-width: 20px;
#     }
#     .links line.clickable_edge.highlight  {
#         opacity: 0;
#         stroke-width: 22px;
#     }
#
#     .markers polyline {
#       fill: none;
#       stroke: #aaa;
#       stroke-width: 2px;
#     }
#
#     .markers polyline.highlight {
#         fill: none;
#         stroke: black;
#         stroke-width: 4px;
#     }
#
#     .nodes circle {
#         fill: #bbb;
#     }
#
#     .nodes circle.highlight {
#         fill: black;
#     }
#
#     .relation {
#         background-color: #a7b7e3;
#         margin: 6px 6px;
#         padding: 3px 3px;
#         border-radius: 3px ;
#     }
#
#     .relation:hover {
#         background-color: #96a4c9;
#     }
#
#     .relationName {
#         display: flex;
#         margin: 5px 5px;
#         font-weight: bold;
#     }
#
#     .attribute {
#         display: flex;
#         background-color: white;
#         border-radius: 3px ;
#         margin: 6px 8px;
#         padding: 3px 10px;
#         display: none;
#     }
#
#     .attribute.expanded {
#         display: block;
#     }
#
#     .attribute:hover {
#         background-color: #dfdfdf;
#     }
#
#
#     .attribute.join_keys {
#         background-color: #d9f7da;
#     }
#
#     .attribute.join_keys:hover {
#         background-color: #b6ddb8;
#     }
#
#     .attribute.join_keys.highlight {
#         outline: 3px solid #499568;
#     }
#
#     .attribute.measurements {
#         background-color: #ffd9ea;
#     }
#     .attribute.measurements.highlight {
#         outline: 3px solid #a16e76;
#     }
#
#     .attribute.measurements:hover {
#         background-color: #cd97af;
#     }
#
#     div.scroll {
#         overflow-x: hidden;
#         overflow-y: auto;
#         text-align:justify;
#     }
#
#     /* custom scrollbar */
#     ::-webkit-scrollbar {
#       width: 15px;
#     }
#
#     ::-webkit-scrollbar-track {
#       background-color: transparent;
#     }
#
#     ::-webkit-scrollbar-thumb {
#       background-color: #d6dee1;
#       border-radius: 20px;
#       border: solid transparent;
#       background-clip: content-box;
#     }
#
#     ::-webkit-scrollbar-thumb:hover {
#       background-color: #a8bbbf;
#     }
#
# </style>
# <div class="flex-container" style="font-family:sans-serif;font-size:12px;">
#     <div id="session1683579683schema" class="scroll"  style="background-color:#38425D;width:220px;height:100vh"></div>
#     <div><svg id="session1683579683" width="600" height="600"></svg></div>
# </div>
# <script src="https://d3js.org/d3.v5.min.js"></script>
# <script>
#
#     graph = {
#         "nodes": [{'id': 'sales', 'name': 'sales', 'measurements': [], 'attributes': ['tid', 'item_nbr'], 'join_keys': ['tid', 'item_nbr']}, {'id': 'holidays', 'name': 'holidays', 'measurements': [], 'attributes': ['locale', 'f2', 'date', 'transferred', 'htype', 'locale_name'], 'join_keys': ['date']}, {'id': 'oil', 'name': 'oil', 'measurements': [], 'attributes': ['dcoilwtico', 'date', 'f3'], 'join_keys': ['date']}, {'id': 'transactions', 'name': 'transactions', 'measurements': [], 'attributes': ['tid', 'transactions', 'date', 'f5', 'store_nbr'], 'join_keys': ['tid', 'store_nbr', 'date']}, {'id': 'stores', 'name': 'stores', 'measurements': [], 'attributes': ['stype', 'state', 'cluster', 'city', 'store_nbr', 'f4'], 'join_keys': ['store_nbr']}, {'id': 'items', 'name': 'items', 'measurements': [], 'attributes': ['f1', 'family', 'item_nbr', 'perishable', 'class'], 'join_keys': ['item_nbr']}],
#         "links": [{'source': 'sales', 'target': 'items', 'left_keys': (['item_nbr'], ['item_nbr']), 'right_keys': (['item_nbr'], ['item_nbr']), 'multiplicity': ['M', '1'], 'missing': [920, 0]}, {'source': 'sales', 'target': 'transactions', 'left_keys': (['tid'], ['tid']), 'right_keys': (['tid'], ['tid']), 'multiplicity': ['M', '1'], 'missing': [74219, 0]}, {'source': 'holidays', 'target': 'transactions', 'left_keys': (['date'], ['date']), 'right_keys': (['date'], ['date']), 'multiplicity': ['1', 'M'], 'missing': [0, 0]}, {'source': 'holidays', 'target': 'oil', 'left_keys': (['date'], ['date']), 'right_keys': (['date'], ['date']), 'multiplicity': ['1', '1'], 'missing': [0, 0]}, {'source': 'transactions', 'target': 'stores', 'left_keys': (['store_nbr'], ['store_nbr']), 'right_keys': (['store_nbr'], ['store_nbr']), 'multiplicity': ['M', '1'], 'missing': [0, 0]}]
#     }
#
#     console.log(graph)
#
#     // height and width of the whole visualization
#     var svg = d3.select("#session1683579683")
#     svg.on("mousedown", function() {
#         //reset all highlighting if background is clicked
#         unHighlightGraph();
#     })
#     var width = +svg.attr("width")
#     var height = +svg.attr("height");
#
#
#     // attributes for Join Graph
#     var circleRadius = 30
#     var linkDistance = 120
#
#     var triangleBase = 15
#     var triangleHeight =13
#     //svg elements can be clipped and marker defs are rendered in the corner for some reason
#     //this offset will move it out of the corner
#     var verticalOffset = 5
#
#     // this is to make the edges a bit longer.
#     var edgeLengthModifier = 3
#
#     var defs = svg.append('defs')
#
#     defs.append('marker')
#         .attr('id','arrowHead').attr('markerWidth','30').attr('markerHeight','30')
#         .attr('refX', circleRadius + triangleHeight-3).attr('refY',triangleBase/2 + verticalOffset)
#         .attr('orient', 'auto-start-reverse')
#         .attr('class','markers')
#         .attr('markerUnits', 'userSpaceOnUse')
#         .append('polyline')
#         // triangle ArrowHead
#         .attr('transform', `translate(0,${verticalOffset})`)
#         .attr('points',`0 ${triangleBase/2}, ${triangleHeight +edgeLengthModifier} 0, 0 ${triangleBase/2}, ${triangleHeight +edgeLengthModifier} ${triangleBase}`)
#         // .attr('points',`0 0, ${triangleHeight} ${triangleBase/2}, 0 ${triangleBase}`)
#
#     defs .append('marker')
#         .attr('id','arrowHeadHighlight').attr('markerWidth','100px').attr('markerHeight','100px')
#         .attr('refX', circleRadius + triangleHeight-3).attr('refY',triangleBase/2 + verticalOffset)
#         .attr('orient', 'auto-start-reverse').attr('class', 'markers highlight')
#         .attr('markerUnits', 'userSpaceOnUse')
#         .attr('transform', `translate(0,${verticalOffset})`)
#         .append('polyline')
#         .attr('class', 'markers highlight')
#         // triangle ArrowHead
#         .attr('transform', `translate(0,${verticalOffset})`)
#         .attr('points',`0 ${triangleBase/2}, ${triangleHeight +edgeLengthModifier} 0, 0 ${triangleBase/2}, ${triangleHeight +edgeLengthModifier} ${triangleBase}`)
#
#
#     var schemaArea = d3.select("#session1683579683schema")
#
#     var trueTypeOf = (obj) => Object.prototype.toString.call(obj).slice(8, -1).toLowerCase()
#
#     var schema = schemaArea
#         .selectAll("div")
#         .data(graph.nodes)
#         .enter()
#         .append("div")
#         .attr('class', 'relation')
#         .attr('id', (d)=>{return 'schema_' + d.name;})
#         .on("click", function (d) {
#             d3.select(this)
#             .selectAll("span")
#             .classed('expanded', function() {return !d3.select(this).classed("expanded");})
#         });
#
#     schema
#         .append("text")
#         .attr('class', 'relationName')
#         .text((d)=>{return d.id ;})
#
#     schema
#         .append("div")
#         .selectAll("span")
#         .data((d)=>{return d.measurements;})
#         .enter()
#         .append("span")
#         .attr('id', (d)=>{return 'attribute_' + d.name;})
#         .attr('class', 'attribute measurements')
#         .text((d)=>{return d.name;})
#         .on("click", function (d) {
#             d3.event.stopPropagation();
#             unHighlightGraph()
#             unHighlightSchema()
#             d3.select(this).classed('highlight',true)
#             d.edges.map((e) => highlightRelationEdge(e.left_rel, e.right_rel, e.color))
#             d.relations.map((r) => highlightRelationNode(r.name, r.color, r.text

# %% [markdown]
# # Training a Decision Tree with JoinBoost
#
# Once you have defined the join graph, you can train a decision tree over it using JoinBoost.

# %%
from joinboost.app import DecisionTree

# Set the parameters for the decision tree
depth = 3
reg = DecisionTree(learning_rate=1, max_leaves=2 ** depth, max_depth=depth)

# Train the decision tree on the dataset
reg.fit(dataset)

# Compute the Root Mean Square Error (RMSE) on the training set
train_rmse = reg.compute_rmse('train')[0]
print("Training RMSE:", train_rmse)
# Out:
# Training RMSE: 2535.060839158587

# %% [markdown]
# # Training Gradient Boosting with JoinBoost
#
# After training a decision tree, you can train a Gradient Boosting model with JoinBoost for further improvement. In this example, we train a Gradient Boosting model with 10 iterations.
#
# As demonstrated, Gradient Boosting can further reduce the RMSE.

# %%
from joinboost.app import GradientBoosting

# Set the parameters for the Gradient Boosting model
reg = GradientBoosting(learning_rate=1, max_leaves=2 ** depth, max_depth=depth, iteration=10)

# Train the Gradient Boosting model on the dataset
reg.fit(dataset)

# Compute the Root Mean Square Error (RMSE) on the training set
train_rmse = reg.compute_rmse('train')[0]
print("Training RMSE for Gradient Boosting:", train_rmse)
# Out:
# Training RMSE for Gradient Boosting: 786.8773440907672

# %% [markdown]
# # Exploring JoinBoost Internals
#
# Internally, JoinBoost translates machine learning logic into SQL and executes SQL queries directly in your database without the need for data movement.
#
# To see the SQL queries generated by JoinBoost, you can enable debug mode when creating an executor instance:

# %%
# Create SparkExecutor instance with debug mode enabled
exe = SparkExecutor(spark, debug=True)

# Initialize JoinGraph with the executor
dataset = JoinGraph(exe=exe)

# Add relations and join conditions as described earlier
dataset.add_relation("sales", [], y='Y')
dataset.add_relation("holidays", ["htype", "locale", "locale_name", "transferred", "f2"])
dataset.add_relation("oil", ["dcoilwtico", "f3"])
dataset.add_relation("transactions", ["transactions", "f5"])
dataset.add_relation("stores", ["city", "state", "stype", "cluster", "f4"])
dataset.add_relation("items", ["family", "class", "perishable", "f1"])
dataset.add_join("sales", "items", ["item_nbr"], ["item_nbr"])
dataset.add_join("sales", "transactions", ["tid"], ["tid"])
dataset.add_join("transactions", "stores", ["store_nbr"], ["store_nbr"])
dataset.add_join("transactions", "holidays", ["date"], ["date"])
dataset.add_join("holidays", "oil", ["date"], ["date"])

# Set the parameters for the decision tree
depth = 3
reg = DecisionTree(learning_rate=1, max_leaves=2 ** depth, max_depth=depth)

# Train the decision tree on the dataset
reg.fit(dataset)

# Compute the Root Mean Square Error (RMSE) on the training set
train_rmse = reg.compute_rmse('train')[0]
print("Training RMSE:", train_rmse)
# Out:
# Streaming output truncated to the last 5000 lines.
# +-------------------+---+--------+
# |-2523.9350228107196|  1|     148|
# | -5114.945259512356|  2|    2142|
# | -17303.40289066734|  3|     471|
# |  -3982.77144377889|  1|    1591|
# | -4670.405934014017|  4|     463|
# | 2540.3161527900907|  1|    2659|
# |-13903.023418589346|  2|     496|
# | 2084.7686805128587|  1|     833|
# | -102.3144433702937|  1|    1829|
# |   3812.20308713511|  1|    1580|
# | -6953.031007789631|  1|    1645|
# | -2515.973519282561|  1|    2866|
# | 2478.3953426740836|  1|    3175|
# | -9856.377730253382|  3|    1088|
# | -7192.629214109124|  1|    2122|
# |-3778.5422158933607|  1|    1342|
# |-15662.887643042312|  3|    1507|
# |  2167.326165316411|  1|    2999|
# | -5952.213483393995|  3|     623|
# | -3415.399713834943|  1|    3179|
# +-------------------+---+--------+
# only showing top 20 rows
#
# SELECT htype AS htype, CASE WHEN 4626 > c THEN ((s/c)*s + (13439060.470843479-s)/(4626-c)*(13439060.470843479-s)) ELSE 0 END AS criteria, s AS s, c AS c
# FROM (SELECT SUM(s) OVER joinboost_window  AS s, SUM(c) OVER joinboost_window  AS c, htype AS htype
# FROM (SELECT SUM(s) AS s, SUM(c) AS c, holidays.htype AS htype
# FROM joinboost_tmp_7,holidays
# WHERE joinboost_tmp_7.date IS NOT DISTINCT FROM holidays.date
# GROUP BY holidays.htype
# )
# WINDOW joinboost_window AS (ORDER BY htype)
# )
# ORDER BY criteria DESC
# LIMIT 1
#
# 0.02168750762939453
# +-----+--------------------+-----------------+---+
# |htype|            criteria|                s|  c|
# +-----+--------------------+-----------------+---+
# |    1|3.910234392919276E10|429343.8198676765|119|
# +-----+--------------------+-----------------+---+
#
# SELECT locale AS locale, CASE WHEN 4626 > c THEN ((s/c)*s + (13439060.470843479-s)/(4626-c)*(13439060.470843479-s)) ELSE 0 END AS criteria, s AS s, c AS c
# FROM (SELECT SUM(s) OVER joinboost_window  AS s, SUM(c) OVER joinboost_window  AS c, locale AS locale
# FROM (SELECT SUM(s) AS s, SUM(c) AS c, holidays.locale AS locale
# FROM joinboost_tmp_7,holidays
# WHERE joinboost_tmp_7.date IS NOT DISTINCT FROM holidays.date
# GROUP BY holidays.locale
# )
# WINDOW joinboost_window AS (ORDER BY locale)
# )
# ORDER BY criteria DESC
# LIMIT 1
#
# 0.05697989463806152
# +------+--------------------+-----------------+---+
# |locale|            criteria|                s|  c|
# +------+--------------------+-----------------+---+
# |     1|3.905106275720991...|2177649.199440339|724|
# +------+--------------------+-----------------+---+
#
# SELECT locale_name AS locale_name, CASE WHEN 4626 > c THEN ((s/c)*s + (13439060.470843479-s)/(4626-c)*(13439060.470843479-s)) ELSE 0 END AS criteria, s AS s, c AS c
# FROM (SELECT SUM(s) OVER joinboost_window  AS s, SUM(c) OVER joinboost_window  AS c, locale_name AS locale_name
# FROM (SELECT SUM(s) AS s, SUM(c) AS c, holidays.locale_name AS locale_name
# FROM joinboost_tmp_7,holidays
# WHERE joinboost_tmp_7.date IS NOT DISTINCT FROM holidays.date
# GROUP BY holidays.locale_name
# )
# WINDOW joinboost_window AS (ORDER BY locale_name)
# )
# ORDER BY criteria DESC
# LIMIT 1
#
# 0.022906780242919922
# +-----------+--------------------+--------------------+----+
# |locale_name|            criteria|                   s|   c|
# +-----------+--------------------+--------------------+----+
# |         21|3.913079447957082E10|1.3346870149266029E7|4608|
# +-----------+--------------------+--------------------+----+
#
# SELECT transferred AS transferred, CASE WHEN 4626 > c THEN ((s/c)*s + (13439060.470843479-s)/(4626-c)*(13439060.470843479-s)) ELSE 0 END AS criteria, s AS s, c AS c
# FROM (SELECT SUM(s) OVER joinboost_window  AS s, SUM(c) OVER joinboost_window  AS c, transferred AS transferred
# FROM (SELECT SUM(s) AS s, SUM(c) AS c, holidays.transferred AS transferred
# FROM joinboost_tmp_7,holidays
# WHERE joinboost_tmp_7.date IS NOT DISTINCT FROM holidays.date
# GROUP BY holidays.transferred
# )
# WINDOW joinboost_window AS (ORDER BY transferred)
# )
# ORDER BY criteria DESC
# LIMIT 1
#
# 0.020133256912231445
# +-----------+--------------------+--------------------+----+
# |transferred|            criteria|                   s|   c|
# +-----------+--------------------+--------------------+----+
# |          1|3.928559844342974E10|1.3237016367131023E7|4589|
# +-----------+--------------------+--------------------+----+
#
# SELECT f2 AS f2, CASE WHEN 4626 > c THEN ((s/c)*s + (13439060.470843479-s)/(4626-c)*(13439060.470843479-s)) ELSE 0 END AS criteria, s AS s, c AS c
# FROM (SELECT SUM(s) OVER joinboost_window  AS s, SUM(c) OVER joinboost_window  AS c, f2 AS f2
# FROM (SELECT SUM(s) AS s, SUM(c) AS c, holidays.f2 AS f2
# FROM joinboost_tmp_7,holidays
# WHERE joinboost_tmp_7.date IS NOT DISTINCT FROM holidays.date
# GROUP BY holidays.f2
# )
# WINDOW joinboost_window AS (ORDER BY f2)
# )
# ORDER BY criteria DESC
# LIMIT 1
#
# 0.03277254104614258
# +---+--------------------+------------------+---+
# | f2|            criteria|                 s|  c|
# +---+--------------------+------------------+---+
# |128|3.919104171618184E10|1529153.2840263757|624|
# +---+--------------------+------------------+---+
#
# SELECT dcoilwtico AS dcoilwtico, CASE WHEN 4626 > c THEN ((s/c)*s + (13439060.470843479-s)/(4626-c)*(13439060.470843479-s)) ELSE 0 END AS criteria, s AS s, c AS c
# FROM (SELECT SUM(s) OVER joinboost_window  AS s, SUM(c) OVER joinboost_window  AS c, dcoilwtico AS dcoilwtico
# FROM (SELECT SUM(s) AS s, SUM(c) AS c, oil.dcoilwtico AS dcoilwtico
# FROM joinboost_tmp_8,oil
# WHERE joinboost_tmp_8.date IS NOT DISTINCT FROM oil.date
# GROUP BY oil.dcoilwtico
# )
# WINDOW joinboost_window AS (ORDER BY dcoilwtico)
# )
# ORDER BY criteria DESC
# LIMIT 1
#
# 0.019458532333374023
# +----------+--------------------+--------------------+----+
# |dcoilwtico|            criteria|                   s|   c|
# +----------+--------------------+--------------------+----+
# |         8|3.909245252860062...|1.2743530081060432E7|4347|
# +----------+--------------------+--------------------+----+
#
# SELECT f3 AS f3, CASE WHEN 4626 > c THEN ((s/c)*s + (13439060.470843479-s)/(4626-c)*(13439060.470843479-s)) ELSE 0 END AS criteria, s AS s, c AS c
# FROM (SELECT SUM(s) OVER joinboost_window  AS s, SUM(c) OVER joinboost_window  AS c, f3 AS f3
# FROM (SELECT SUM(s) AS s, SUM(c) AS c, oil.f3 AS f3
# FROM joinboost_tmp_8,oil
# WHERE joinboost_tmp_8.date IS NOT DISTINCT FROM oil.date
# GROUP BY oil.f3
# )
# WINDOW joinboost_window AS (ORDER BY f3)
# )
# ORDER BY criteria DESC
# LIMIT 1
#
# 0.03729653358459473
# +---+--------------------+--------------------+----+
# | f3|            criteria|                   s|   c|
# +---+--------------------+--------------------+----+
# |463|6.904685613990591E10|1.2754131196806507E7|2363|
# +---+--------------------+--------------------+----+
#
# SELECT transactions AS transactions, CASE WHEN 4626 > c THEN ((s/c)*s + (13439060.470843479-s)/(4626-c)*(13439060.470843479-s)) ELSE 0 END AS criteria, s AS s, c AS c
# FROM (SELECT SUM(s) OVER joinboost_window  AS s, SUM(c) OVER joinboost_window  AS c, transactions AS transactions
# FROM (SELECT SUM(s) AS s, SUM(c) AS c, transactions.transactions AS transactions
# FROM joinboost_tmp_6,joinboost_tmp_2,transactions
# WHERE joinboost_tmp_6.store_nbr IS NOT DISTINCT FROM transactions.store_nbr AND joinboost_tmp_2.tid IS NOT DISTINCT FROM transactions.tid
# GROUP BY transactions.transactions
# )
# WINDOW joinboost_window AS (ORDER BY transactions)
# )
# ORDER BY criteria DESC
# LIMIT 1
#
# 0.02431464195251465
# +------------+-------------------+-------------------+----+
# |transactions|           criteria|                  s|   c|
# +------------+-------------------+-------------------+----+
# |           3|4.03722320952434E10|1.007983674662842E7|3066|
# +------------+-------------------+-------------------+----+
#
# SELECT f5 AS f5, CASE WHEN 4626 > c THEN ((s/c)*s + (13439060.470843479-s)/(4626-c)*(13439060.470843479-s)) ELSE 0 END AS criteria, s AS s, c AS c
# FROM (SELECT SUM(s) OVER joinboost_window  AS s, SUM(c) OVER joinboost_window  AS c, f5 AS f5
# FROM (SELECT SUM(s) AS s, SUM(c) AS c, transactions.f5 AS f5
# FROM joinboost_tmp_6,joinboost_tmp_2,transactions
# WHERE joinboost_tmp_6.store_nbr IS NOT DISTINCT FROM transactions.store_nbr AND joinboost_tmp_2.tid IS NOT DISTINCT FROM transactions.tid
# GROUP BY transactions.f5
# )
# WINDOW joinboost_window AS (ORDER BY f5)
# )
# ORDER BY criteria DESC
# LIMIT 1
#
# 0.032624244689941406
# +---+--------------------+------------------+----+
# | f5|            criteria|                 s|   c|
# +---+--------------------+------------------+----+
# |557|7.003195532250107E10|1424411.6112285736|2541|
# +---+--------------------+------------------+----+
#
# SELECT city AS city, CASE WHEN 4626 > c THEN ((s/c)*s + (13439060.470843479-s)/(4626-c)*(13439060.470843479-s)) ELSE 0 END AS criteria, s AS s, c AS c
# FROM (SELECT SUM(s) OVER joinboost_window  AS s, SUM(c) OVER joinboost_window  AS c, city AS city
# FROM (SELECT SUM(s) AS s, SUM(c) AS c, stores.city AS city
# FROM joinboost_tmp_3,stores
# WHERE stores.f4 <= 496 AND joinboost_tmp_3.store_nbr IS NOT DISTINCT FROM stores.store_nbr
# GROUP BY stores.city
# )
# WINDOW joinboost_window AS (ORDER BY city)
# )
# ORDER BY criteria DESC
# LIMIT 1
#
# 0.025646448135375977
# +----+--------------------+------------------+---+
# |city|            criteria|                 s|  c|
# +----+--------------------+------------------+---+
# |   0|4.009011927671780...|214708.23139363603|243|
# +----+--------------------+------------------+---+
#
# SELECT state AS state, CASE WHEN 4626 > c THEN ((s/c)*s + (13439060.470843479-s)/(4626-c)*(13439060.470843479-s)) ELSE 0 END AS criteria, s AS s, c AS c
# FROM (SELECT SUM(s) OVER joinboost_window  AS s, SUM(c) OVER joinboost_window  AS c, state AS state
# FROM (SELECT SUM(s) AS s, SUM(c) AS c, stores.state AS state
# FROM joinboost_tmp_3,stores
# WHERE stores.f4 <= 496 AND joinboost_tmp_3.store_nbr IS NOT DISTINCT FROM stores.store_nbr
# GROUP BY stores.state
# )
# WINDOW joinboost_window AS (ORDER BY state)
# )
# ORDER BY criteria DESC
# LIMIT 1
#
# 0.028387069702148438
# +-----+--------------------+--------------------+----+
# |state|            criteria|                   s|   c|
# +-----+--------------------+--------------------+----+
# |   14|4.009011927671780...|1.3224352239449844E7|4383|
# +-----+--------------------+--------------------+----+
#
# SELECT stype AS stype, CASE WHEN 4626 > c THEN ((s/c)*s + (13439060.470843479-s)/(4626-c)*(13439060.470843479-s)) ELSE 0 END AS criteria, s AS s, c AS c
# FROM (SELECT SUM(s) OVER joinboost_window  AS s, SUM(c) OVER joinboost_window  AS c, stype AS stype
# FROM (SELECT SUM(s) AS s, SUM(c) AS c, stores.stype AS stype
# FROM joinboost_tmp_3,stores
# WHERE stores.f4 <= 496 AND joinboost_tmp_3.store_nbr IS NOT DISTINCT FROM stores.store_nbr
# GROUP BY stores.stype
# )
# WINDOW joinboost_window AS (ORDER BY stype)
# )
# ORDER BY criteria DESC
# LIMIT 1
#
# 0.019922971725463867
# +-----+--------------------+-------------------+----+
# |stype|            criteria|                  s|   c|
# +-----+--------------------+-------------------+----+
# |    3|3.980255639139815E10|1.270699825550817E7|4485|
# +-----+--------------------+-------------------+----+
#
# SELECT cluster AS cluster, CASE WHEN 4626 > c THEN ((s/c)*s + (13439060.470843479-s)/(4626-c)*(13439060.470843479-s)) ELSE 0 END AS criteria, s AS s, c AS c
# FROM (SELECT SUM(s) OVER joinboost_window  AS s, SUM(c) OVER joinboost_window  AS c, cluster AS cluster
# FROM (SELECT SUM(s) AS s, SUM(c) AS c, stores.cluster AS cluster
# FROM joinboost_tmp_3,stores
# WHERE stores.f4 <= 496 AND joinboost_tmp_3.store_nbr IS NOT DISTINCT FROM stores.store_nbr
# GROUP BY stores.cluster
# )
# WINDOW joinboost_window AS (ORDER BY cluster)
# )
# ORDER BY criteria DESC
# LIMIT 1
#
# 0.01500391960144043
# +-------+--------------------+-----------------+----+
# |cluster|            criteria|                s|   c|
# +-------+--------------------+-----------------+----+
# |      7|4.002234559869362E10|5622806.178675278|2302|
# +-------+--------------------+-----------------+----+
#
# SELECT f4 AS f4, CASE WHEN 4626 > c THEN ((s/c)*s + (13439060.470843479-s)/(4626-c)*(13439060.470843479-s)) ELSE 0 END AS criteria, s AS s, c AS c
# FROM (SELECT SUM(s) OVER joinboost_window  AS s, SUM(c) OVER joinboost_window  AS c, f4 AS f4
# FROM (SELECT SUM(s) AS s, SUM(c) AS c, stores.f4 AS f4
# FROM joinboost_tmp_3,stores
# WHERE stores.f4 <= 496 AND joinboost_tmp_3.store_nbr IS NOT DISTINCT FROM stores.store_nbr
# GROUP BY stores.f4
# )
# WINDOW joinboost_window AS (ORDER BY f4)
# )
# ORDER BY criteria DESC
# LIMIT 1
#
# 0.016248464584350586
# +---+--------------------+-----------------+----+
# | f4|            criteria|                s|   c|
# +---+--------------------+-----------------+----+
# |166|4.675157946682722E10|8366429.573822367|1871|
# +---+--------------------+-----------------+----+
#
# SELECT family AS family, CASE WHEN 4626 > c THEN ((s/c)*s + (13439060.470843479-s)/(4626-c)*(13439060.470843479-s)) ELSE 0 END AS criteria, s AS s, c AS c
# FROM (SELECT SUM(s) OVER joinboost_window  AS s, SUM(c) OVER joinboost_window  AS c, family AS family
# FROM (SELECT SUM(s) AS s, SUM(c) AS c, items.family AS family
# FROM joinboost_tmp_10,items
# WHERE joinboost_tmp_10.item_nbr IS NOT DISTINCT FROM items.item_nbr
# GROUP BY items.family
# )
# WINDOW joinboost_window AS (ORDER BY family)
# )
# ORDER BY criteria DESC
# LIMIT 1
#
# 0.019644737243652344
# +------+--------------------+-----------------+----+
# |family|            criteria|                s|   c|
# +------+--------------------+-----------------+----+
# |     8|3.910765755425466E10|5098742.650681833|1848|
# +------+--------------------+-----------------+----+
#
# SELECT class AS class, CASE WHEN 4626 > c THEN ((s/c)*s + (13439060.470843479-s)/(4626-c)*(13439060.470843479-s)) ELSE 0 END AS criteria, s AS s, c AS c
# FROM (SELECT SUM(s) OVER joinboost_window  AS s, SUM(c) OVER joinboost_window  AS c, class AS class
# FROM (SELECT SUM(s) AS s, SUM(c) AS c, items.class AS class
# FROM joinboost_tmp_10,items
# WHERE joinboost_tmp_10.item_nbr IS NOT DISTINCT FROM items.item_nbr
# GROUP BY items.class
# )
# WINDOW joinboost_window AS (ORDER BY class)
# )
# ORDER BY criteria DESC
# LIMIT 1
#
# 0.022624969482421875
# +-----+--------------------+-----------------+---+
# |class|            criteria|                s|  c|
# +-----+--------------------+-----------------+---+
# |   22|3.916681069334866E10|2385491.118097749|726|
# +-----+--------------------+-----------------+---+
#
# SELECT perishable AS perishable, CASE WHEN 4626 > c THEN ((s/c)*s + (13439060.470843479-s)/(4626-c)*(13439060.470843479-s)) ELSE 0 END AS criteria, s AS s, c AS c
# FROM (SELECT SUM(s) OVER joinboost_window  AS s, SUM(c) OVER joinboost_window  AS c, perishable AS perishable
# FROM (SELECT SUM(s) AS s, SUM(c) AS c, items.perishable AS perishable
# FROM joinboost_tmp_10,items
# WHERE joinboost_tmp_10.item_nbr IS NOT DISTINCT FROM items.item_nbr
# GROUP BY items.perishable
# )
# WINDOW joinboost_window AS (ORDER BY perishable)
# )
# ORDER BY criteria DESC
# LIMIT 1
#
# 0.013535261154174805
# +----------+--------------------+-------------------+----+
# |perishable|            criteria|                  s|   c|
# +----------+--------------------+-------------------+----+
# |         0|3.904237128860941E10|1.001430178271311E7|3441|
# +----------+--------------------+-------------------+----+
#
# SELECT f1 AS f1, CASE WHEN 4626 > c THEN ((s/c)*s + (13439060.470843479-s)/(4626-c)*(13439060.470843479-s)) ELSE 0 END AS criteria, s AS s, c AS c
# FROM (SELECT SUM(s) OVER joinboost_window  AS s, SUM(c) OVER joinboost_window  AS c, f1 AS f1
# FROM (SELECT SUM(s) AS s, SUM(c) AS c, items.f1 AS f1
# FROM joinboost_tmp_10,items
# WHERE joinboost_tmp_10.item_nbr IS NOT DISTINCT FROM items.item_nbr
# GROUP BY items.f1
# )
# WINDOW joinboost_window AS (ORDER BY f1)
# )
# ORDER BY criteria DESC
# LIMIT 1
#
# 0.04798388481140137
# +---+--------------------+-----------------+----+
# | f1|            criteria|                s|   c|
# +---+--------------------+-----------------+----+
# |592|3.944907881812749E10|6916619.378190666|2615|
# +---+--------------------+-----------------+----+
#
# SELECT htype AS htype, CASE WHEN 5374 > c THEN ((s/c)*s + (-13439060.470843479-s)/(5374-c)*(-13439060.470843479-s)) ELSE 0 END AS criteria, s AS s, c AS c
# FROM (SELECT SUM(s) OVER joinboost_window  AS s, SUM(c) OVER joinboost_window  AS c, htype AS htype
# FROM (SELECT SUM(s) AS s, SUM(c) AS c, holidays.htype AS htype
# FROM joinboost_tmp_12,holidays
# WHERE joinboost_tmp_12.date IS NOT DISTINCT FROM holidays.date
# GROUP BY holidays.htype
# )
# WINDOW joinboost_window AS (ORDER BY htype)
# )
# ORDER BY criteria DESC
# LIMIT 1
#
# 0.03693342208862305
# +-----+-------------------+-------------------+---+
# |htype|           criteria|                  s|  c|
# +-----+-------------------+-------------------+---+
# |    1|3.36651419773215E10|-228926.27910104085|125|
# +-----+-------------------+-------------------+---+
#
# SELECT locale AS locale, CASE WHEN 5374 > c THEN ((s/c)*s + (-13439060.470843479-s)/(5374-c)*(-13439060.470843479-s)) ELSE 0 END AS criteria, s AS s, c AS c
# FROM (SELECT SUM(s) OVER joinboost_window  AS s, SUM(c) OVER joinboost_window  AS c, locale AS locale
# FROM (SELECT SUM(s) AS s, SUM(c) AS c, holidays.locale AS locale
# FROM joinboost_tmp_12,holidays
# WHERE joinboost_tmp_12.date IS NOT DISTINCT FROM holidays.date
# GROUP BY holidays.locale
# )
# WINDOW joinboost_window AS (ORDER BY locale)
# )
# ORDER BY criteria DESC
# LIMIT 1
#
# 0.02119898796081543
# +------+--------------------+--------------------+----+
# |locale|            criteria|                   s|   c|
# +------+--------------------+--------------------+----+
# |     2|3.366968915868725E10|-1.336350718939613E7|5321|
# +------+--------------------+--------------------+----+
#
# SELECT locale_name AS locale_name, CASE WHEN 5374 > c THEN ((s/c)*s + (-13439060.470843479-s)/(5374-c)*(-13439060.470843479-s)) ELSE 0 END AS criteria, s AS s, c AS c
# FROM (SELECT SUM(s) OVER joinboost_window  AS s, SUM(c) OVER joinboost_window  AS c, locale_name AS locale_name
# FROM (SELECT SUM(s) AS s, SUM(c) AS c, holidays.locale_name AS locale_name
# FROM joinboost_tmp_12,holidays
# WHERE joinboost_tmp_12.date IS NOT DISTINCT FROM holidays.date
# GROUP BY holidays.locale_name
# )
# WINDOW joinboost_window AS (ORDER BY locale_name)
# )
# ORDER BY criteria DESC
# LIMIT 1
#
# 0.041785478591918945
# +-----------+--------------------+-------------------+---+
# |locale_name|            criteria|                  s|  c|
# +-----------+--------------------+-------------------+---+
# |          0|3.366829227363492E10|-16945.370618370463| 21|
# +-----------+--------------------+-------------------+---+
#
# SELECT transferred AS transferred, CASE WHEN 5374 > c THEN ((s/c)*s + (-13439060.470843479-s)/(5374-c)*(-13439060.470843479-s)) ELSE 0 END AS criteria, s AS s, c AS c
# FROM (SELECT SUM(s) OVER joinboost_window  AS s, SUM(c) OVER joinboost_window  AS c, transferred AS transferred
# FROM (SELECT SUM(s) AS s, SUM(c) AS c, holidays.transferred AS transferred
# FROM joinboost_tmp_12,holidays
# WHERE joinboost_tmp_12.date IS NOT DISTINCT FROM holidays.date
# GROUP BY holidays.transferred
# )
# WINDOW joinboost_window AS (ORDER BY transferred)
# )
# ORDER BY criteria DESC
# LIMIT 1
#
# 0.019907236099243164
# +-----------+--------------------+--------------------+----+
# |transferred|            criteria|                   s|   c|
# +-----------+--------------------+--------------------+----+
# |          1|3.365190065813913...|-1.34078184716595...|5348|
# +-----------+--------------------+--------------------+----+
#
# SELECT f2 AS f2, CASE WHEN 5374 > c THEN ((s/c)*s + (-13439060.470843479-s)/(5374-c)*(-13439060.470843479-s)) ELSE 0 END AS criteria, s AS s, c AS c
# FROM (SELECT SUM(s) OVER joinboost_window  AS s, SUM(c) OVER joinboost_window  AS c, f2 AS f2
# FROM (SELECT SUM(s) AS s, SUM(c) AS c, holidays.f2 AS f2
# FROM joinboost_tmp_12,holidays
# WHERE joinboost_tmp_12.date IS NOT DISTINCT FROM holidays.date
# GROUP BY holidays.f2
# )
# WINDOW joinboost_window AS (ORDER BY f2)
# )
# ORDER BY criteria DESC
# LIMIT 1
#
# 0.07740211486816406
# +---+--------------------+--------------------+----+
# | f2|            criteria|                   s|   c|
# +---+--------------------+--------------------+----+
# |790|3.371108841016909E10|-1.06013279569244...|4113|
# +---+--------------------+--------------------+----+
#
# SELECT dcoilwtico AS dcoilwtico, CASE WHEN 5374 > c THEN ((s/c)*s + (-13439060.470843479-s)/(5374-c)*(-13439060.470843479-s)) ELSE 0 END AS criteria, s AS s, c AS c
# FROM (SELECT SUM(s) OVER joinboost_window  AS s, SUM(c) OVER joinboost_window  AS c, dcoilwtico AS dcoilwtico
# FROM (SELECT SUM(s) AS s, SUM(c) AS c, oil.dcoilwtico AS dcoilwtico
# FROM joinboost_tmp_13,oil
# WHERE joinboost_tmp_13.date IS NOT DISTINCT FROM oil.date
# GROUP BY oil.dcoilwtico
# )
# WINDOW joinboost_window AS (ORDER BY dcoilwtico)
# )
# ORDER BY criteria DESC
# LIMIT 1
#
# 0.01966094970703125
# +----------+--------------------+------------------+----+
# |dcoilwtico|            criteria|                 s|   c|
# +----------+--------------------+------------------+----+
# |         4|3.368173083720414...|-8628564.661899794|3328|
# +----------+--------------------+------------------+----+
#
# SELECT f3 AS f3, CASE WHEN 5374 > c THEN ((s/c)*s + (-13439060.470843479-s)/(5374-c)*(-13439060.470843479-s)) ELSE 0 END AS criteria, s AS s, c AS c
# FROM (SELECT SUM(s) OVER joinboost_window  AS s, SUM(c) OVER joinboost_window  AS c, f3 AS f3
# FROM (SELECT SUM(s) AS s, SUM(c) AS c, oil.f3 AS f3
# FROM joinboost_tmp_13,oil
# WHERE joinboost_tmp_13.date IS NOT DISTINCT FROM oil.date
# GROUP BY oil.f3
# )
# WINDOW joinboost_window AS (ORDER BY f3)
# )
# ORDER BY criteria DESC
# LIMIT 1
#
# 0.029013872146606445
# +---+--------------------+------------------+----+
# | f3|            criteria|                 s|   c|
# +---+--------------------+------------------+----+
# |512|6.713224671915622E10|-438939.6478998393|2854|
# +---+--------------------+------------------+----+
#
# SELECT transactions AS transactions, CASE WHEN 5374 > c THEN ((s/c)*s + (-13439060.470843479-s)/(5374-c)*(-13439060.470843479-s)) ELSE 0 END AS criteria, s AS s, c AS c
# FROM (SELECT SUM(s) OVER joinboost_window  AS s, SUM(c) OVER joinboost_window  AS c, transactions AS transactions
# FROM (SELECT SUM(s) AS s, SUM(c) AS c, transactions.transactions AS transactions
# FROM joinboost_tmp_11,joinboost_tmp_2,transactions
# WHERE joinboost_tmp_11.store_nbr IS NOT DISTINCT FROM transactions.store_nbr AND joinboost_tmp_2.tid IS NOT DISTINCT FROM transactions.tid
# GROUP BY transactions.transactions
# )
# WINDOW joinboost_window AS (ORDER BY transactions)
# )
# ORDER BY criteria DESC
# LIMIT 1
#
# 0.0287783145904541
# +------------+--------------------+--------------------+----+
# |transactions|            criteria|                   s|   c|
# +------------+--------------------+--------------------+----+
# |           4|3.397161795296413...|-1.263323303857964E7|4892|
# +------------+--------------------+--------------------+----+
#
# SELECT f5 AS f5, CASE WHEN 5374 > c THEN ((s/c)*s + (-13439060.470843479-s)/(5374-c)*(-13439060.470843479-s)) ELSE 0 END AS criteria, s AS s, c AS c
# FROM (SELECT SUM(s) OVER joinboost_window  AS s, SUM(c) OVER joinboost_window  AS c, f5 AS f5
# FROM (SELECT SUM(s) AS s, SUM(c) AS c, transactions.f5 AS f5
# FROM joinboost_tmp_11,joinboost_tmp_2,transactions
# WHERE joinboost_tmp_11.store_nbr IS NOT DISTINCT FROM transactions.store_nbr AND joinboost_tmp_2.tid IS NOT DISTINCT FROM transactions.tid
# GROUP BY transactions.f5
# )
# WINDOW joinboost_window AS (ORDER BY f5)
# )
# ORDER BY criteria DESC
# LIMIT 1
#
# 0.03822159767150879
# +---+--------------------+--------------------+----+
# | f5|            criteria|                   s|   c|
# +---+--------------------+--------------------+----+
# |553|6.982692425209145E10|-1.44829037512785...|3024|
# +---+--------------------+--------------------+----+
#
# SELECT city AS city, CASE WHEN 5374 > c THEN ((s/c)*s + (-13439060.470843479-s)/(5374-c)*(-13439060.470843479-s)) ELSE 0 END AS criteria, s AS s, c AS c
# FROM (SELECT SUM(s) OVER joinboost_window  AS s, SUM(c) OVER joinboost_window  AS c, city AS city
# FROM (SELECT SUM(s) AS s, SUM(c) AS c, stores.city AS city
# FROM joinboost_tmp_3,stores
# WHERE stores.f4 > 496 AND joinboost_tmp_3.store_nbr IS NOT DISTINCT FROM stores.store_nbr
# GROUP BY stores.city
# )
# WINDOW joinboost_window AS (ORDER BY city)
# )
# ORDER BY criteria DESC
# LIMIT 1
#
# 0.01878809928894043
# +----+--------------------+--------------------+----+
# |city|            criteria|                   s|   c|
# +----+--------------------+--------------------+----+
# |  19|3.503154701448369...|-1.32367418143567...|5018|
# +----+--------------------+--------------------+----+
#
# SELECT state AS state, CASE WHEN 5374 > c THEN ((s/c)*s + (-13439060.470843479-s)/(5374-c)*(-13439060.470843479-s)) ELSE 0 END AS criteria, s AS s, c AS c
# FROM (SELECT SUM(s) OVER joinboost_window  AS s, SUM(c) OVER joinboost_window  AS c, state AS state
# FROM (SELECT SUM(s) AS s, SUM(c) AS c, stores.state AS state
# FROM joinboost_tmp_3,stores
# WHERE stores.f4 > 496 AND joinboost_tmp_3.store_nbr IS NOT DISTINCT FROM stores.store_nbr
# GROUP BY stores.state
# )
# WINDOW joinboost_window AS (ORDER BY state)
# )
# ORDER BY criteria DESC
# LIMIT 1
#
# 0.029451370239257812
# +-----+-------------------+--------------------+----+
# |state|           criteria|                   s|   c|
# +-----+-------------------+--------------------+----+
# |   12|3.49863719294744E10|-1.29160851614198...|4839|
# +-----+-------------------+--------------------+----+
#
# SELECT stype AS stype, CASE WHEN 5374 > c THEN ((s/c)*s + (-13439060.470843479-s)/(5374-c)*(-13439060.470843479-s)) ELSE 0 END AS criteria, s AS s, c AS c
# FROM (SELECT SUM(s) OVER joinboost_window  AS s, SUM(c) OVER joinboost_window  AS c, stype AS stype
# FROM (SELECT SUM(s) AS s, SUM(c) AS c, stores.stype AS stype
# FROM joinboost_tmp_3,stores
# WHERE stores.f4 > 496 AND joinboost_tmp_3.store_nbr IS NOT DISTINCT FROM stores.store_nbr
# GROUP BY stores.stype
# )
# WINDOW joinboost_window AS (ORDER BY stype)
# )
# ORDER BY criteria DESC
# LIMIT 1
#
# 0.018456220626831055
# +-----+--------------------+------------------+----+
# |stype|            criteria|                 s|   c|
# +-----+--------------------+------------------+----+
# |    2|3.419330116252354E10|-8133837.968412863|2899|
# +-----+--------------------+------------------+----+
#
# SELECT cluster AS cluster, CASE WHEN 5374 > c THEN ((s/c)*s + (-13439060.470843479-s)/(5374-c)*(-13439060.470843479-s)) ELSE 0 END AS criteria, s AS s, c AS c
# FROM (SELECT SUM(s) OVER joinboost_window  AS s, SUM(c) OVER joinboost_window  AS c, cluster AS cluster
# FROM (SELECT SUM(s) AS s, SUM(c) AS c, stores.cluster AS cluster
# FROM joinboost_tmp_3,stores
# WHERE stores.f4 > 496 AND joinboost_tmp_3.store_nbr IS NOT DISTINCT FROM stores.store_nbr
# GROUP BY stores.cluster
# )
# WINDOW joinboost_window AS (ORDER BY cluster)
# )
# ORDER BY criteria DESC
# LIMIT 1
#
# 0.015753507614135742
# +-------+--------------------+------------------+----+
# |cluster|            criteria|                 s|   c|
# +-------+--------------------+------------------+----+
# |      3|3.454534580153005E10|-2260533.654197694|1287|
# +-------+--------------------+------------------+----+
#
# SELECT f4 AS f4, CASE WHEN 5374 > c THEN ((s/c)*s + (-13439060.470843479-s)/(5374-c)*(-13439060.470843479-s)) ELSE 0 END AS criteria, s AS s, c AS c
# FROM (SELECT SUM(s) OVER joinboost_window  AS s, SUM(c) OVER joinboost_window  AS c, f4 AS f4
# FROM (SELECT SUM(s) AS s, SUM(c) AS c, stores.f4 AS f4
# FROM joinboost_tmp_3,stores
# WHERE stores.f4 > 496 AND joinboost_tmp_3.store_nbr IS NOT DISTINCT FROM stores.store_nbr
# GROUP BY stores.f4
# )
# WINDOW joinboost_window AS (ORDER BY f4)
# )
# ORDER BY criteria DESC
# LIMIT 1
#
# 0.03743624687194824
# +---+--------------------+------------------+----+
# | f4|            criteria|                 s|   c|
# +---+--------------------+------------------+----+
# |760|4.427805013637171E10|-2749688.859242913|2613|
# +---+--------------------+------------------+----+
#
# SELECT family AS family, CASE WHEN 5374 > c THEN ((s/c)*s + (-13439060.470843479-s)/(5374-c)*(-13439060.470843479-s)) ELSE 0 END AS criteria, s AS s, c AS c
# FROM (SELECT SUM(s) OVER joinboost_window  AS s, SUM(c) OVER joinboost_window  AS c, family AS family
# FROM (SELECT SUM(s) AS s, SUM(c) AS c, items.family AS family
# FROM joinboost_tmp_15,items
# WHERE joinboost_tmp_15.item_nbr IS NOT DISTINCT FROM items.item_nbr
# GROUP BY items.family
# )
# WINDOW joinboost_window AS (ORDER BY family)
# )
# ORDER BY criteria DESC
# LIMIT 1
#
# 0.03057694435119629
# +------+--------------------+-------------------+----+
# |family|            criteria|                  s|   c|
# +------+--------------------+-------------------+----+
# |     5|3.365178999708441E10|-2318830.6881369534|1003|
# +------+--------------------+-------------------+----+
#
# SELECT class AS class, CASE WHEN 5374 > c THEN ((s/c)*s + (-13439060.470843479-s)/(5374-c)*(-13439060.470843479-s)) ELSE 0 END AS criteria, s AS s, c AS c
# FROM (SELECT SUM(s) OVER joinboost_window  AS s, SUM(c) OVER joinboost_window  AS c, class AS class
# FROM (SELECT SUM(s) AS s, SUM(c) AS c, items.class AS class
# FROM joinboost_tmp_15,items
# WHERE joinboost_tmp_15.item_nbr IS NOT DISTINCT FROM items.item_nbr
# GROUP BY items.class
# )
# WINDOW joinboost_window AS (ORDER BY class)
# )
# ORDER BY criteria DESC
# LIMIT 1
#
# 0.02196478843688965
# +-----+--------------------+--------------------+----+
# |class|            criteria|                   s|   c|
# +-----+--------------------+--------------------+----+
# |  186|3.365419791657678...|-1.00151689670538...|4090|
# +-----+--------------------+--------------------+----+
#
# SELECT perishable AS perishable, CASE WHEN 5374 > c THEN ((s/c)*s + (-13439060.470843479-s)/(5374-c)*(-13439060.470843479-s)) ELSE 0 END AS criteria, s AS s, c AS c
# FROM (SELECT SUM(s) OVER joinboost_window  AS s, SUM(c) OVER joinboost_window  AS c, perishable AS perishable
# FROM (SELECT SUM(s) AS s, SUM(c) AS c, items.perishable AS perishable
# FROM joinboost_tmp_15,items
# WHERE joinboost_tmp_15.item_nbr IS NOT DISTINCT FROM items.item_nbr
# GROUP BY items.perishable
# )
# WINDOW joinboost_window AS (ORDER BY perishable)
# )
# ORDER BY criteria DESC
# LIMIT 1
#
# 0.03433561325073242
# +----------+--------------------+------------------+----+
# |perishable|            criteria|                 s|   c|
# +----------+--------------------+------------------+----+
# |         0|3.361595436437243...|-9985218.178083746|3956|
# +----------+--------------------+------------------+----+
#
# SELECT f1 AS f1, CASE WHEN 5374 > c THEN ((s/c)*s + (-13439060.470843479-s)/(5374-c)*(-13439060.470843479-s)) ELSE 0 END AS criteria, s AS s, c AS c
# FROM (SELECT SUM(s) OVER joinboost_window  AS s, SUM(c) OVER joinboost_window  AS c, f1 AS f1
# FROM (SELECT SUM(s) AS s, SUM(c) AS c, items.f1 AS f1
# FROM joinboost_tmp_15,items
# WHERE joinboost_tmp_15.item_nbr IS NOT DISTINCT FROM items.item_nbr
# GROUP BY items.f1
# )
# WINDOW joinboost_window AS (ORDER BY f1)
# )
# ORDER BY criteria DESC
# LIMIT 1
#
# 0.04448294639587402
# +---+--------------------+------------------+----+
# | f1|            criteria|                 s|   c|
# +---+--------------------+------------------+----+
# |589|3.405536365523504E10|-8528382.279861003|3104|
# +---+--------------------+------------------+----+
#
# SELECT SUM(s) AS s, SUM(c) AS c, transactions.store_nbr AS store_nbr
# FROM joinboost_tmp_11,joinboost_tmp_2,transactions
# WHERE transactions.f5 <= 553 AND joinboost_tmp_11.store_nbr IS NOT DISTINCT FROM transactions.store_nbr AND joinboost_tmp_2.tid IS NOT DISTINCT FROM transactions.tid
# GROUP BY transactions.store_nbr
#
# 0.009932279586791992
# +-------------------+---+---------+
# |                  s|  c|store_nbr|
# +-------------------+---+---------+
# |-236745.35143862807| 75|       31|
# | -505716.5817944538| 74|       53|
# | -442061.8768471421| 72|       28|
# | -532698.3310883151|115|       26|
# |-349349.68352830934|110|       27|
# |-424369.50349997147|110|       22|
# | -663413.0550264765|170|       47|
# | -474789.3012357694| 80|       13|
# | -759840.1079461736|123|        6|
# |-431986.68408131285| 98|       16|
# | -676505.3906072627|122|        3|
# | -948182.6862966403|140|       48|
# | -359266.0851047584| 70|       41|
# | -300110.1282214463| 82|       15|
# | -539969.1110212348| 74|        9|
# | -688584.2222340435| 99|       35|
# |-264250.41212528513|104|        4|
# | -911542.8375946184|133|        8|
# | -675760.0999038484|136|       10|
# |-413970.18757482356|140|       50|
# +-------------------+---+---------+
# only showing top 20 rows
#
# SELECT SUM(s) AS s, SUM(c) AS c, transactions.date AS date
# FROM joinboost_tmp_11,joinboost_tmp_2,transactions
# WHERE transactions.f5 <= 553 AND joinboost_tmp_11.store_nbr IS NOT DISTINCT FROM transactions.store_nbr AND joinboost_tmp_2.tid IS NOT DISTINCT FROM transactions.tid
# GROUP BY transactions.date
#
# 0.010869026184082031
# +-------------------+---+----+
# |                  s|  c|date|
# +-------------------+---+----+
# | -23409.29430286877|  2|1645|
# | -7474.955067115277|  2| 833|
# |  -31386.3739130673|  7|1591|
# |-15788.207469590277|  4|1342|
# |-17864.112100458435|  2|1238|
# |-31168.521905055397|  3|1580|
# | -8636.717551164973|  3| 496|
# | 1399.9060898181287|  2| 471|
# |-7286.6041241039975|  3|1460|
# |-1732.5760753738632|  1| 858|
# |  -7241.68883162167|  4|1025|
# | -33828.83576785647|  4|1395|
# |-19603.412616121117|  2| 897|
# |-12615.521081564191|  3| 392|
# | -27811.52926732089|  3| 540|
# |-32448.877202418345|  3|1507|
# | -21584.32250887183|  3|1522|
# | -4625.075736637552|  1|1483|
# | 2409.6108830694016|  1| 623|
# | -7443.718465129451|  2|1084|
# +-------------------+---+----+
# only showing top 20 rows
#
# SELECT SUM(s) AS s, SUM(c) AS c, holidays.date AS date
# FROM joinboost_tmp_17,holidays
# WHERE joinboost_tmp_17.date IS NOT DISTINCT FROM holidays.date
# GROUP BY holidays.date
#
# 0.007169008255004883
# +-------------------+---+----+
# |                  s|  c|date|
# +-------------------+---+----+
# | -23409.29430286877|  2|1645|
# | -7474.955067115277|  2| 833|
# |  -31386.3739130673|  7|1591|
# |-15788.207469590277|  4|1342|
# |-17864.112100458435|  2|1238|
# |-31168.521905055397|  3|1580|
# | -8636.717551164973|  3| 496|
# | 1399.9060898181287|  2| 471|
# |-7286.6041241039975|  3|1460|
# |-1732.5760753738632|  1| 858|
# |  -7241.68883162167|  4|1025|
# | -33828.83576785647|  4|1395|
# |-19603.412616121117|  2| 897|
# |-12615.521081564191|  3| 392|
# | -27811.52926732089|  3| 540|
# |-32448.877202418345|  3|1507|
# | -21584.32250887183|  3|1522|
# | -4625.075736637552|  1|1483|
# | 2409.6108830694016|  1| 623|
# | -7443.718465129451|  2|1084|
# +-------------------+---+----+
# only showing top 20 rows
#
# SELECT transactions.tid AS tid
# FROM joinboost_tmp_11,joinboost_tmp_2,transactions
# WHERE transactions.f5 <= 553 AND joinboost_tmp_11.store_nbr IS NOT DISTINCT FROM transactions.store_nbr AND joinboost_tmp_2.tid IS NOT DISTINCT FROM transactions.tid
# GROUP BY transactions.tid
#
# 0.008579492568969727
# +-----+
# |  tid|
# +-----+
# |32539|
# |46465|
# |40011|
# |37111|
# | 1580|
# |66176|
# | 8389|
# |82582|
# |79641|
# |46778|
# |58486|
# |48206|
# |56203|
# |46448|
# |78185|
# |81284|
# |41175|
# |47497|
# |68078|
# |53168|
# +-----+
# only showing top 20 rows
#
# SELECT SUM(s) AS s, SUM(c) AS c, joinboost_tmp_0.item_nbr AS item_nbr
# FROM joinboost_tmp_19,joinboost_tmp_0
# WHERE joinboost_tmp_19.tid IS NOT DISTINCT FROM joinboost_tmp_0.tid
# GROUP BY joinboost_tmp_0.item_nbr
#
# 0.005606651306152344
# +-------------------+---+--------+
# |                  s|  c|item_nbr|
# +-------------------+---+--------+
# |-2523.9350228107196|  1|     148|
# |-3842.4741370696493|  1|    2142|
# |-16571.212451005184|  2|     471|
# |  -3982.77144377889|  1|    1591|
# |-12851.378923608201|  1|     463|
# | 2540.3161527900907|  1|    2659|
# |-13903.023418589346|  2|     496|
# | 2084.7686805128587|  1|     833|
# | -6953.031007789631|  1|    1645|
# | -2515.973519282561|  1|    2866|
# |-3778.5422158933607|  1|    1342|
# | -7729.100248516917|  2|    1088|
# | -3415.399713834943|  1|    3179|
# |-27576.096606168612|  3|     392|
# |-3811.1230600452045|  1|    2580|
# | 2327.0585173177583|  3|    1483|
# |-11735.677323923115|  1|     897|
# | -17397.06803258234|  2|    1990|
# | -7346.156090404198|  2|     623|
# | -16877.50828413697|  2|    1507|
# +-------------------+---+--------+
# only showing top 20 rows
#
# SELECT SUM(s) AS s, SUM(c) AS c, transactions.store_nbr AS store_nbr
# FROM joinboost_tmp_11,joinboost_tmp_2,transactions
# WHERE transactions.f5 > 553 AND joinboost_tmp_11.store_nbr IS NOT DISTINCT FROM transactions.store_nbr AND joinboost_tmp_2.tid IS NOT DISTINCT FROM transactions.tid
# GROUP BY transactions.store_nbr
#
# 0.01159048080444336
# +-------------------+---+---------+
# |                  s|  c|store_nbr|
# +-------------------+---+---------+
# | 178569.21138696556| 57|       31|
# |-102205.56732061891| 53|       53|
# |-32089.966619111638| 54|       28|
# | 47707.233764892786| 93|       26|
# | 156991.62227271523| 83|       27|
# | 103712.85056305882| 69|       22|
# | 206531.27968178695|136|       47|
# | -142611.5800730284| 71|       13|
# | -142289.9183317401|112|        6|
# | 127458.96407140733| 89|       16|
# |-1507.5313476265892| 92|        3|
# |-170262.48329606466| 99|       48|
# | 16641.335087182528| 46|       41|
# |   99797.7423923673| 78|       15|
# | -71510.31256557148| 79|        9|
# | -137624.0843640641| 76|       35|
# | 262244.14146770834| 92|        4|
# |-147728.63065043866| 83|        8|
# |-35595.293470471544| 74|       10|
# |  198216.0523752356|102|       50|
# +-------------------+---+---------+
# only showing top 20 rows
#
# SELECT SUM(s) AS s, SUM(c) AS c, transactions.date AS date
# FROM joinboost_tmp_11,joinboost_tmp_2,transactions
# WHERE transactions.f5 > 553 AND joinboost_tmp_11.store_nbr IS NOT DISTINCT FROM transactions.store_nbr AND joinboost_tmp_2.tid IS NOT DISTINCT FROM transactions.tid
# GROUP BY transactions.date
#
# 0.009527921676635742
# +-------------------+---+----+
# |                  s|  c|date|
# +-------------------+---+----+
# | -8734.149506011436|  3|1580|
# |  5298.968622176841|  1| 471|
# |-10510.586760185502|  4|1238|
# |  9348.412307214126|  2| 833|
# | -102.3144433702937|  1|1088|
# | -14267.29829200139|  4|1645|
# | -4729.152633420389|  2|1342|
# | -15886.34818949889|  2| 897|
# | 14254.205925796967|  5|1483|
# |  1505.521958953179|  7|1084|
# |  6399.966061381081|  1| 243|
# |   9068.55353940171|  2| 623|
# | 3353.2344790830584|  4|1127|
# |  2803.610867087654|  1| 858|
# |  8175.283671972893|  2|1460|
# | -5464.748740369257|  1|1395|
# | -563.8877384488196|  1| 737|
# | -6162.961673033103|  2|1522|
# |  1595.627480831592|  2|1618|
# | 10835.767606551186|  2|1139|
# +-------------------+---+----+
# only showing top 20 rows
#
# SELECT SUM(s) AS s, SUM(c) AS c, holidays.date AS date
# FROM joinboost_tmp_22,holidays
# WHERE joinboost_tmp_22.date IS NOT DISTINCT FROM holidays.date
# GROUP BY holidays.date
#
# 0.009198427200317383
# +-------------------+---+----+
# |                  s|  c|date|
# +-------------------+---+----+
# | -8734.149506011436|  3|1580|
# |  5298.968622176841|  1| 471|
# |-10510.586760185502|  4|1238|
# |  9348.412307214126|  2| 833|
# | -102.3144433702937|  1|1088|
# | -14267.29829200139|  4|1645|
# | -4729.152633420389|  2|1342|
# | -15886.34818949889|  2| 897|
# | 14254.205925796967|  5|1483|
# |  1505.521958953179|  7|1084|
# |  6399.966061381081|  1| 243|
# |   9068.55353940171|  2| 623|
# | 3353.2344790830584|  4|1127|
# |  2803.610867087654|  1| 858|
# |  8175.283671972893|  2|1460|
# | -5464.748740369257|  1|1395|
# | -563.8877384488196|  1| 737|
# | -6162.961673033103|  2|1522|
# |  1595.627480831592|  2|1618|
# | 10835.767606551186|  2|1139|
# +-------------------+---+----+
# only showing top 20 rows
#
# SELECT transactions.tid AS tid
# FROM joinboost_tmp_11,joinboost_tmp_2,transactions
# WHERE transactions.f5 > 553 AND joinboost_tmp_11.store_nbr IS NOT DISTINCT FROM transactions.store_nbr AND joinboost_tmp_2.tid IS NOT DISTINCT FROM transactions.tid
# GROUP BY transactions.tid
#
# 0.015232324600219727
# +-----+
# |  tid|
# +-----+
# |81900|
# |75120|
# |74852|
# |26425|
# |63271|
# |12046|
# |74904|
# |77234|
# |70476|
# |62526|
# |58707|
# |45622|
# |66277|
# | 1270|
# |56617|
# |37657|
# |75102|
# |50340|
# |17077|
# |65353|
# +-----+
# only showing top 20 rows
#
# SELECT SUM(s) AS s, SUM(c) AS c, joinboost_tmp_0.item_nbr AS item_nbr
# FROM joinboost_tmp_24,joinboost_tmp_0
# WHERE joinboost_tmp_24.tid IS NOT DISTINCT FROM joinboost_tmp_0.tid
# GROUP BY joinboost_tmp_0.item_nbr
#
# 0.007985353469848633
# +-------------------+---+--------+
# |                  s|  c|item_nbr|
# +-------------------+---+--------+
# |  8180.972989594185|  3|     463|
# | -102.3144433702937|  1|    1829|
# |   3812.20308713511|  1|    1580|
# | -732.1904396621576|  1|     471|
# | 2478.3953426740836|  1|    3175|
# |-2127.2774817364643|  1|    1088|
# | -7192.629214109124|  1|    2122|
# |-1272.4711224427065|  1|    2142|
# | 1214.6206410946588|  1|    1507|
# |  2167.326165316411|  1|    2999|
# | 1393.9426070102027|  1|     623|
# |-3088.3997306650344|  2|    1395|
# | -675.7890461112565|  2|    1483|
# |-1996.8699746742996|  1|    1990|
# | -4980.082249905131|  1|    2387|
# |  8835.784920201204|  1|    1139|
# |-1008.8475077961057|  1|      31|
# |-147.07727001014837|  2|    1143|
# |  2238.211152016178|  1|     516|
# | 3706.4001915329136|  1|    1303|
# +-------------------+---+--------+
# only showing top 20 rows
#
# SELECT htype AS htype, CASE WHEN 3024 > c THEN ((s/c)*s + (-14482903.751278546-s)/(3024-c)*(-14482903.751278546-s)) ELSE 0 END AS criteria, s AS s, c AS c
# FROM (SELECT SUM(s) OVER joinboost_window  AS s, SUM(c) OVER joinboost_window  AS c, htype AS htype
# FROM (SELECT SUM(s) AS s, SUM(c) AS c, holidays.htype AS htype
# FROM joinboost_tmp_17,holidays
# WHERE joinboost_tmp_17.date IS NOT DISTINCT FROM holidays.date
# GROUP BY holidays.htype
# )
# WINDOW joinboost_window AS (ORDER BY htype)
# )
# ORDER BY criteria DESC
# LIMIT 1
#
# 0.043576955795288086
# +-----+--------------------+-------------------+---+
# |htype|            criteria|                  s|  c|
# +-----+--------------------+-------------------+---+
# |    3|6.939536751232593E10|-2119272.8371206378|420|
# +-----+--------------------+-------------------+---+
#
# SELECT locale AS locale, CASE WHEN 3024 > c THEN ((s/c)*s + (-14482903.751278546-s)/(3024-c)*(-14482903.751278546-s)) ELSE 0 END AS criteria, s AS s, c AS c
# FROM (SELECT SUM(s) OVER joinboost_window  AS s, SUM(c) OVER joinboost_window  AS c, locale AS locale
# FROM (SELECT SUM(s) AS s, SUM(c) AS c, holidays.locale AS locale
# FROM joinboost_tmp_17,holidays
# WHERE joinboost_tmp_17.date IS NOT DISTINCT FROM holidays.date
# GROUP BY holidays.locale
# )
# WINDOW joinboost_window AS (ORDER BY locale)
# )
# ORDER BY criteria DESC
# LIMIT 1
#
# 0.024300813674926758
# +------+--------------------+------------------+---+
# |locale|            criteria|                 s|  c|
# +------+--------------------+------------------+---+
# |     1|6.942295508757892E10|-2168319.171766952|422|
# +------+--------------------+------------------+---+
#
# SELECT locale_name AS locale_name, CASE WHEN 3024 > c THEN ((s/c)*s + (-14482903.751278546-s)/(3024-c)*(-14482903.751278546-s)) ELSE 0 END AS criteria, s AS s, c AS c
# FROM (SELECT SUM(s) OVER joinboost_window  AS s, SUM(c) OVER joinboost_window  AS c, locale_name AS locale_name
# FROM (SELECT SUM(s) AS s, SUM(c) AS c, holidays.locale_name AS locale_name
# FROM joinboost_tmp_17,holidays
# WHERE joinboost_tmp_17.date IS NOT DISTINCT FROM holidays.date
# GROUP BY holidays.locale_name
# )
# WINDOW joinboost_window AS (ORDER BY locale_name)
# )
# ORDER BY criteria DESC
# LIMIT 1
#
# 0.016053199768066406
# +-----------+--------------------+-------------------+---+
# |locale_name|            criteria|                  s|  c|
# +-----------+--------------------+-------------------+---+
# |          7|6.940890846260867E10|-1651815.7920755292|321|
# +-----------+--------------------+-------------------+---+
#
# SELECT transferred AS transferred, CASE WHEN 3024 > c THEN ((s/c)*s + (-14482903.751278546-s)/(3024-c)*(-14482903.751278546-s)) ELSE 0 END AS criteria, s AS s, c AS c
# FROM (SELECT SUM(s) OVER joinboost_window  AS s, SUM(c) OVER joinboost_window  AS c, transferred AS transferred
# FROM (SELECT SUM(s) AS s, SUM(c) AS c, holidays.transferred AS transferred
# FROM joinboost_tmp_17,holidays
# WHERE joinboost_tmp_17.date IS NOT DISTINCT FROM holidays.date
# GROUP BY holidays.transferred
# )
# WINDOW joinboost_window AS (ORDER BY transferred)
# )
# ORDER BY criteria DESC
# LIMIT 1
#
# 0.01650714874267578
# +-----------+--------------------+-------------------+---+
# |transferred|            criteria|                  s|  c|
# +-----------+--------------------+-------------------+---+
# |          0|6.941709466370178E10|-2190469.5226754835|428|
# +-----------+--------------------+-------------------+---+
#
# SELECT f2 AS f2, CASE WHEN 3024 > c THEN ((s/c)*s + (-14482903.751278546-s)/(3024-c)*(-14482903.751278546-s)) ELSE 0 END AS criteria, s AS s, c AS c
# FROM (SELECT SUM(s) OVER joinboost_window  AS s, SUM(c) OVER joinboost_window  AS c, f2 AS f2
# FROM (SELECT SUM(s) AS s, SUM(c) AS c, holidays.f2 AS f2
# FROM joinboost_tmp_17,holidays
# WHERE joinboost_tmp_17.date IS NOT DISTINCT FROM holidays.date
# GROUP BY holidays.f2
# )
# WINDOW joinboost_window AS (ORDER BY f2)
# )
# ORDER BY criteria DESC
# LIMIT 1
#
# 0.013907909393310547
# +---+--------------------+-----------------+---+
# | f2|            criteria|                s|  c|
# +---+--------------------+-----------------+---+
# |103|6.943428046353015E10|-1610283.84823045|307|
# +---+--------------------+-----------------+---+
#
# SELECT dcoilwtico AS dcoilwtico, CASE WHEN 3024 > c THEN ((s/c)*s + (-14482903.751278546-s)/(3024-c)*(-14482903.751278546-s)) ELSE 0 END AS criteria, s AS s, c AS c
# FROM (SELECT SUM(s) OVER joinboost_window  AS s, SUM(c) OVER joinboost_window  AS c, dcoilwtico AS dcoilwtico
# FROM (SELECT SUM(s) AS s, SUM(c) AS c, oil.dcoilwtico AS dcoilwtico
# FROM joinboost_tmp_18,oil
# WHERE joinboost_tmp_18.date IS NOT DISTINCT FROM oil.date
# GROUP BY oil.dcoilwtico
# )
# WINDOW joinboost_window AS (ORDER BY dcoilwtico)
# )
# ORDER BY criteria DESC
# LIMIT 1
#
# 0.01971578598022461
# +----------+-------------------+------------------+----+
# |dcoilwtico|           criteria|                 s|   c|
# +----------+-------------------+------------------+----+
# |         4|6.93836114880495E10|-9114690.570670264|1878|
# +----------+-------------------+------------------+----+
#
# SELECT f3 AS f3, CASE WHEN 3024 > c THEN ((s/c)*s + (-14482903.751278546-s)/(3024-c)*(-14482903.751278546-s)) ELSE 0 END AS criteria, s AS s, c AS c
# FROM (SELECT SUM(s) OVER joinboost_window  AS s, SUM(c) OVER joinboost_window  AS c, f3 AS f3
# FROM (SELECT SUM(s) AS s, SUM(c) AS c, oil.f3 AS f3
# FROM joinboost_tmp_18,oil
# WHERE joinboost_tmp_18.date IS NOT DISTINCT FROM oil.date
# GROUP BY oil.f3
# )
# WINDOW joinboost_window AS (ORDER BY f3)
# )
# ORDER BY criteria DESC
# LIMIT 1
#
# 0.03081965446472168
# +---+--------------------+-------------------+----+
# | f3|            criteria|                  s|   c|
# +---+--------------------+-------------------+----+
# |475|8.694436986029121E10|-3476491.2161172307|1487|
# +---+--------------------+-------------------+----+
#
# SELECT transactions AS transactions, CASE WHEN 3024 > c THEN ((s/c)*s + (-14482903.751278546-s)/(3024-c)*(-14482903.751278546-s)) ELSE 0 END AS criteria, s AS s, c AS c
# FROM (SELECT SUM(s) OVER joinboost_window  AS s, SUM(c) OVER joinboost_window  AS c, transactions AS transactions
# FROM (SELECT SUM(s) AS s, SUM(c) AS c, transactions.transactions AS transactions
# FROM joinboost_tmp_11,joinboost_tmp_2,transactions
# WHERE transactions.f5 <= 553 AND joinboost_tmp_11.store_nbr IS NOT DISTINCT FROM transactions.store_nbr AND joinboost_tmp_2.tid IS NOT DISTINCT FROM transactions.tid
# GROUP BY transactions.transactions
# )
# WINDOW joinboost_window AS (ORDER BY transactions)
# )
# ORDER BY criteria DESC
# LIMIT 1
#
# 0.01627182960510254
# +------------+--------------------+--------------------+----+
# |transactions|            criteria|                   s|   c|
# +------------+--------------------+--------------------+----+
# |           4|6.956710953612265E10|-1.33871646054240...|2748|
# +------------+--------------------+--------------------+----+
#
# SELECT f5 AS f5, CASE WHEN 3024 > c THEN ((s/c)*s + (-14482903.751278546-s)/(3024-c)*(-14482903.751278546-s)) ELSE 0 END AS criteria, s AS s, c AS c
# FROM (SELECT SUM(s) OVER joinboost_window  AS s, SUM(c) OVER joinboost_window  AS c, f5 AS f5
# FROM (SELECT SUM(s) AS s, SUM(c) AS c, transactions.f5 AS f5
# FROM joinboost_tmp_11,joinboost_tmp_2,transactions
# WHERE transactions.f5 <= 553 AND joinboost_tmp_11.store_nbr IS NOT DISTINCT FROM transactions.store_nbr AND joinboost_tmp_2.tid IS NOT DISTINCT FROM transactions.tid
# GROUP BY transactions.f5
# )
# WINDOW joinboost_window AS (ORDER BY f5)
# )
# ORDER BY criteria DESC
# LIMIT 1
#
# 0.02221059799194336
# ...
# GROUP BY transactions.tid
#
# 0.021401405334472656
# +-----+
# |  tid|
# +-----+
# |71527|
# |26623|
# |51415|
# |83242|
# |76493|
# |72820|
# |39153|
# |54844|
# |37482|
# | 4219|
# |78766|
# |21715|
# |29177|
# |32680|
# |27471|
# |34713|
# | 1143|
# |40824|
# |74681|
# | 5482|
# +-----+
# only showing top 20 rows
#
# SELECT SUM(s) AS s, SUM(c) AS c, joinboost_tmp_0.item_nbr AS item_nbr
# FROM joinboost_tmp_69,joinboost_tmp_0
# WHERE joinboost_tmp_69.tid IS NOT DISTINCT FROM joinboost_tmp_0.tid
# GROUP BY joinboost_tmp_0.item_nbr
#
# 0.02706599235534668
# +------------------+---+--------+
# |                 s|  c|item_nbr|
# +------------------+---+--------+
# |20747.757175426228|  3|    1342|
# |11742.529169851063|  1|    1580|
# | 8646.497991665441|  1|     471|
# |3846.7943016538175|  1|    2366|
# | 9330.335517209609|  1|    1088|
# | 10298.34527693781|  1|    1959|
# | 5735.436658681468|  1|    2142|
# | 4032.921723047165|  1|    2563|
# |6406.3563445097825|  1|    1127|
# | 7426.921684394134|  1|    2580|
# | 6012.521252336554|  1|    2811|
# | 6737.194976574487|  1|    1483|
# | 7400.007388419062|  1|    3179|
# | 6669.357815524145|  1|    1084|
# | 6476.417037180405|  1|    1395|
# |  7547.36167277216|  1|    2999|
# | 7532.753618196456|  1|     897|
# | 9261.084952036348|  1|     858|
# | 10665.89206672429|  1|    1352|
# |11671.880615020886|  1|    3213|
# +------------------+---+--------+
# only showing top 20 rows
#
# SELECT oil.date AS date
# FROM joinboost_tmp_33,oil
# WHERE oil.f3 > 463 AND joinboost_tmp_33.date IS NOT DISTINCT FROM oil.date
# GROUP BY oil.date
#
# 0.005982637405395508
# +----+
# |date|
# +----+
# |1238|
# |1342|
# |1591|
# |1645|
# |1580|
# |1522|
# | 737|
# |1395|
# | 897|
# |1618|
# |1352|
# | 516|
# |1650|
# |1303|
# |1143|
# | 580|
# | 251|
# |1265|
# |  85|
# | 883|
# +----+
# only showing top 20 rows
#
# SELECT holidays.date AS date
# FROM joinboost_tmp_32,joinboost_tmp_71,holidays
# WHERE joinboost_tmp_32.date IS NOT DISTINCT FROM holidays.date AND joinboost_tmp_71.date IS NOT DISTINCT FROM holidays.date
# GROUP BY holidays.date
#
# 0.03502035140991211
# +----+
# |date|
# +----+
# |1238|
# |1342|
# |1591|
# |1645|
# |1580|
# |1522|
# | 737|
# |1395|
# | 897|
# |1618|
# |1352|
# | 516|
# |1650|
# |1303|
# |1143|
# | 580|
# | 251|
# |1265|
# |  85|
# | 883|
# +----+
# only showing top 20 rows
#
# SELECT SUM(s) AS s, SUM(c) AS c, transactions.store_nbr AS store_nbr
# FROM joinboost_tmp_6,joinboost_tmp_72,joinboost_tmp_2,transactions
# WHERE transactions.f5 > 557 AND joinboost_tmp_6.store_nbr IS NOT DISTINCT FROM transactions.store_nbr AND joinboost_tmp_72.date IS NOT DISTINCT FROM transactions.date AND joinboost_tmp_2.tid IS NOT DISTINCT FROM transactions.tid
# GROUP BY transactions.store_nbr
#
# 0.020293712615966797
# +------------------+---+---------+
# |                 s|  c|store_nbr|
# +------------------+---+---------+
# |154064.29298413408| 34|       34|
# |138888.11220278754| 56|       44|
# | 63572.63088313048| 23|       12|
# |309734.76089321234| 63|        1|
# | 91598.99110653611| 32|       52|
# |59758.849129701375| 16|       20|
# |  33857.8697361437| 34|       40|
# |326819.11902402935| 58|        5|
# |104390.76764953176| 35|       19|
# | 56954.70527941084| 53|       43|
# |213452.51075387315| 45|       37|
# |  86921.0490566635| 40|       17|
# |179672.97017848256| 46|       23|
# |219651.39270827788| 47|       39|
# | 44442.73432518329| 55|       49|
# |17903.545067054805| 48|        7|
# |16812.455299263922|  3|       51|
# | 140026.7345993204| 54|       45|
# |129961.47121097961| 48|       38|
# | 81110.96156972795| 45|       24|
# +------------------+---+---------+
# only showing top 20 rows
#
# SELECT transactions.tid AS tid
# FROM joinboost_tmp_6,joinboost_tmp_72,joinboost_tmp_2,transactions
# WHERE transactions.f5 > 557 AND joinboost_tmp_6.store_nbr IS NOT DISTINCT FROM transactions.store_nbr AND joinboost_tmp_72.date IS NOT DISTINCT FROM transactions.date AND joinboost_tmp_2.tid IS NOT DISTINCT FROM transactions.tid
# GROUP BY transactions.tid
#
# 0.01828932762145996
# +-----+
# |  tid|
# +-----+
# |28024|
# |31035|
# |58665|
# |45341|
# |22990|
# |36106|
# |32891|
# |56687|
# |14536|
# |57955|
# |51914|
# |70844|
# |41496|
# |42613|
# |34435|
# |67231|
# |77488|
# |27709|
# |82963|
# |27030|
# +-----+
# only showing top 20 rows
#
# SELECT SUM(s) AS s, SUM(c) AS c, joinboost_tmp_0.item_nbr AS item_nbr
# FROM joinboost_tmp_74,joinboost_tmp_0
# WHERE joinboost_tmp_74.tid IS NOT DISTINCT FROM joinboost_tmp_0.tid
# GROUP BY joinboost_tmp_0.item_nbr
#
# 0.011841535568237305
# +-------------------+---+--------+
# |                  s|  c|item_nbr|
# +-------------------+---+--------+
# | 10198.730828894259|  2|    1591|
# |  4518.002900191929|  1|    1645|
# | 3590.3237563044513|  1|     471|
# |  6782.554001088626|  1|    1580|
# |  4761.581730504651|  2|    1025|
# |  8671.757245718974|  3|    1127|
# | 5029.0810967269545|  1|    1507|
# | 1607.0161794639967|  1|    1721|
# | 1185.0356762981282|  1|     540|
# |  5037.007218156194|  1|    1483|
# | -459.2399089616647|  1|     858|
# |  203.8224658606341|  1|     243|
# |  842.3836092531947|  1|    2563|
# |    3547.9236936881|  1|    2999|
# |  3156.100049630937|  1|    1650|
# |  428.6200305071943|  1|    1903|
# |  6491.213026874381|  1|    1303|
# |-1831.5664827901583|  1|    2393|
# |  4031.689770634289|  1|    1975|
# | -748.4909183860373|  1|    1265|
# +-------------------+---+--------+
# only showing top 20 rows
#
# DROP TABLE IF EXISTS joinboost_tmp_5;
#
# 0.005249738693237305
# ++
# ||
# ++
# ++
#
# DROP TABLE IF EXISTS joinboost_tmp_3;
#
# 0.0052683353424072266
# ++
# ||
# ++
# ++
#
# DROP TABLE IF EXISTS joinboost_tmp_4;
#
# 0.004753828048706055
# ++
# ||
# ++
# ++
#
# DROP TABLE IF EXISTS joinboost_tmp_1;
#
# 0.004097700119018555
# ++
# ||
# ++
# ++
#
# DROP TABLE IF EXISTS joinboost_tmp_2;
#
# 0.003888845443725586
# ++
# ||
# ++
# ++
#
# DROP TABLE IF EXISTS joinboost_tmp_8;
#
# 0.004849672317504883
# ++
# ||
# ++
# ++
#
# DROP TABLE IF EXISTS joinboost_tmp_3;
#
# 0.004212141036987305
# ++
# ||
# ++
# ++
#
# DROP TABLE IF EXISTS joinboost_tmp_7;
#
# 0.0028290748596191406
# ++
# ||
# ++
# ++
#
# DROP TABLE IF EXISTS joinboost_tmp_9;
#
# 0.0032181739807128906
# ++
# ||
# ++
# ++
#
# DROP TABLE IF EXISTS joinboost_tmp_6;
#
# 0.0030126571655273438
# ++
# ||
# ++
# ++
#
# DROP TABLE IF EXISTS joinboost_tmp_10;
#
# 0.002774953842163086
# ++
# ||
# ++
# ++
#
# DROP TABLE IF EXISTS joinboost_tmp_2;
#
# 0.0028214454650878906
# ++
# ||
# ++
# ++
#
# DROP TABLE IF EXISTS joinboost_tmp_13;
#
# 0.0023212432861328125
# ++
# ||
# ++
# ++
#
# DROP TABLE IF EXISTS joinboost_tmp_3;
#
# 0.0026750564575195312
# ++
# ||
# ++
# ++
#
# DROP TABLE IF EXISTS joinboost_tmp_12;
#
# 0.0072138309478759766
# ++
# ||
# ++
# ++
#
# DROP TABLE IF EXISTS joinboost_tmp_14;
#
# 0.006334781646728516
# ++
# ||
# ++
# ++
#
# DROP TABLE IF EXISTS joinboost_tmp_11;
#
# 0.0068361759185791016
# ++
# ||
# ++
# ++
#
# DROP TABLE IF EXISTS joinboost_tmp_15;
#
# 0.005250692367553711
# ++
# ||
# ++
# ++
#
# DROP TABLE IF EXISTS joinboost_tmp_2;
#
# 0.006152629852294922
# ++
# ||
# ++
# ++
#
# DROP TABLE IF EXISTS joinboost_tmp_18;
#
# 0.0038487911224365234
# ++
# ||
# ++
# ++
#
# DROP TABLE IF EXISTS joinboost_tmp_16;
#
# 0.0029566287994384766
# ++
# ||
# ++
# ++
#
# DROP TABLE IF EXISTS joinboost_tmp_17;
#
# 0.0029747486114501953
# ++
# ||
# ++
# ++
#
# DROP TABLE IF EXISTS joinboost_tmp_19;
#
# 0.003282785415649414
# ++
# ||
# ++
# ++
#
# DROP TABLE IF EXISTS joinboost_tmp_11;
#
# 0.0032362937927246094
# ++
# ||
# ++
# ++
#
# DROP TABLE IF EXISTS joinboost_tmp_20;
#
# 0.00394749641418457
# ++
# ||
# ++
# ++
#
# DROP TABLE IF EXISTS joinboost_tmp_2;
#
# 0.004395008087158203
# ++
# ||
# ++
# ++
#
# DROP TABLE IF EXISTS joinboost_tmp_23;
#
# 0.003991127014160156
# ++
# ||
# ++
# ++
#
# DROP TABLE IF EXISTS joinboost_tmp_21;
#
# 0.004564046859741211
# ++
# ||
# ++
# ++
#
# DROP TABLE IF EXISTS joinboost_tmp_22;
#
# 0.005007028579711914
# ++
# ||
# ++
# ++
#
# DROP TABLE IF EXISTS joinboost_tmp_24;
#
# 0.004049777984619141
# ++
# ||
# ++
# ++
#
# DROP TABLE IF EXISTS joinboost_tmp_11;
#
# 0.003996610641479492
# ++
# ||
# ++
# ++
#
# DROP TABLE IF EXISTS joinboost_tmp_25;
#
# 0.0043354034423828125
# ++
# ||
# ++
# ++
#
# DROP TABLE IF EXISTS joinboost_tmp_2;
#
# 0.006154060363769531
# ++
# ||
# ++
# ++
#
# DROP TABLE IF EXISTS joinboost_tmp_28;
#
# 0.004439592361450195
# ++
# ||
# ++
# ++
#
# DROP TABLE IF EXISTS joinboost_tmp_26;
#
# 0.00394439697265625
# ++
# ||
# ++
# ++
#
# DROP TABLE IF EXISTS joinboost_tmp_27;
#
# 0.005288362503051758
# ++
# ||
# ++
# ++
#
# DROP TABLE IF EXISTS joinboost_tmp_29;
#
# 0.004652738571166992
# ++
# ||
# ++
# ++
#
# DROP TABLE IF EXISTS joinboost_tmp_6;
#
# 0.004952192306518555
# ++
# ||
# ++
# ++
#
# DROP TABLE IF EXISTS joinboost_tmp_30;
#
# 0.003941059112548828
# ++
# ||
# ++
# ++
#
# DROP TABLE IF EXISTS joinboost_tmp_2;
#
# 0.003956794738769531
# ++
# ||
# ++
# ++
#
# DROP TABLE IF EXISTS joinboost_tmp_33;
#
# 0.003376483917236328
# ++
# ||
# ++
# ++
#
# DROP TABLE IF EXISTS joinboost_tmp_31;
#
# 0.007037162780761719
# ++
# ||
# ++
# ++
#
# DROP TABLE IF EXISTS joinboost_tmp_32;
#
# 0.004388093948364258
# ++
# ||
# ++
# ++
#
# DROP TABLE IF EXISTS joinboost_tmp_34;
#
# 0.005255937576293945
# ++
# ||
# ++
# ++
#
# DROP TABLE IF EXISTS joinboost_tmp_6;
#
# 0.00559544563293457
# ++
# ||
# ++
# ++
#
# DROP TABLE IF EXISTS joinboost_tmp_35;
#
# 0.004772663116455078
# ++
# ||
# ++
# ++
#
# DROP TABLE IF EXISTS joinboost_tmp_2;
#
# 0.003443002700805664
# ++
# ||
# ++
# ++
#
# DROP TABLE IF EXISTS joinboost_tmp_37;
#
# 0.005036115646362305
# ++
# ||
# ++
# ++
#
# DROP TABLE IF EXISTS joinboost_tmp_18;
#
# 0.004716634750366211
# ++
# ||
# ++
# ++
#
# DROP TABLE IF EXISTS joinboost_tmp_36;
#
# 0.004240751266479492
# ++
# ||
# ++
# ++
#
# DROP TABLE IF EXISTS joinboost_tmp_38;
#
# 0.004764556884765625
# ++
# ||
# ++
# ++
#
# DROP TABLE IF EXISTS joinboost_tmp_17;
#
# 0.004030704498291016
# ++
# ||
# ++
# ++
#
# DROP TABLE IF EXISTS joinboost_tmp_39;
#
# 0.004137992858886719
# ++
# ||
# ++
# ++
#
# DROP TABLE IF EXISTS joinboost_tmp_11;
#
# 0.0055408477783203125
# ++
# ||
# ++
# ++
#
# DROP TABLE IF EXISTS joinboost_tmp_40;
#
# 0.005158424377441406
# ++
# ||
# ++
# ++
#
# DROP TABLE IF EXISTS joinboost_tmp_2;
#
# 0.005984306335449219
# ++
# ||
# ++
# ++
#
# DROP TABLE IF EXISTS joinboost_tmp_42;
#
# 0.00681614875793457
# ++
# ||
# ++
# ++
#
# DROP TABLE IF EXISTS joinboost_tmp_18;
#
# 0.003816843032836914
# ++
# ||
# ++
# ++
#
# DROP TABLE IF EXISTS joinboost_tmp_41;
#
# 0.003874063491821289
# ++
# ||
# ++
# ++
#
# DROP TABLE IF EXISTS joinboost_tmp_43;
#
# 0.004500865936279297
# ++
# ||
# ++
# ++
#
# DROP TABLE IF EXISTS joinboost_tmp_17;
#
# 0.004815578460693359
# ++
# ||
# ++
# ++
#
# DROP TABLE IF EXISTS joinboost_tmp_44;
#
# 0.008414030075073242
# ++
# ||
# ++
# ++
#
# DROP TABLE IF EXISTS joinboost_tmp_11;
#
# 0.009064435958862305
# ++
# ||
# ++
# ++
#
# DROP TABLE IF EXISTS joinboost_tmp_45;
#
# 0.006718873977661133
# ++
# ||
# ++
# ++
#
# DROP TABLE IF EXISTS joinboost_tmp_2;
#
# 0.008698225021362305
# ++
# ||
# ++
# ++
#
# DROP TABLE IF EXISTS joinboost_tmp_47;
#
# 0.004948139190673828
# ++
# ||
# ++
# ++
#
# DROP TABLE IF EXISTS joinboost_tmp_28;
#
# 0.010307073593139648
# ++
# ||
# ++
# ++
#
# DROP TABLE IF EXISTS joinboost_tmp_46;
#
# 0.005114316940307617
# ++
# ||
# ++
# ++
#
# DROP TABLE IF EXISTS joinboost_tmp_48;
#
# 0.005011796951293945
# ++
# ||
# ++
# ++
#
# DROP TABLE IF EXISTS joinboost_tmp_27;
#
# 0.005035400390625
# ++
# ||
# ++
# ++
#
# DROP TABLE IF EXISTS joinboost_tmp_49;
#
# 0.0050754547119140625
# ++
# ||
# ++
# ++
#
# DROP TABLE IF EXISTS joinboost_tmp_6;
#
# 0.005662441253662109
# ++
# ||
# ++
# ++
#
# DROP TABLE IF EXISTS joinboost_tmp_50;
#
# 0.007956266403198242
# ++
# ||
# ++
# ++
#
# DROP TABLE IF EXISTS joinboost_tmp_2;
#
# 0.005143404006958008
# ++
# ||
# ++
# ++
#
# DROP TABLE IF EXISTS joinboost_tmp_52;
#
# 0.005988121032714844
# ++
# ||
# ++
# ++
#
# DROP TABLE IF EXISTS joinboost_tmp_28;
#
# 0.005728006362915039
# ++
# ||
# ++
# ++
#
# DROP TABLE IF EXISTS joinboost_tmp_51;
#
# 0.004973173141479492
# ++
# ||
# ++
# ++
#
# DROP TABLE IF EXISTS joinboost_tmp_53;
#
# 0.0052492618560791016
# ++
# ||
# ++
# ++
#
# DROP TABLE IF EXISTS joinboost_tmp_27;
#
# 0.0027043819427490234
# ++
# ||
# ++
# ++
#
# DROP TABLE IF EXISTS joinboost_tmp_54;
#
# 0.003271818161010742
# ++
# ||
# ++
# ++
#
# DROP TABLE IF EXISTS joinboost_tmp_6;
#
# 0.002348661422729492
# ++
# ||
# ++
# ++
#
# DROP TABLE IF EXISTS joinboost_tmp_55;
#
# 0.0030608177185058594
# ++
# ||
# ++
# ++
#
# DROP TABLE IF EXISTS joinboost_tmp_2;
#
# 0.0029604434967041016
# ++
# ||
# ++
# ++
#
# DROP TABLE IF EXISTS joinboost_tmp_57;
#
# 0.006278038024902344
# ++
# ||
# ++
# ++
#
# DROP TABLE IF EXISTS joinboost_tmp_23;
#
# 0.005583047866821289
# ++
# ||
# ++
# ++
#
# DROP TABLE IF EXISTS joinboost_tmp_56;
#
# 0.0034096240997314453
# ++
# ||
# ++
# ++
#
# DROP TABLE IF EXISTS joinboost_tmp_58;
#
# 0.003648042678833008
# ++
# ||
# ++
# ++
#
# DROP TABLE IF EXISTS joinboost_tmp_22;
#
# 0.004505634307861328
# ++
# ||
# ++
# ++
#
# DROP TABLE IF EXISTS joinboost_tmp_59;
#
# 0.004101753234863281
# ++
# ||
# ++
# ++
#
# DROP TABLE IF EXISTS joinboost_tmp_11;
#
# 0.0037767887115478516
# ++
# ||
# ++
# ++
#
# DROP TABLE IF EXISTS joinboost_tmp_60;
#
# 0.005517482757568359
# ++
# ||
# ++
# ++
#
# DROP TABLE IF EXISTS joinboost_tmp_2;
#
# 0.00582432746887207
# ++
# ||
# ++
# ++
#
# DROP TABLE IF EXISTS joinboost_tmp_62;
#
# 0.005025625228881836
# ++
# ||
# ++
# ++
#
# DROP TABLE IF EXISTS joinboost_tmp_23;
#
# 0.005636692047119141
# ++
# ||
# ++
# ++
#
# DROP TABLE IF EXISTS joinboost_tmp_61;
#
# 0.007127285003662109
# ++
# ||
# ++
# ++
#
# DROP TABLE IF EXISTS joinboost_tmp_63;
#
# 0.0037529468536376953
# ++
# ||
# ++
# ++
#
# DROP TABLE IF EXISTS joinboost_tmp_22;
#
# 0.004255771636962891
# ++
# ||
# ++
# ++
#
# DROP TABLE IF EXISTS joinboost_tmp_64;
#
# 0.004505634307861328
# ++
# ||
# ++
# ++
#
# DROP TABLE IF EXISTS joinboost_tmp_11;
#
# 0.004634380340576172
# ++
# ||
# ++
# ++
#
# DROP TABLE IF EXISTS joinboost_tmp_65;
#
# 0.005011796951293945
# ++
# ||
# ++
# ++
#
# DROP TABLE IF EXISTS joinboost_tmp_2;
#
# 0.00536346435546875
# ++
# ||
# ++
# ++
#
# DROP TABLE IF EXISTS joinboost_tmp_67;
#
# 0.004624128341674805
# ++
# ||
# ++
# ++
#
# DROP TABLE IF EXISTS joinboost_tmp_33;
#
# 0.007181406021118164
# ++
# ||
# ++
# ++
#
# DROP TABLE IF EXISTS joinboost_tmp_66;
#
# 0.003896951675415039
# ++
# ||
# ++
# ++
#
# DROP TABLE IF EXISTS joinboost_tmp_68;
#
# 0.002424955368041992
# ++
# ||
# ++
# ++
#
# DROP TABLE IF EXISTS joinboost_tmp_32;
#
# 0.003927946090698242
# ++
# ||
# ++
# ++
#
# DROP TABLE IF EXISTS joinboost_tmp_69;
#
# 0.0028777122497558594
# ++
# ||
# ++
# ++
#
# DROP TABLE IF EXISTS joinboost_tmp_6;
#
# 0.0040209293365478516
# ++
# ||
# ++
# ++
#
# DROP TABLE IF EXISTS joinboost_tmp_70;
#
# 0.003631114959716797
# ++
# ||
# ++
# ++
#
# DROP TABLE IF EXISTS joinboost_tmp_2;
#
# 0.004147768020629883
# ++
# ||
# ++
# ++
#
# DROP TABLE IF EXISTS joinboost_tmp_72;
#
# 0.004300117492675781
# ++
# ||
# ++
# ++
#
# DROP TABLE IF EXISTS joinboost_tmp_33;
#
# 0.004639387130737305
# ++
# ||
# ++
# ++
#
# DROP TABLE IF EXISTS joinboost_tmp_71;
#
# 0.0059053897857666016
# ++
# ||
# ++
# ++
#
# DROP TABLE IF EXISTS joinboost_tmp_73;
#
# 0.00397038459777832
# ++
# ||
# ++
# ++
#
# DROP TABLE IF EXISTS joinboost_tmp_32;
#
# 0.006765604019165039
# ++
# ||
# ++
# ++
#
# DROP TABLE IF EXISTS joinboost_tmp_74;
#
# 0.005516767501831055
# ++
# ||
# ++
# ++
#
# DROP TABLE IF EXISTS joinboost_tmp_6;
#
# 0.0059049129486083984
# ++
# ||
# ++
# ++
#
# DROP TABLE IF EXISTS joinboost_tmp_75;
#
# 0.005692958831787109
# ++
# ||
# ++
# ++
#
# DROP TABLE IF EXISTS joinboost_tmp_2;
#
# 0.005329608917236328
# ++
# ||
# ++
# ++
#
# SELECT Y, -4842.635841853514+
# CASE
#  WHEN f4 > 496 AND f5 <= 553 AND f3 <= 475 THEN CAST(-2337.9228084177744 AS DOUBLE)
#  WHEN f4 > 496 AND f5 <= 553 AND f3 > 475 THEN CAST(-7160.971070371707 AS DOUBLE)
#  WHEN f4 <= 496 AND f5 <= 557 AND f3 > 475 THEN CAST(-2060.9581497628296 AS DOUBLE)
#  WHEN f4 > 496 AND f5 > 553 AND f3 > 450 THEN CAST(-1953.1974409598827 AS DOUBLE)
#  WHEN f4 <= 496 AND f5 <= 557 AND f3 <= 475 THEN CAST(3039.5826387332836 AS DOUBLE)
#  WHEN f4 > 496 AND f5 > 553 AND f3 <= 450 THEN CAST(3077.032261442609 AS DOUBLE)
#  WHEN f4 <= 496 AND f5 > 557 AND f3 <= 463 THEN CAST(8135.210187401265 AS DOUBLE)
#  WHEN f4 <= 496 AND f5 > 557 AND f3 > 463 THEN CAST(3187.945806284532 AS DOUBLE)
# ELSE 0 END
# AS prediction FROM train
# 0.009264945983886719
# +-------------------+-------------------+
# |                  Y|         prediction|
# +-------------------+-------------------+
# | -5739.103112581849| -7180.558650271289|
# |  872.3485190238571|-1765.6035804109047|
# | -7674.674962408274| -6903.593991616343|
# | 2542.1098731280003| 3292.5743455477514|
# | -5824.012509244241| -7180.558650271289|
# |  -4057.32567323008|-1654.6900355689818|
# | -10236.57424820753| -7180.558650271289|
# |-3072.8988510905165|-1654.6900355689818|
# | -6936.222332066423| -7180.558650271289|
# |-10618.292559605285| -6795.833282813396|
# | -6594.577738456323| -6903.593991616343|
# |  2198.946664006416| 3292.5743455477514|
# |-12060.540783571269|-12003.606912225221|
# |-3216.3131218782064|-1803.0532031202301|
# | -9832.813998390822| -6903.593991616343|
# |-1637.8139852829518|-1765.6035804109047|
# | -6886.859180597294| -7180.558650271289|
# | -2801.045551561624|-1654.6900355689818|
# | -5929.772913869145| -6903.593991616343|
# | -9897.532995634308| -6795.833282813396|
# +-------------------+-------------------+
# only showing top 20 rows
#
# SELECT *
# FROM (SELECT SQRT(AVG(POW(Y - prediction, 2))) AS RMSE
# FROM joinboost_tmp_76
# )
#
# 0.007688760757446289
# +-----------------+
# |             RMSE|
# +-----------------+
# |2535.060839158587|
# +-----------------+
#
# Training RMSE: 2535.060839158587

# %% [markdown]
# # Install JoinBoost and databases package.
# In this demo, we use duckdb as the database.

# %%
# %pip install joinboost==0.0.14
# %pip install duckdb
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting joinboost==0.0.14
#   Downloading joinboost-0.0.14-py3-none-any.whl (18 kB)
# Installing collected packages: joinboost
#   Attempting uninstall: joinboost
#     Found existing installation: joinboost 0.0.13
#     Uninstalling joinboost-0.0.13:
#       Successfully uninstalled joinboost-0.0.13
# Successfully installed joinboost-0.0.14
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: duckdb in /usr/local/lib/python3.7/dist-packages (0.5.1)
# Requirement already satisfied: numpy>=1.14 in /usr/local/lib/python3.7/dist-packages (from duckdb) (1.21.6)

# %% [markdown]
# # Download data and load data into database.
#
# This step is only necessary for this demo as we don't have existing databases. JoinBoost to directly build models over your databases without data downloading/loading.

# %%
import duckdb
import urllib.request
from joinboost.executor import DuckdbExecutor
from joinboost.joingraph import JoinGraph
from joinboost.app import DecisionTree,GradientBoosting

urllib.request.urlretrieve("https://www.dropbox.com/s/kaovdndtevcvt83/holidays.csv?dl=1", "holidays.csv")
urllib.request.urlretrieve("https://www.dropbox.com/s/wh6amz4um7ieyqz/items.csv?dl=1", "items.csv")
urllib.request.urlretrieve("https://www.dropbox.com/s/ze6of1xqwslt8jb/oil.csv?dl=1", "oil.csv")
urllib.request.urlretrieve("https://www.dropbox.com/s/uiojfrc5c20gyrl/sales_small.csv?dl=1", "sales_small.csv")
urllib.request.urlretrieve("https://www.dropbox.com/s/cwy6z0b7rhsnrxb/stores.csv?dl=1", "stores.csv")
urllib.request.urlretrieve("https://www.dropbox.com/s/wwaoga17z70jb6l/train_small.csv?dl=1", "train_small.csv")
urllib.request.urlretrieve("https://www.dropbox.com/s/2bxto9wnetwnvqd/transactions.csv?dl=1", "transactions.csv")

con = duckdb.connect(database=':memory:')
con.execute("CREATE OR REPLACE TABLE holidays AS SELECT * FROM 'holidays.csv';")
con.execute("CREATE OR REPLACE TABLE oil AS SELECT * FROM 'oil.csv';")
con.execute("CREATE OR REPLACE TABLE transactions AS SELECT * FROM 'transactions.csv';")
con.execute("CREATE OR REPLACE TABLE stores AS SELECT * FROM 'stores.csv';")
con.execute("CREATE OR REPLACE TABLE items AS SELECT * FROM 'items.csv';")
con.execute("CREATE OR REPLACE TABLE sales AS SELECT * FROM 'sales_small.csv';")
con.execute("CREATE OR REPLACE TABLE train AS SELECT * FROM 'train_small.csv';")

# %% [markdown]
# # Data exploration and Data Transformation
# You can use the database SQL queries to show all available tables and their schema. You can perform data transformations over these tables.

# %%
con.execute("describe;").df()
# Out:
#      table_name                                       column_names  \
# 0      holidays  [date, f2, htype, locale, locale_name, transfe...
# 1         items          [class, f1, family, item_nbr, perishable]
# 2           oil                             [date, dcoilwtico, f3]
# 3         sales        [Y, item_nbr, onpromotion, tid, unit_sales]
# 4        stores       [city, cluster, f4, state, store_nbr, stype]
# 5         train  [Y, city, class, cluster, date, dcoilwtico, f1...
# 6  transactions           [date, f5, store_nbr, tid, transactions]
#
#                                         column_types  temporary
# 0  [INTEGER, INTEGER, INTEGER, INTEGER, INTEGER, ...      False
# 1      [INTEGER, INTEGER, INTEGER, INTEGER, INTEGER]      False
# 2                        [INTEGER, INTEGER, INTEGER]      False
# 3        [DOUBLE, INTEGER, INTEGER, INTEGER, DOUBLE]      False
# 4  [INTEGER, INTEGER, INTEGER, INTEGER, INTEGER, ...      False
# 5  [DOUBLE, INTEGER, INTEGER, INTEGER, INTEGER, I...      False
# 6      [INTEGER, INTEGER, INTEGER, INTEGER, INTEGER]      False

# %% [markdown]
# # Train Decision Tree using JoinBoost
# First, we need to specify the join graph: what are the relations and features you want to use. How these relations are supposed to be join.
#
# For instance,
# ```
# dataset.add_join("sales", "items", ["item_nbr"], ["item_nbr"])
# ```
# says the join condition is: sales.item_nbr = items.item_nbr

# %%
exe = DuckdbExecutor(con, debug=False)
dataset = JoinGraph(exe=exe)
dataset.add_relation("sales", [], y = 'Y')
dataset.add_relation("holidays", ["htype", "locale", "locale_name", "transferred","f2"])
dataset.add_relation("oil", ["dcoilwtico","f3"])
dataset.add_relation("transactions", ["transactions","f5"])
dataset.add_relation("stores", ["city","state","stype","cluster","f4"])
dataset.add_relation("items", ["family","class","perishable","f1"])
dataset.add_join("sales", "items", ["item_nbr"], ["item_nbr"])
dataset.add_join("sales", "transactions", ["tid"], ["tid"])
dataset.add_join("transactions", "stores", ["store_nbr"], ["store_nbr"])
dataset.add_join("transactions", "holidays", ["date"], ["date"])
dataset.add_join("holidays", "oil", ["date"], ["date"])

depth = 3
reg = DecisionTree(learning_rate=1, max_leaves=2 ** depth, max_depth=depth)

reg.fit(dataset)
reg.compute_rmse('train')[0]
# Out:
# 2535.0608391585865

# %% [markdown]
# # Train Gradient Boosting using JoinBoost
# Next, we train Gradient Boosting of 10 iterations.
#
# As shown, Gradient Boosting further reduces the rmse.

# %%
reg = GradientBoosting(learning_rate=1, max_leaves=2 ** depth, max_depth=depth, iteration = 10)
reg.fit(dataset)
reg.compute_rmse('train')[0]
# Out:
# 786.8773440907675

# %% [markdown]
# # JoinBoost Internals
# Internally, JoinBoost translates ML logics into SQL, and execute SQL queries directly in your databases without data movement.
#
# To see these SQL queries, we can enable the debug mode
#
#
# ```
# exe = DuckdbExecutor(con, debug=True)
# ```
#
# such that are SQL queries executed are printed out.

# %%
exe = DuckdbExecutor(con, debug=True)
dataset = JoinGraph(exe=exe)
dataset.add_relation("sales", [], y = 'Y')
dataset.add_relation("holidays", ["htype", "locale", "locale_name", "transferred","f2"])
dataset.add_relation("oil", ["dcoilwtico","f3"])
dataset.add_relation("transactions", ["transactions","f5"])
dataset.add_relation("stores", ["city","state","stype","cluster","f4"])
dataset.add_relation("items", ["family","class","perishable","f1"])
dataset.add_join("sales", "items", ["item_nbr"], ["item_nbr"])
dataset.add_join("sales", "transactions", ["tid"], ["tid"])
dataset.add_join("transactions", "stores", ["store_nbr"], ["store_nbr"])
dataset.add_join("transactions", "holidays", ["date"], ["date"])
dataset.add_join("holidays", "oil", ["date"], ["date"])

depth = 3
reg = DecisionTree(learning_rate=1, max_leaves=2 ** depth, max_depth=depth)

reg.fit(dataset)
reg.compute_rmse('train')[0]
# Out:
# PRAGMA table_info(sales)
# 0.0023736953735351562
# PRAGMA table_info(holidays)
# 0.0009341239929199219
# PRAGMA table_info(oil)
# 0.0002970695495605469
# PRAGMA table_info(transactions)
# 0.00022339820861816406
# PRAGMA table_info(stores)
# 0.0001742839813232422
# PRAGMA table_info(items)
# 0.00014972686767578125
# SELECT SUM(Y) AS s, SUM(1) AS c
# FROM sales
#
# 0.00036025047302246094
# CREATE OR REPLACE TABLE joinboost_tmp_0 AS SELECT Y- (-4842.635841853514) AS s, 1 AS c, item_nbr AS item_nbr, tid AS tid
# FROM sales
#
# 0.0015192031860351562
# CREATE OR REPLACE TABLE joinboost_tmp_1 AS SELECT SUM(s) AS s, SUM(c) AS c, joinboost_tmp_0.item_nbr AS item_nbr
# FROM joinboost_tmp_0
# GROUP BY joinboost_tmp_0.item_nbr
#
# 0.0026786327362060547
# CREATE OR REPLACE TABLE joinboost_tmp_2 AS SELECT SUM(s) AS s, SUM(c) AS c, joinboost_tmp_0.tid AS tid
# FROM joinboost_tmp_0
# GROUP BY joinboost_tmp_0.tid
#
# 0.00576019287109375
# CREATE OR REPLACE TABLE joinboost_tmp_3 AS SELECT SUM(s) AS s, SUM(c) AS c, transactions.store_nbr AS store_nbr
# FROM joinboost_tmp_2,transactions
# WHERE joinboost_tmp_2.tid IS NOT DISTINCT FROM transactions.tid
# GROUP BY transactions.store_nbr
#
# 0.006470918655395508
# CREATE OR REPLACE TABLE joinboost_tmp_4 AS SELECT SUM(s) AS s, SUM(c) AS c, transactions.date AS date
# FROM joinboost_tmp_2,transactions
# WHERE joinboost_tmp_2.tid IS NOT DISTINCT FROM transactions.tid
# GROUP BY transactions.date
#
# 0.007377147674560547
# CREATE OR REPLACE TABLE joinboost_tmp_5 AS SELECT SUM(s) AS s, SUM(c) AS c, holidays.date AS date
# FROM joinboost_tmp_4,holidays
# WHERE joinboost_tmp_4.date IS NOT DISTINCT FROM holidays.date
# GROUP BY holidays.date
#
# 0.001680135726928711
# SELECT *
# FROM (SELECT htype AS htype, CASE WHEN 10000 > c THEN (-(CAST(0 AS DOUBLE)/10000)* 0 + (s/c)*s + (0-s)/(10000-c)*(0-s)) ELSE 0 END AS criteria, c AS c, s AS s
# FROM (SELECT SUM(s) OVER joinboost_window  AS s, SUM(c) OVER joinboost_window  AS c, htype AS htype
# FROM (SELECT SUM(s) AS s, SUM(c) AS c, holidays.htype AS htype
# FROM joinboost_tmp_4,holidays
# WHERE joinboost_tmp_4.date IS NOT DISTINCT FROM holidays.date
# GROUP BY holidays.htype
# )
# WINDOW joinboost_window AS (ORDER BY htype)
# )
# ORDER BY criteria DESC
# LIMIT 1
# )
#
# 0.0021278858184814453
# SELECT *
# FROM (SELECT locale AS locale, CASE WHEN 10000 > c THEN (-(CAST(0 AS DOUBLE)/10000)* 0 + (s/c)*s + (0-s)/(10000-c)*(0-s)) ELSE 0 END AS criteria, c AS c, s AS s
# FROM (SELECT SUM(s) OVER joinboost_window  AS s, SUM(c) OVER joinboost_window  AS c, locale AS locale
# FROM (SELECT SUM(s) AS s, SUM(c) AS c, holidays.locale AS locale
# FROM joinboost_tmp_4,holidays
# WHERE joinboost_tmp_4.date IS NOT DISTINCT FROM holidays.date
# GROUP BY holidays.locale
# )
# WINDOW joinboost_window AS (ORDER BY locale)
# )
# ORDER BY criteria DESC
# LIMIT 1
# )
#
# 0.0023300647735595703
# SELECT *
# FROM (SELECT locale_name AS locale_name, CASE WHEN 10000 > c THEN (-(CAST(0 AS DOUBLE)/10000)* 0 + (s/c)*s + (0-s)/(10000-c)*(0-s)) ELSE 0 END AS criteria, c AS c, s AS s
# FROM (SELECT SUM(s) OVER joinboost_window  AS s, SUM(c) OVER joinboost_window  AS c, locale_name AS locale_name
# FROM (SELECT SUM(s) AS s, SUM(c) AS c, holidays.locale_name AS locale_name
# FROM joinboost_tmp_4,holidays
# WHERE joinboost_tmp_4.date IS NOT DISTINCT FROM holidays.date
# GROUP BY holidays.locale_name
# )
# WINDOW joinboost_window AS (ORDER BY locale_name)
# )
# ORDER BY criteria DESC
# LIMIT 1
# )
#
# 0.003187417984008789
# SELECT *
# FROM (SELECT transferred AS transferred, CASE WHEN 10000 > c THEN (-(CAST(0 AS DOUBLE)/10000)* 0 + (s/c)*s + (0-s)/(10000-c)*(0-s)) ELSE 0 END AS criteria, c AS c, s AS s
# FROM (SELECT SUM(s) OVER joinboost_window  AS s, SUM(c) OVER joinboost_window  AS c, transferred AS transferred
# FROM (SELECT SUM(s) AS s, SUM(c) AS c, holidays.transferred AS transferred
# FROM joinboost_tmp_4,holidays
# WHERE joinboost_tmp_4.date IS NOT DISTINCT FROM holidays.date
# GROUP BY holidays.transferred
# )
# WINDOW joinboost_window AS (ORDER BY transferred)
# )
# ORDER BY criteria DESC
# LIMIT 1
# )
#
# 0.0027844905853271484
# SELECT *
# FROM (SELECT f2 AS f2, CASE WHEN 10000 > c THEN (-(CAST(0 AS DOUBLE)/10000)* 0 + (s/c)*s + (0-s)/(10000-c)*(0-s)) ELSE 0 END AS criteria, c AS c, s AS s
# FROM (SELECT SUM(s) OVER joinboost_window  AS s, SUM(c) OVER joinboost_window  AS c, f2 AS f2
# FROM (SELECT SUM(s) AS s, SUM(c) AS c, holidays.f2 AS f2
# FROM joinboost_tmp_4,holidays
# WHERE joinboost_tmp_4.date IS NOT DISTINCT FROM holidays.date
# GROUP BY holidays.f2
# )
# WINDOW joinboost_window AS (ORDER BY f2)
# )
# ORDER BY criteria DESC
# LIMIT 1
# )
#
# 0.0031223297119140625
# SELECT *
# FROM (SELECT dcoilwtico AS dcoilwtico, CASE WHEN 10000 > c THEN (-(CAST(0 AS DOUBLE)/10000)* 0 + (s/c)*s + (0-s)/(10000-c)*(0-s)) ELSE 0 END AS criteria, c AS c, s AS s
# FROM (SELECT SUM(s) OVER joinboost_window  AS s, SUM(c) OVER joinboost_window  AS c, dcoilwtico AS dcoilwtico
# FROM (SELECT SUM(s) AS s, SUM(c) AS c, oil.dcoilwtico AS dcoilwtico
# FROM joinboost_tmp_5,oil
# WHERE joinboost_tmp_5.date IS NOT DISTINCT FROM oil.date
# GROUP BY oil.dcoilwtico
# )
# WINDOW joinboost_window AS (ORDER BY dcoilwtico)
# )
# ORDER BY criteria DESC
# LIMIT 1
# )
#
# 0.0021162033081054688
# SELECT *
# FROM (SELECT f3 AS f3, CASE WHEN 10000 > c THEN (-(CAST(0 AS DOUBLE)/10000)* 0 + (s/c)*s + (0-s)/(10000-c)*(0-s)) ELSE 0 END AS criteria, c AS c, s AS s
# FROM (SELECT SUM(s) OVER joinboost_window  AS s, SUM(c) OVER joinboost_window  AS c, f3 AS f3
# FROM (SELECT SUM(s) AS s, SUM(c) AS c, oil.f3 AS f3
# FROM joinboost_tmp_5,oil
# WHERE joinboost_tmp_5.date IS NOT DISTINCT FROM oil.date
# GROUP BY oil.f3
# )
# WINDOW joinboost_window AS (ORDER BY f3)
# )
# ORDER BY criteria DESC
# LIMIT 1
# )
#
# 0.0037882328033447266
# SELECT *
# FROM (SELECT transactions AS transactions, CASE WHEN 10000 > c THEN (-(CAST(0 AS DOUBLE)/10000)* 0 + (s/c)*s + (0-s)/(10000-c)*(0-s)) ELSE 0 END AS criteria, c AS c, s AS s
# FROM (SELECT SUM(s) OVER joinboost_window  AS s, SUM(c) OVER joinboost_window  AS c, transactions AS transactions
# FROM (SELECT SUM(s) AS s, SUM(c) AS c, transactions.transactions AS transactions
# FROM joinboost_tmp_2,transactions
# WHERE joinboost_tmp_2.tid IS NOT DISTINCT FROM transactions.tid
# GROUP BY transactions.transactions
# )
# WINDOW joinboost_window AS (ORDER BY transactions)
# )
# ORDER BY criteria DESC
# LIMIT 1
# )
#
# 0.004526376724243164
# SELECT *
# FROM (SELECT f5 AS f5, CASE WHEN 10000 > c THEN (-(CAST(0 AS DOUBLE)/10000)* 0 + (s/c)*s + (0-s)/(10000-c)*(0-s)) ELSE 0 END AS criteria, c AS c, s AS s
# FROM (SELECT SUM(s) OVER joinboost_window  AS s, SUM(c) OVER joinboost_window  AS c, f5 AS f5
# FROM (SELECT SUM(s) AS s, SUM(c) AS c, transactions.f5 AS f5
# FROM joinboost_tmp_2,transactions
# WHERE joinboost_tmp_2.tid IS NOT DISTINCT FROM transactions.tid
# GROUP BY transactions.f5
# )
# WINDOW joinboost_window AS (ORDER BY f5)
# )
# ORDER BY criteria DESC
# LIMIT 1
# )
#
# 0.0059604644775390625
# SELECT *
# FROM (SELECT city AS city, CASE WHEN 10000 > c THEN (-(CAST(0 AS DOUBLE)/10000)* 0 + (s/c)*s + (0-s)/(10000-c)*(0-s)) ELSE 0 END AS criteria, c AS c, s AS s
# FROM (SELECT SUM(s) OVER joinboost_window  AS s, SUM(c) OVER joinboost_window  AS c, city AS city
# FROM (SELECT SUM(s) AS s, SUM(c) AS c, stores.city AS city
# FROM joinboost_tmp_3,stores
# WHERE joinboost_tmp_3.store_nbr IS NOT DISTINCT FROM stores.store_nbr
# GROUP BY stores.city
# )
# WINDOW joinboost_window AS (ORDER BY city)
# )
# ORDER BY criteria DESC
# LIMIT 1
# )
#
# 0.0020852088928222656
# SELECT *
# FROM (SELECT state AS state, CASE WHEN 10000 > c THEN (-(CAST(0 AS DOUBLE)/10000)* 0 + (s/c)*s + (0-s)/(10000-c)*(0-s)) ELSE 0 END AS criteria, c AS c, s AS s
# FROM (SELECT SUM(s) OVER joinboost_window  AS s, SUM(c) OVER joinboost_window  AS c, state AS state
# FROM (SELECT SUM(s) AS s, SUM(c) AS c, stores.state AS state
# FROM joinboost_tmp_3,stores
# WHERE joinboost_tmp_3.store_nbr IS NOT DISTINCT FROM stores.store_nbr
# GROUP BY stores.state
# )
# WINDOW joinboost_window AS (ORDER BY state)
# )
# ORDER BY criteria DESC
# LIMIT 1
# )
#
# 0.0018892288208007812
# SELECT *
# FROM (SELECT stype AS stype, CASE WHEN 10000 > c THEN (-(CAST(0 AS DOUBLE)/10000)* 0 + (s/c)*s + (0-s)/(10000-c)*(0-s)) ELSE 0 END AS criteria, c AS c, s AS s
# FROM (SELECT SUM(s) OVER joinboost_window  AS s, SUM(c) OVER joinboost_window  AS c, stype AS stype
# FROM (SELECT SUM(s) AS s, SUM(c) AS c, stores.stype AS stype
# FROM joinboost_tmp_3,stores
# WHERE joinboost_tmp_3.store_nbr IS NOT DISTINCT FROM stores.store_nbr
# GROUP BY stores.stype
# )
# WINDOW joinboost_window AS (ORDER BY stype)
# )
# ORDER BY criteria DESC
# LIMIT 1
# )
#
# 0.0018396377563476562
# SELECT *
# FROM (SELECT cluster AS cluster, CASE WHEN 10000 > c THEN (-(CAST(0 AS DOUBLE)/10000)* 0 + (s/c)*s + (0-s)/(10000-c)*(0-s)) ELSE 0 END AS criteria, c AS c, s AS s
# FROM (SELECT SUM(s) OVER joinboost_window  AS s, SUM(c) OVER joinboost_window  AS c, cluster AS cluster
# FROM (SELECT SUM(s) AS s, SUM(c) AS c, stores.cluster AS cluster
# FROM joinboost_tmp_3,stores
# WHERE joinboost_tmp_3.store_nbr IS NOT DISTINCT FROM stores.store_nbr
# GROUP BY stores.cluster
# )
# WINDOW joinboost_window AS (ORDER BY cluster)
# )
# ORDER BY criteria DESC
# LIMIT 1
# )
#
# 0.0018768310546875
# SELECT *
# FROM (SELECT f4 AS f4, CASE WHEN 10000 > c THEN (-(CAST(0 AS DOUBLE)/10000)* 0 + (s/c)*s + (0-s)/(10000-c)*(0-s)) ELSE 0 END AS criteria, c AS c, s AS s
# FROM (SELECT SUM(s) OVER joinboost_window  AS s, SUM(c) OVER joinboost_window  AS c, f4 AS f4
# FROM (SELECT SUM(s) AS s, SUM(c) AS c, stores.f4 AS f4
# FROM joinboost_tmp_3,stores
# WHERE joinboost_tmp_3.store_nbr IS NOT DISTINCT FROM stores.store_nbr
# GROUP BY stores.f4
# )
# WINDOW joinboost_window AS (ORDER BY f4)
# )
# ORDER BY criteria DESC
# LIMIT 1
# )
#
# 0.0018470287322998047
# SELECT *
# FROM (SELECT family AS family, CASE WHEN 10000 > c THEN (-(CAST(0 AS DOUBLE)/10000)* 0 + (s/c)*s + (0-s)/(10000-c)*(0-s)) ELSE 0 END AS criteria, c AS c, s AS s
# FROM (SELECT SUM(s) OVER joinboost_window  AS s, SUM(c) OVER joinboost_window  AS c, family AS family
# FROM (SELECT SUM(s) AS s, SUM(c) AS c, items.family AS family
# FROM joinboost_tmp_1,items
# WHERE joinboost_tmp_1.item_nbr IS NOT DISTINCT FROM items.item_nbr
# GROUP BY items.family
# )
# WINDOW joinboost_window AS (ORDER BY family)
# )
# ORDER BY criteria DESC
# LIMIT 1
# )
#
# 0.0022416114807128906
# SELECT *
# FROM (SELECT class AS class, CASE WHEN 10000 > c THEN (-(CAST(0 AS DOUBLE)/10000)* 0 + (s/c)*s + (0-s)/(10000-c)*(0-s)) ELSE 0 END AS criteria, c AS c, s AS s
# FROM (SELECT SUM(s) OVER joinboost_window  AS s, SUM(c) OVER joinboost_window  AS c, class AS class
# FROM (SELECT SUM(s) AS s, SUM(c) AS c, items.class AS class
# FROM joinboost_tmp_1,items
# WHERE joinboost_tmp_1.item_nbr IS NOT DISTINCT FROM items.item_nbr
# GROUP BY items.class
# )
# WINDOW joinboost_window AS (ORDER BY class)
# )
# ORDER BY criteria DESC
# LIMIT 1
# )
#
# 0.002523183822631836
# SELECT *
# FROM (SELECT perishable AS perishable, CASE WHEN 10000 > c THEN (-(CAST(0 AS DOUBLE)/10000)* 0 + (s/c)*s + (0-s)/(10000-c)*(0-s)) ELSE 0 END AS criteria, c AS c, s AS s
# FROM (SELECT SUM(s) OVER joinboost_window  AS s, SUM(c) OVER joinboost_window  AS c, perishable AS perishable
# FROM (SELECT SUM(s) AS s, SUM(c) AS c, items.perishable AS perishable
# FROM joinboost_tmp_1,items
# WHERE joinboost_tmp_1.item_nbr IS NOT DISTINCT FROM items.item_nbr
# GROUP BY items.perishable
# )
# WINDOW joinboost_window AS (ORDER BY perishable)
# )
# ORDER BY criteria DESC
# LIMIT 1
# )
#
# 0.0021576881408691406
# SELECT *
# FROM (SELECT f1 AS f1, CASE WHEN 10000 > c THEN (-(CAST(0 AS DOUBLE)/10000)* 0 + (s/c)*s + (0-s)/(10000-c)*(0-s)) ELSE 0 END AS criteria, c AS c, s AS s
# FROM (SELECT SUM(s) OVER joinboost_window  AS s, SUM(c) OVER joinboost_window  AS c, f1 AS f1
# FROM (SELECT SUM(s) AS s, SUM(c) AS c, items.f1 AS f1
# FROM joinboost_tmp_1,items
# WHERE joinboost_tmp_1.item_nbr IS NOT DISTINCT FROM items.item_nbr
# GROUP BY items.f1
# )
# WINDOW joinboost_window AS (ORDER BY f1)
# )
# ORDER BY criteria DESC
# LIMIT 1
# )
#
# 0.003574848175048828
# CREATE OR REPLACE TABLE joinboost_tmp_6 AS SELECT stores.store_nbr AS store_nbr
# FROM stores
# WHERE stores.f4 <= 496
# GROUP BY stores.store_nbr
#
# 0.001127004623413086
# CREATE OR REPLACE TABLE joinboost_tmp_7 AS SELECT SUM(s) AS s, SUM(c) AS c, transactions.date AS date
# FROM joinboost_tmp_6,joinboost_tmp_2,transactions
# WHERE joinboost_tmp_6.store_nbr IS NOT DISTINCT FROM transactions.store_nbr AND joinboost_tmp_2.tid IS NOT DISTINCT FROM transactions.tid
# GROUP BY transactions.date
#
# 0.0046539306640625
# CREATE OR REPLACE TABLE joinboost_tmp_8 AS SELECT SUM(s) AS s, SUM(c) AS c, holidays.date AS date
# FROM joinboost_tmp_7,holidays
# WHERE joinboost_tmp_7.date IS NOT DISTINCT FROM holidays.date
# GROUP BY holidays.date
#
# 0.001667022705078125
# CREATE OR REPLACE TABLE joinboost_tmp_9 AS SELECT transactions.tid AS tid
# FROM joinboost_tmp_6,transactions
# WHERE joinboost_tmp_6.store_nbr IS NOT DISTINCT FROM transactions.store_nbr
# GROUP BY transactions.tid
#
# 0.009765863418579102
# CREATE OR REPLACE TABLE joinboost_tmp_10 AS SELECT SUM(s) AS s, SUM(c) AS c, joinboost_tmp_0.item_nbr AS item_nbr
# FROM joinboost_tmp_9,joinboost_tmp_0
# WHERE joinboost_tmp_9.tid IS NOT DISTINCT FROM joinboost_tmp_0.tid
# GROUP BY joinboost_tmp_0.item_nbr
#
# 0.0039064884185791016
# CREATE OR REPLACE TABLE joinboost_tmp_11 AS SELECT stores.store_nbr AS store_nbr
# FROM stores
# WHERE stores.f4 > 496
# GROUP BY stores.store_nbr
#
# 0.0010635852813720703
# CREATE OR REPLACE TABLE joinboost_tmp_12 AS SELECT SUM(s) AS s, SUM(c) AS c, transactions.date AS date
# FROM joinboost_tmp_11,joinboost_tmp_2,transactions
# WHERE joinboost_tmp_11.store_nbr IS NOT DISTINCT FROM transactions.store_nbr AND joinboost_tmp_2.tid IS NOT DISTINCT FROM transactions.tid
# GROUP BY transactions.date
#
# 0.004610776901245117
# CREATE OR REPLACE TABLE joinboost_tmp_13 AS SELECT SUM(s) AS s, SUM(c) AS c, holidays.date AS date
# FROM joinboost_tmp_12,holidays
# WHERE joinboost_tmp_12.date IS NOT DISTINCT FROM holidays.date
# GROUP BY holidays.date
#
# 0.0019800662994384766
# CREATE OR REPLACE TABLE joinboost_tmp_14 AS SELECT transactions.tid AS tid
# FROM joinboost_tmp_11,transactions
# WHERE joinboost_tmp_11.store_nbr IS NOT DISTINCT FROM transactions.store_nbr
# GROUP BY transactions.tid
#
# 0.013002157211303711
# CREATE OR REPLACE TABLE joinboost_tmp_15 AS SELECT SUM(s) AS s, SUM(c) AS c, joinboost_tmp_0.item_nbr AS item_nbr
# FROM joinboost_tmp_14,joinboost_tmp_0
# WHERE joinboost_tmp_14.tid IS NOT DISTINCT FROM joinboost_tmp_0.tid
# GROUP BY joinboost_tmp_0.item_nbr
#
# 0.003286123275756836
# SELECT *
# FROM (SELECT htype AS htype, CASE WHEN 4626 > c THEN (-(CAST(13439060.470843477 AS DOUBLE)/4626)* 13439060.470843477 + (s/c)*s + (13439060.470843477-s)/(4626-c)*(13439060.470843477-s)) ELSE 0 END AS criteria, c AS c, s AS s
# FROM (SELECT SUM(s) OVER joinboost_window  AS s, SUM(c) OVER joinboost_window  AS c, htype AS htype
# FROM (SELECT SUM(s) AS s, SUM(c) AS c, holidays.htype AS htype
# FROM joinboost_tmp_7,holidays
# WHERE joinboost_tmp_7.date IS NOT DISTINCT FROM holidays.date
# GROUP BY holidays.htype
# )
# WINDOW joinboost_window AS (ORDER BY htype)
# )
# ORDER BY criteria DESC
# LIMIT 1
# )
#
# 0.0021724700927734375
# SELECT *
# FROM (SELECT locale AS locale, CASE WHEN 4626 > c THEN (-(CAST(13439060.470843477 AS DOUBLE)/4626)* 13439060.470843477 + (s/c)*s + (13439060.470843477-s)/(4626-c)*(13439060.470843477-s)) ELSE 0 END AS criteria, c AS c, s AS s
# FROM (SELECT SUM(s) OVER joinboost_window  AS s, SUM(c) OVER joinboost_window  AS c, locale AS locale
# FROM (SELECT SUM(s) AS s, SUM(c) AS c, holidays.locale AS locale
# FROM joinboost_tmp_7,holidays
# WHERE joinboost_tmp_7.date IS NOT DISTINCT FROM holidays.date
# GROUP BY holidays.locale
# )
# WINDOW joinboost_window AS (ORDER BY locale)
# )
# ORDER BY criteria DESC
# LIMIT 1
# )
#
# 0.001989603042602539
# SELECT *
# FROM (SELECT locale_name AS locale_name, CASE WHEN 4626 > c THEN (-(CAST(13439060.470843477 AS DOUBLE)/4626)* 13439060.470843477 + (s/c)*s + (13439060.470843477-s)/(4626-c)*(13439060.470843477-s)) ELSE 0 END AS criteria, c AS c, s AS s
# FROM (SELECT SUM(s) OVER joinboost_window  AS s, SUM(c) OVER joinboost_window  AS c, locale_name AS locale_name
# FROM (SELECT SUM(s) AS s, SUM(c) AS c, holidays.locale_name AS locale_name
# FROM joinboost_tmp_7,holidays
# WHERE joinboost_tmp_7.date IS NOT DISTINCT FROM holidays.date
# GROUP BY holidays.locale_name
# )
# WINDOW joinboost_window AS (ORDER BY locale_name)
# )
# ORDER BY criteria DESC
# LIMIT 1
# )
#
# 0.0019664764404296875
# SELECT *
# FROM (SELECT transferred AS transferred, CASE WHEN 4626 > c THEN (-(CAST(13439060.470843477 AS DOUBLE)/4626)* 13439060.470843477 + (s/c)*s + (13439060.470843477-s)/(4626-c)*(13439060.470843477-s)) ELSE 0 END AS criteria, c AS c, s AS s
# FROM (SELECT SUM(s) OVER joinboost_window  AS s, SUM(c) OVER joinboost_window  AS c, transferred AS transferred
# FROM (SELECT SUM(s) AS s, SUM(c) AS c, holidays.transferred AS transferred
# FROM joinboost_tmp_7,holidays
# WHERE joinboost_tmp_7.date IS NOT DISTINCT FROM holidays.date
# GROUP BY holidays.transferred
# )
# WINDOW joinboost_window AS (ORDER BY transferred)
# )
# ORDER BY criteria DESC
# LIMIT 1
# )
#
# 0.0028297901153564453
# SELECT *
# FROM (SELECT f2 AS f2, CASE WHEN 4626 > c THEN (-(CAST(13439060.470843477 AS DOUBLE)/4626)* 13439060.470843477 + (s/c)*s + (13439060.470843477-s)/(4626-c)*(13439060.470843477-s)) ELSE 0 END AS criteria, c AS c, s AS s
# FROM (SELECT SUM(s) OVER joinboost_window  AS s, SUM(c) OVER joinboost_window  AS c, f2 AS f2
# FROM (SELECT SUM(s) AS s, SUM(c) AS c, holidays.f2 AS f2
# FROM joinboost_tmp_7,holidays
# WHERE joinboost_tmp_7.date IS NOT DISTINCT FROM holidays.date
# GROUP BY holidays.f2
# )
# WINDOW joinboost_window AS (ORDER BY f2)
# )
# ORDER BY criteria DESC
# LIMIT 1
# )
#
# 0.0036368370056152344
# SELECT *
# FROM (SELECT dcoilwtico AS dcoilwtico, CASE WHEN 4626 > c THEN (-(CAST(13439060.470843477 AS DOUBLE)/4626)* 13439060.470843477 + (s/c)*s + (13439060.470843477-s)/(4626-c)*(13439060.470843477-s)) ELSE 0 END AS criteria, c AS c, s AS s
# FROM (SELECT SUM(s) OVER joinboost_window  AS s, SUM(c) OVER joinboost_window  AS c, dcoilwtico AS dcoilwtico
# FROM (SELECT SUM(s) AS s, SUM(c) AS c, oil.dcoilwtico AS dcoilwtico
# FROM joinboost_tmp_8,oil
# WHERE joinboost_tmp_8.date IS NOT DISTINCT FROM oil.date
# GROUP BY oil.dcoilwtico
# )
# WINDOW joinboost_window AS (ORDER BY dcoilwtico)
# )
# ORDER BY criteria DESC
# LIMIT 1
# )
#
# 0.0024225711822509766
# SELECT *
# FROM (SELECT f3 AS f3, CASE WHEN 4626 > c THEN (-(CAST(13439060.470843477 AS DOUBLE)/4626)* 13439060.470843477 + (s/c)*s + (13439060.470843477-s)/(4626-c)*(13439060.470843477-s)) ELSE 0 END AS criteria, c AS c, s AS s
# FROM (SELECT SUM(s) OVER joinboost_window  AS s, SUM(c) OVER joinboost_window  AS c, f3 AS f3
# FROM (SELECT SUM(s) AS s, SUM(c) AS c, oil.f3 AS f3
# FROM joinboost_tmp_8,oil
# WHERE joinboost_tmp_8.date IS NOT DISTINCT FROM oil.date
# GROUP BY oil.f3
# )
# WINDOW joinboost_window AS (ORDER BY f3)
# )
# ORDER BY criteria DESC
# LIMIT 1
# )
#
# 0.004405498504638672
# SELECT *
# FROM (SELECT transactions AS transactions, CASE WHEN 4626 > c THEN (-(CAST(13439060.470843477 AS DOUBLE)/4626)* 13439060.470843477 + (s/c)*s + (13439060.470843477-s)/(4626-c)*(13439060.470843477-s)) ELSE 0 END AS criteria, c AS c, s AS s
# FROM (SELECT SUM(s) OVER joinboost_window  AS s, SUM(c) OVER joinboost_window  AS c, transactions AS transactions
# FROM (SELECT SUM(s) AS s, SUM(c) AS c, transactions.transactions AS transactions
# FROM joinboost_tmp_6,joinboost_tmp_2,transactions
# WHERE joinboost_tmp_6.store_nbr IS NOT DISTINCT FROM transactions.store_nbr AND joinboost_tmp_2.tid IS NOT DISTINCT FROM transactions.tid
# GROUP BY transactions.transactions
# )
# WINDOW joinboost_window AS (ORDER BY transactions)
# )
# ORDER BY criteria DESC
# LIMIT 1
# )
#
# 0.0064351558685302734
# SELECT *
# FROM (SELECT f5 AS f5, CASE WHEN 4626 > c THEN (-(CAST(13439060.470843477 AS DOUBLE)/4626)* 13439060.470843477 + (s/c)*s + (13439060.470843477-s)/(4626-c)*(13439060.470843477-s)) ELSE 0 END AS criteria, c AS c, s AS s
# FROM (SELECT SUM(s) OVER joinboost_window  AS s, SUM(c) OVER joinboost_window  AS c, f5 AS f5
# FROM (SELECT SUM(s) AS s, SUM(c) AS c, transactions.f5 AS f5
# FROM joinboost_tmp_6,joinboost_tmp_2,transactions
# WHERE joinboost_tmp_6.store_nbr IS NOT DISTINCT FROM transactions.store_nbr AND joinboost_tmp_2.tid IS NOT DISTINCT FROM transactions.tid
# GROUP BY transactions.f5
# )
# WINDOW joinboost_window AS (ORDER BY f5)
# )
# ORDER BY criteria DESC
# LIMIT 1
# )
#
# 0.015939712524414062
# SELECT *
# FROM (SELECT city AS city, CASE WHEN 4626 > c THEN (-(CAST(13439060.470843477 AS DOUBLE)/4626)* 13439060.470843477 + (s/c)*s + (13439060.470843477-s)/(4626-c)*(13439060.470843477-s)) ELSE 0 END AS criteria, c AS c, s AS s
# FROM (SELECT SUM(s) OVER joinboost_window  AS s, SUM(c) OVER joinboost_window  AS c, city AS city
# FROM (SELECT SUM(s) AS s, SUM(c) AS c, stores.city AS city
# FROM joinboost_tmp_3,stores
# WHERE joinboost_tmp_3.store_nbr IS NOT DISTINCT FROM stores.store_nbr AND stores.f4 <= 496
# GROUP BY stores.city
# )
# WINDOW joinboost_window AS (ORDER BY city)
# )
# ORDER BY criteria DESC
# LIMIT 1
# )
#
# 0.0022704601287841797
# SELECT *
# FROM (SELECT state AS state, CASE WHEN 4626 > c THEN (-(CAST(13439060.470843477 AS DOUBLE)/4626)* 13439060.470843477 + (s/c)*s + (13439060.470843477-s)/(4626-c)*(13439060.470843477-s)) ELSE 0 END AS criteria, c AS c, s AS s
# FROM (SELECT SUM(s) OVER joinboost_window  AS s, SUM(c) OVER joinboost_window  AS c, state AS state
# FROM (SELECT SUM(s) AS s, SUM(c) AS c, stores.state AS state
# FROM joinboost_tmp_3,stores
# WHERE joinboost_tmp_3.store_nbr IS NOT DISTINCT FROM stores.store_nbr AND stores.f4 <= 496
# GROUP BY stores.state
# )
# WINDOW joinboost_window AS (ORDER BY state)
# )
# ORDER BY criteria DESC
# LIMIT 1
# )
#
# 0.0021212100982666016
# SELECT *
# FROM (SELECT stype AS stype, CASE WHEN 4626 > c THEN (-(CAST(13439060.470843477 AS DOUBLE)/4626)* 13439060.470843477 + (s/c)*s + (13439060.470843477-s)/(4626-c)*(13439060.470843477-s)) ELSE 0 END AS criteria, c AS c, s AS s
# FROM (SELECT SUM(s) OVER joinboost_window  AS s, SUM(c) OVER joinboost_window  AS c, stype AS stype
# FROM (SELECT SUM(s) AS s, SUM(c) AS c, stores.stype AS stype
# FROM joinboost_tmp_3,stores
# WHERE joinboost_tmp_3.store_nbr IS NOT DISTINCT FROM stores.store_nbr AND stores.f4 <= 496
# GROUP BY stores.stype
# )
# WINDOW joinboost_window AS (ORDER BY stype)
# )
# ORDER BY criteria DESC
# LIMIT 1
# )
#
# 0.002285003662109375
# SELECT *
# FROM (SELECT cluster AS cluster, CASE WHEN 4626 > c THEN (-(CAST(13439060.470843477 AS DOUBLE)/4626)* 13439060.470843477 + (s/c)*s + (13439060.470843477-s)/(4626-c)*(13439060.470843477-s)) ELSE 0 END AS criteria, c AS c, s AS s
# FROM (SELECT SUM(s) OVER joinboost_window  AS s, SUM(c) OVER joinboost_window  AS c, cluster AS cluster
# FROM (SELECT SUM(s) AS s, SUM(c) AS c, stores.cluster AS cluster
# FROM joinboost_tmp_3,stores
# WHERE joinboost_tmp_3.store_nbr IS NOT DISTINCT FROM stores.store_nbr AND stores.f4 <= 496
# GROUP BY stores.cluster
# )
# WINDOW joinboost_window AS (ORDER BY cluster)
# )
# ORDER BY criteria DESC
# LIMIT 1
# )
#
# 0.0021975040435791016
# SELECT *
# FROM (SELECT f4 AS f4, CASE WHEN 4626 > c THEN (-(CAST(13439060.470843477 AS DOUBLE)/4626)* 13439060.470843477 + (s/c)*s + (13439060.470843477-s)/(4626-c)*(13439060.470843477-s)) ELSE 0 END AS criteria, c AS c, s AS s
# FROM (SELECT SUM(s) OVER joinboost_window  AS s, SUM(c) OVER joinboost_window  AS c, f4 AS f4
# FROM (SELECT SUM(s) AS s, SUM(c) AS c, stores.f4 AS f4
# FROM joinboost_tmp_3,stores
# WHERE joinboost_tmp_3.store_nbr IS NOT DISTINCT FROM stores.store_nbr AND stores.f4 <= 496
# GROUP BY stores.f4
# )
# WINDOW joinboost_window AS (ORDER BY f4)
# )
# ORDER BY criteria DESC
# LIMIT 1
# )
#
# 0.002259969711303711
# SELECT *
# FROM (SELECT family AS family, CASE WHEN 4626 > c THEN (-(CAST(13439060.470843477 AS DOUBLE)/4626)* 13439060.470843477 + (s/c)*s + (13439060.470843477-s)/(4626-c)*(13439060.470843477-s)) ELSE 0 END AS criteria, c AS c, s AS s
# FROM (SELECT SUM(s) OVER joinboost_window  AS s, SUM(c) OVER joinboost_window  AS c, family AS family
# FROM (SELECT SUM(s) AS s, SUM(c) AS c, items.family AS family
# FROM joinboost_tmp_10,items
# WHERE joinboost_tmp_10.item_nbr IS NOT DISTINCT FROM items.item_nbr
# GROUP BY items.family
# )
# WINDOW joinboost_window AS (ORDER BY family)
# )
# ORDER BY criteria DESC
# LIMIT 1
# )
#
# 0.002435445785522461
# SELECT *
# FROM (SELECT class AS class, CASE WHEN 4626 > c THEN (-(CAST(13439060.470843477 AS DOUBLE)/4626)* 13439060.470843477 + (s/c)*s + (13439060.470843477-s)/(4626-c)*(13439060.470843477-s)) ELSE 0 END AS criteria, c AS c, s AS s
# FROM (SELECT SUM(s) OVER joinboost_window  AS s, SUM(c) OVER joinboost_window  AS c, class AS class
# FROM (SELECT SUM(s) AS s, SUM(c) AS c, items.class AS class
# FROM joinboost_tmp_10,items
# WHERE joinboost_tmp_10.item_nbr IS NOT DISTINCT FROM items.item_nbr
# GROUP BY items.class
# )
# WINDOW joinboost_window AS (ORDER BY class)
# )
# ORDER BY criteria DESC
# LIMIT 1
# )
#
# 0.00269317626953125
# SELECT *
# FROM (SELECT perishable AS perishable, CASE WHEN 4626 > c THEN (-(CAST(13439060.470843477 AS DOUBLE)/4626)* 13439060.470843477 + (s/c)*s + (13439060.470843477-s)/(4626-c)*(13439060.470843477-s)) ELSE 0 END AS criteria, c AS c, s AS s
# FROM (SELECT SUM(s) OVER joinboost_window  AS s, SUM(c) OVER joinboost_window  AS c, perishable AS perishable
# FROM (SELECT SUM(s) AS s, SUM(c) AS c, items.perishable AS perishable
# FROM joinboost_tmp_10,items
# WHERE joinboost_tmp_10.item_nbr IS NOT DISTINCT FROM items.item_nbr
# GROUP BY items.perishable
# )
# WINDOW joinboost_window AS (ORDER BY perishable)
# )
# ORDER BY criteria DESC
# LIMIT 1
# )
#
# 0.0024373531341552734
# SELECT *
# FROM (SELECT f1 AS f1, CASE WHEN 4626 > c THEN (-(CAST(13439060.470843477 AS DOUBLE)/4626)* 13439060.470843477 + (s/c)*s + (13439060.470843477-s)/(4626-c)*(13439060.470843477-s)) ELSE 0 END AS criteria, c AS c, s AS s
# FROM (SELECT SUM(s) OVER joinboost_window  AS s, SUM(c) OVER joinboost_window  AS c, f1 AS f1
# FROM (SELECT SUM(s) AS s, SUM(c) AS c, items.f1 AS f1
# FROM joinboost_tmp_10,items
# WHERE joinboost_tmp_10.item_nbr IS NOT DISTINCT FROM items.item_nbr
# GROUP BY items.f1
# )
# WINDOW joinboost_window AS (ORDER BY f1)
# )
# ORDER BY criteria DESC
# LIMIT 1
# )
#
# 0.003679513931274414
# SELECT *
# FROM (SELECT htype AS htype, CASE WHEN 5374 > c THEN (-(CAST(-13439060.470843477 AS DOUBLE)/5374)* -13439060.470843477 + (s/c)*s + (-13439060.470843477-s)/(5374-c)*(-13439060.470843477-s)) ELSE 0 END AS criteria, c AS c, s AS s
# FROM (SELECT SUM(s) OVER joinboost_window  AS s, SUM(c) OVER joinboost_window  AS c, htype AS htype
# FROM (SELECT SUM(s) AS s, SUM(c) AS c, holidays.htype AS htype
# FROM joinboost_tmp_12,holidays
# WHERE joinboost_tmp_12.date IS NOT DISTINCT FROM holidays.date
# GROUP BY holidays.htype
# )
# WINDOW joinboost_window AS (ORDER BY htype)
# )
# ORDER BY criteria DESC
# LIMIT 1
# )
#
# 0.0023097991943359375
# SELECT *
# FROM (SELECT locale AS locale, CASE WHEN 5374 > c THEN (-(CAST(-13439060.470843477 AS DOUBLE)/5374)* -13439060.470843477 + (s/c)*s + (-13439060.470843477-s)/(5374-c)*(-13439060.470843477-s)) ELSE 0 END AS criteria, c AS c, s AS s
# FROM (SELECT SUM(s) OVER joinboost_window  AS s, SUM(c) OVER joinboost_window  AS c, locale AS locale
# FROM (SELECT SUM(s) AS s, SUM(c) AS c, holidays.locale AS locale
# FROM joinboost_tmp_12,holidays
# WHERE joinboost_tmp_12.date IS NOT DISTINCT FROM holidays.date
# GROUP BY holidays.locale
# )
# WINDOW joinboost_window AS (ORDER BY locale)
# )
# ORDER BY criteria DESC
# LIMIT 1
# )
#
# 0.0022246837615966797
# SELECT *
# FROM (SELECT locale_name AS locale_name, CASE WHEN 5374 > c THEN (-(CAST(-13439060.470843477 AS DOUBLE)/5374)* -13439060.470843477 + (s/c)*s + (-13439060.470843477-s)/(5374-c)*(-13439060.470843477-s)) ELSE 0 END AS criteria, c AS c, s AS s
# FROM (SELECT SUM(s) OVER joinboost_window  AS s, SUM(c) OVER joinboost_window  AS c, locale_name AS locale_name
# FROM (SELECT SUM(s) AS s, SUM(c) AS c, holidays.locale_name AS locale_name
# FROM joinboost_tmp_12,holidays
# WHERE joinboost_tmp_12.date IS NOT DISTINCT FROM holidays.date
# GROUP BY holidays.locale_name
# )
# WINDOW joinboost_window AS (ORDER BY locale_name)
# )
# ORDER BY criteria DESC
# LIMIT 1
# )
#
# 0.0024111270904541016
# SELECT *
# FROM (SELECT transferred AS transferred, CASE WHEN 5374 > c THEN (-(CAST(-13439060.470843477 AS DOUBLE)/5374)* -13439060.470843477 + (s/c)*s + (-13439060.470843477-s)/(5374-c)*(-13439060.470843477-s)) ELSE 0 END AS criteria, c AS c, s AS s
# FROM (SELECT SUM(s) OVER joinboost_window  AS s, SUM(c) OVER joinboost_window  AS c, transferred AS transferred
# FROM (SELECT SUM(s) AS s, SUM(c) AS c, holidays.transferred AS transferred
# FROM joinboost_tmp_12,holidays
# WHERE joinboost_tmp_12.date IS NOT DISTINCT FROM holidays.date
# GROUP BY holidays.transferred
# )
# WINDOW joinboost_window AS (ORDER BY transferred)
# )
# ORDER BY criteria DESC
# LIMIT 1
# )
#
# 0.0021784305572509766
# SELECT *
# FROM (SELECT f2 AS f2, CASE WHEN 5374 > c THEN (-(CAST(-13439060.470843477 AS DOUBLE)/5374)* -13439060.470843477 + (s/c)*s + (-13439060.470843477-s)/(5374-c)*(-13439060.470843477-s)) ELSE 0 END AS criteria, c AS c, s AS s
# FROM (SELECT SUM(s) OVER joinboost_window  AS s, SUM(c) OVER joinboost_window  AS c, f2 AS f2
# FROM (SELECT SUM(s) AS s, SUM(c) AS c, holidays.f2 AS f2
# FROM joinboost_tmp_12,holidays
# WHERE joinboost_tmp_12.date IS NOT DISTINCT FROM holidays.date
# GROUP BY holidays.f2
# )
# WINDOW joinboost_window AS (ORDER BY f2)
# )
# ORDER BY criteria DESC
# LIMIT 1
# )
#
# 0.0034706592559814453
# SELECT *
# FROM (SELECT dcoilwtico AS dcoilwtico, CASE WHEN 5374 > c THEN (-(CAST(-13439060.470843477 AS DOUBLE)/5374)* -13439060.470843477 + (s/c)*s + (-13439060.470843477-s)/(5374-c)*(-13439060.470843477-s)) ELSE 0 END AS criteria, c AS c, s AS s
# FROM (SELECT SUM(s) OVER joinboost_window  AS s, SUM(c) OVER joinboost_window  AS c, dcoilwtico AS dcoilwtico
# FROM (SELECT SUM(s) AS s, SUM(c) AS c, oil.dcoilwtico AS dcoilwtico
# FROM joinboost_tmp_13,oil
# WHERE joinboost_tmp_13.date IS NOT DISTINCT FROM oil.date
# GROUP BY oil.dcoilwtico
# )
# WINDOW joinboost_window AS (ORDER BY dcoilwtico)
# )
# ORDER BY criteria DESC
# LIMIT 1
# )
#
# 0.002409696578979492
# SELECT *
# FROM (SELECT f3 AS f3, CASE WHEN 5374 > c THEN (-(CAST(-13439060.470843477 AS DOUBLE)/5374)* -13439060.470843477 + (s/c)*s + (-13439060.470843477-s)/(5374-c)*(-13439060.470843477-s)) ELSE 0 END AS criteria, c AS c, s AS s
# FROM (SELECT SUM(s) OVER joinboost_window  AS s, SUM(c) OVER joinboost_window  AS c, f3 AS f3
# FROM (SELECT SUM(s) AS s, SUM(c) AS c, oil.f3 AS f3
# FROM joinboost_tmp_13,oil
# WHERE joinboost_tmp_13.date IS NOT DISTINCT FROM oil.date
# GROUP BY oil.f3
# )
# WINDOW joinboost_window AS (ORDER BY f3)
# )
# ORDER BY criteria DESC
# LIMIT 1
# )
#
# 0.004949331283569336
# SELECT *
# FROM (SELECT transactions AS transactions, CASE WHEN 5374 > c THEN (-(CAST(-13439060.470843477 AS DOUBLE)/5374)* -13439060.470843477 + (s/c)*s + (-13439060.470843477-s)/(5374-c)*(-13439060.470843477-s)) ELSE 0 END AS criteria, c AS c, s AS s
# FROM (SELECT SUM(s) OVER joinboost_window  AS s, SUM(c) OVER joinboost_window  AS c, transactions AS transactions
# FROM (SELECT SUM(s) AS s, SUM(c) AS c, transactions.transactions AS transactions
# FROM joinboost_tmp_11,joinboost_tmp_2,transactions
# WHERE joinboost_tmp_11.store_nbr IS NOT DISTINCT FROM transactions.store_nbr AND joinboost_tmp_2.tid IS NOT DISTINCT FROM transactions.tid
# GROUP BY transactions.transactions
# )
# WINDOW joinboost_window AS (ORDER BY transactions)
# )
# ORDER BY criteria DESC
# LIMIT 1
# )
#
# 0.011770486831665039
# SELECT *
# FROM (SELECT f5 AS f5, CASE WHEN 5374 > c THEN (-(CAST(-13439060.470843477 AS DOUBLE)/5374)* -13439060.470843477 + (s/c)*s + (-13439060.470843477-s)/(5374-c)*(-13439060.470843477-s)) ELSE 0 END AS criteria, c AS c, s AS s
# FROM (SELECT SUM(s) OVER joinboost_window  AS s, SUM(c) OVER joinboost_window  AS c, f5 AS f5
# FROM (SELECT SUM(s) AS s, SUM(c) AS c, transactions.f5 AS f5
# FROM joinboost_tmp_11,joinboost_tmp_2,transactions
# WHERE joinboost_tmp_11.store_nbr IS NOT DISTINCT FROM transactions.store_nbr AND joinboost_tmp_2.tid IS NOT DISTINCT FROM transactions.tid
# GROUP BY transactions.f5
# )
# WINDOW joinboost_window AS (ORDER BY f5)
# )
# ORDER BY criteria DESC
# LIMIT 1
# )
#
# 0.007328510284423828
# SELECT *
# FROM (SELECT city AS city, CASE WHEN 5374 > c THEN (-(CAST(-13439060.470843477 AS DOUBLE)/5374)* -13439060.470843477 + (s/c)*s + (-13439060.470843477-s)/(5374-c)*(-13439060.470843477-s)) ELSE 0 END AS criteria, c AS c, s AS s
# FROM (SELECT SUM(s) OVER joinboost_window  AS s, SUM(c) OVER joinboost_window  AS c, city AS city
# FROM (SELECT SUM(s) AS s, SUM(c) AS c, stores.city AS city
# FROM joinboost_tmp_3,stores
# WHERE joinboost_tmp_3.store_nbr IS NOT DISTINCT FROM stores.store_nbr AND stores.f4 > 496
# GROUP BY stores.city
# )
# WINDOW joinboost_window AS (ORDER BY city)
# )
# ORDER BY criteria DESC
# LIMIT 1
# )
#
# 0.0024251937866210938
# SELECT *
# FROM (SELECT state AS state, CASE WHEN 5374 > c THEN (-(CAST(-13439060.470843477 AS DOUBLE)/5374)* -13439060.470843477 + (s/c)*s + (-13439060.470843477-s)/(5374-c)*(-13439060.470843477-s)) ELSE 0 END AS criteria, c AS c, s AS s
# FROM (SELECT SUM(s) OVER joinboost_window  AS s, SUM(c) OVER joinboost_window  AS c, state AS state
# FROM (SELECT SUM(s) AS s, SUM(c) AS c, stores.state AS state
# FROM joinboost_tmp_3,stores
# WHERE joinboost_tmp_3.store_nbr IS NOT DISTINCT FROM stores.store_nbr AND stores.f4 > 496
# GROUP BY stores.state
# )
# WINDOW joinboost_window AS (ORDER BY state)
# )
# ORDER BY criteria DESC
# LIMIT 1
# )
#
# 0.0027306079864501953
# SELECT *
# FROM (SELECT stype AS stype, CASE WHEN 5374 > c THEN (-(CAST(-13439060.470843477 AS DOUBLE)/5374)* -13439060.470843477 + (s/c)*s + (-13439060.470843477-s)/(5374-c)*(-13439060.470843477-s)) ELSE 0 END AS criteria, c AS c, s AS s
# FROM (SELECT SUM(s) OVER joinboost_window  AS s, SUM(c) OVER joinboost_window  AS c, stype AS stype
# FROM (SELECT SUM(s) AS s, SUM(c) AS c, stores.stype AS stype
# FROM joinboost_tmp_3,stores
# WHERE joinboost_tmp_3.store_nbr IS NOT DISTINCT FROM stores.store_nbr AND stores.f4 > 496
# GROUP BY stores.stype
# )
# WINDOW joinboost_window AS (ORDER BY stype)
# )
# ORDER BY criteria DESC
# LIMIT 1
# )
#
# 0.00264739990234375
# SELECT *
# FROM (SELECT cluster AS cluster, CASE WHEN 5374 > c THEN (-(CAST(-13439060.470843477 AS DOUBLE)/5374)* -13439060.470843477 + (s/c)*s + (-13439060.470843477-s)/(5374-c)*(-13439060.470843477-s)) ELSE 0 END AS criteria, c AS c, s AS s
# FROM (SELECT SUM(s) OVER joinboost_window  AS s, SUM(c) OVER joinboost_window  AS c, cluster AS cluster
# FROM (SELECT SUM(s) AS s, SUM(c) AS c, stores.cluster AS cluster
# FROM joinboost_tmp_3,stores
# WHERE joinboost_tmp_3.store_nbr IS NOT DISTINCT FROM stores.store_nbr AND stores.f4 > 496
# GROUP BY stores.cluster
# )
# WINDOW joinboost_window AS (ORDER BY cluster)
# )
# ORDER BY criteria DESC
# LIMIT 1
# )
#
# 0.002791881561279297
# SELECT *
# FROM (SELECT f4 AS f4, CASE WHEN 5374 > c THEN (-(CAST(-13439060.470843477 AS DOUBLE)/5374)* -13439060.470843477 + (s/c)*s + (-13439060.470843477-s)/(5374-c)*(-13439060.470843477-s)) ELSE 0 END AS criteria, c AS c, s AS s
# FROM (SELECT SUM(s) OVER joinboost_window  AS s, SUM(c) OVER joinboost_window  AS c, f4 AS f4
# FROM (SELECT SUM(s) AS s, SUM(c) AS c, stores.f4 AS f4
# FROM joinboost_tmp_3,stores
# WHERE joinboost_tmp_3.store_nbr IS NOT DISTINCT FROM stores.store_nbr AND stores.f4 > 496
# GROUP BY stores.f4
# )
# WINDOW joinboost_window AS (ORDER BY f4)
# )
# ORDER BY criteria DESC
# LIMIT 1
# )
#
# 0.0019392967224121094
# SELECT *
# FROM (SELECT family AS family, CASE WHEN 5374 > c THEN (-(CAST(-13439060.470843477 AS DOUBLE)/5374)* -13439060.470843477 + (s/c)*s + (-13439060.470843477-s)/(5374-c)*(-13439060.470843477-s)) ELSE 0 END AS criteria, c AS c, s AS s
# FROM (SELECT SUM(s) OVER joinboost_window  AS s, SUM(c) OVER joinboost_window  AS c, family AS family
# FROM (SELECT SUM(s) AS s, SUM(c) AS c, items.family AS family
# FROM joinboost_tmp_15,items
# WHERE joinboost_tmp_15.item_nbr IS NOT DISTINCT FROM items.item_nbr
# GROUP BY items.family
# )
# WINDOW joinboost_window AS (ORDER BY family)
# )
# ORDER BY criteria DESC
# LIMIT 1
# )
#
# 0.003663778305053711
# SELECT *
# FROM (SELECT class AS class, CASE WHEN 5374 > c THEN (-(CAST(-13439060.470843477 AS DOUBLE)/5374)* -13439060.470843477 + (s/c)*s + (-13439060.470843477-s)/(5374-c)*(-13439060.470843477-s)) ELSE 0 END AS criteria, c AS c, s AS s
# FROM (SELECT SUM(s) OVER joinboost_window  AS s, SUM(c) OVER joinboost_window  AS c, class AS class
# FROM (SELECT SUM(s) AS s, SUM(c) AS c, items.class AS class
# FROM joinboost_tmp_15,items
# WHERE joinboost_tmp_15.item_nbr IS NOT DISTINCT FROM items.item_nbr
# GROUP BY items.class
# )
# WINDOW joinboost_window AS (ORDER BY class)
# )
# ORDER BY criteria DESC
# LIMIT 1
# )
#
# 0.0029952526092529297
# SELECT *
# FROM (SELECT perishable AS perishable, CASE WHEN 5374 > c THEN (-(CAST(-13439060.470843477 AS DOUBLE)/5374)* -13439060.470843477 + (s/c)*s + (-13439060.470843477-s)/(5374-c)*(-13439060.470843477-s)) ELSE 0 END AS criteria, c AS c, s AS s
# FROM (SELECT SUM(s) OVER joinboost_window  AS s, SUM(c) OVER joinboost_window  AS c, perishable AS perishable
# FROM (SELECT SUM(s) AS s, SUM(c) AS c, items.perishable AS perishable
# FROM joinboost_tmp_15,items
# WHERE joinboost_tmp_15.item_nbr IS NOT DISTINCT FROM items.item_nbr
# GROUP BY items.perishable
# )
# WINDOW joinboost_window AS (ORDER BY perishable)
# )
# ORDER BY criteria DESC
# LIMIT 1
# )
#
# 0.0024292469024658203
# SELECT *
# FROM (SELECT f1 AS f1, CASE WHEN 5374 > c THEN (-(CAST(-13439060.470843477 AS DOUBLE)/5374)* -13439060.470843477 + (s/c)*s + (-13439060.470843477-s)/(5374-c)*(-13439060.470843477-s)) ELSE 0 END AS criteria, c AS c, s AS s
# FROM (SELECT SUM(s) OVER joinboost_window  AS s, SUM(c) OVER joinboost_window  AS c, f1 AS f1
# FROM (SELECT SUM(s) AS s, SUM(c) AS c, items.f1 AS f1
# FROM joinboost_tmp_15,items
# WHERE joinboost_tmp_15.item_nbr IS NOT DISTINCT FROM items.item_nbr
# GROUP BY items.f1
# )
# WINDOW joinboost_window AS (ORDER BY f1)
# )
# ORDER BY criteria DESC
# LIMIT 1
# )
#
# 0.0036695003509521484
# CREATE OR REPLACE TABLE joinboost_tmp_16 AS SELECT SUM(s) AS s, SUM(c) AS c, transactions.store_nbr AS store_nbr
# FROM joinboost_tmp_2,transactions
# WHERE joinboost_tmp_2.tid IS NOT DISTINCT FROM transactions.tid AND transactions.f5 <= 553
# GROUP BY transactions.store_nbr
#
# 0.004842042922973633
# CREATE OR REPLACE TABLE joinboost_tmp_17 AS SELECT SUM(s) AS s, SUM(c) AS c, transactions.date AS date
# FROM joinboost_tmp_11,joinboost_tmp_2,transactions
# WHERE joinboost_tmp_11.store_nbr IS NOT DISTINCT FROM transactions.store_nbr AND joinboost_tmp_2.tid IS NOT DISTINCT FROM transactions.tid AND transactions.f5 <= 553
# GROUP BY transactions.date
#
# 0.005934476852416992
# CREATE OR REPLACE TABLE joinboost_tmp_18 AS SELECT SUM(s) AS s, SUM(c) AS c, holidays.date AS date
# FROM joinboost_tmp_17,holidays
# WHERE joinboost_tmp_17.date IS NOT DISTINCT FROM holidays.date
# GROUP BY holidays.date
#
# 0.002360105514526367
# CREATE OR REPLACE TABLE joinboost_tmp_19 AS SELECT transactions.tid AS tid
# FROM joinboost_tmp_11,transactions
# WHERE joinboost_tmp_11.store_nbr IS NOT DISTINCT FROM transactions.store_nbr AND transactions.f5 <= 553
# GROUP BY transactions.tid
#
# 0.009664058685302734
# CREATE OR REPLACE TABLE joinboost_tmp_20 AS SELECT SUM(s) AS s, SUM(c) AS c, joinboost_tmp_0.item_nbr AS item_nbr
# FROM joinboost_tmp_19,joinboost_tmp_0
# WHERE joinboost_tmp_19.tid IS NOT DISTINCT FROM joinboost_tmp_0.tid
# GROUP BY joinboost_tmp_0.item_nbr
#
# 0.003342151641845703
# CREATE OR REPLACE TABLE joinboost_tmp_21 AS SELECT SUM(s) AS s, SUM(c) AS c, transactions.store_nbr AS store_nbr
# FROM joinboost_tmp_2,transactions
# WHERE joinboost_tmp_2.tid IS NOT DISTINCT FROM transactions.tid AND transactions.f5 > 553
# GROUP BY transactions.store_nbr
#
# 0.004384756088256836
# CREATE OR REPLACE TABLE joinboost_tmp_22 AS SELECT SUM(s) AS s, SUM(c) AS c, transactions.date AS date
# FROM joinboost_tmp_11,joinboost_tmp_2,transactions
# WHERE joinboost_tmp_11.store_nbr IS NOT DISTINCT FROM transactions.store_nbr AND joinboost_tmp_2.tid IS NOT DISTINCT FROM transactions.tid AND transactions.f5 > 553
# GROUP BY transactions.date
#
# 0.005172252655029297
# CREATE OR REPLACE TABLE joinboost_tmp_23 AS SELECT SUM(s) AS s, SUM(c) AS c, holidays.date AS date
# FROM joinboost_tmp_22,holidays
# WHERE joinboost_tmp_22.date IS NOT DISTINCT FROM holidays.date
# GROUP BY holidays.date
#
# 0.002983570098876953
# CREATE OR REPLACE TABLE joinboost_tmp_24 AS SELECT transactions.tid AS tid
# FROM joinboost_tmp_11,transactions
# WHERE joinboost_tmp_11.store_nbr IS NOT DISTINCT FROM transactions.store_nbr AND transactions.f5 > 553
# GROUP BY transactions.tid
#
# 0.006593465805053711
# CREATE OR REPLACE TABLE joinboost_tmp_25 AS SELECT SUM(s) AS s, SUM(c) AS c, joinboost_tmp_0.item_nbr AS item_nbr
# FROM joinboost_tmp_24,joinboost_tmp_0
# WHERE joinboost_tmp_24.tid IS NOT DISTINCT FROM joinboost_tmp_0.tid
# GROUP BY joinboost_tmp_0.item_nbr
#
# 0.002946615219116211
# SELECT *
# FROM (SELECT htype AS htype, CASE WHEN 3024 > c THEN (-(CAST(-14482903.751278551 AS DOUBLE)/3024)* -14482903.751278551 + (s/c)*s + (-14482903.751278551-s)/(3024-c)*(-14482903.751278551-s)) ELSE 0 END AS criteria, c AS c, s AS s
# FROM (SELECT SUM(s) OVER joinboost_window  AS s, SUM(c) OVER joinboost_window  AS c, htype AS htype
# FROM (SELECT SUM(s) AS s, SUM(c) AS c, holidays.htype AS htype
# FROM joinboost_tmp_17,holidays
# WHERE joinboost_tmp_17.date IS NOT DISTINCT FROM holidays.date
# GROUP BY holidays.htype
# )
# WINDOW joinboost_window AS (ORDER BY htype)
# )
# ORDER BY criteria DESC
# LIMIT 1
# )
#
# 0.0024073123931884766
# SELECT *
# FROM (SELECT locale AS locale, CASE WHEN 3024 > c THEN (-(CAST(-14482903.751278551 AS DOUBLE)/3024)* -14482903.751278551 + (s/c)*s + (-14482903.751278551-s)/(3024-c)*(-14482903.751278551-s)) ELSE 0 END AS criteria, c AS c, s AS s
# FROM (SELECT SUM(s) OVER joinboost_window  AS s, SUM(c) OVER joinboost_window  AS c, locale AS locale
# FROM (SELECT SUM(s) AS s, SUM(c) AS c, holidays.locale AS locale
# FROM joinboost_tmp_17,holidays
# WHERE joinboost_tmp_17.date IS NOT DISTINCT FROM holidays.date
# GROUP BY holidays.locale
# )
# WINDOW joinboost_window AS (ORDER BY locale)
# )
# ORDER BY criteria DESC
# LIMIT 1
# )
#
# 0.0021610260009765625
# SELECT *
# FROM (SELECT locale_name AS locale_name, CASE WHEN 3024 > c THEN (-(CAST(-14482903.751278551 AS DOUBLE)/3024)* -14482903.751278551 + (s/c)*s + (-14482903.751278551-s)/(3024-c)*(-14482903.751278551-s)) ELSE 0 END AS criteria, c AS c, s AS s
# FROM (SELECT SUM(s) OVER joinboost_window  AS s, SUM(c) OVER joinboost_window  AS c, locale_name AS locale_name
# FROM (SELECT SUM(s) AS s, SUM(c) AS c, holidays.locale_name AS locale_name
# FROM joinboost_tmp_17,holidays
# WHERE joinboost_tmp_17.date IS NOT DISTINCT FROM holidays.date
# GROUP BY holidays.locale_name
# )
# WINDOW joinboost_window AS (ORDER BY locale_name)
# )
# ORDER BY criteria DESC
# LIMIT 1
# )
#
# 0.002601146697998047
# SELECT *
# FROM (SELECT transferred AS transferred, CASE WHEN 3024 > c THEN (-(CAST(-14482903.751278551 AS DOUBLE)/3024)* -14482903.751278551 + (s/c)*s + (-14482903.751278551-s)/(3024-c)*(-14482903.751278551-s)) ELSE 0 END AS criteria, c AS c, s AS s
# FROM (SELECT SUM(s) OVER joinboost_window  AS s, SUM(c) OVER joinboost_window  AS c, transferred AS transferred
# FROM (SELECT SUM(s) AS s, SUM(c) AS c, holidays.transferred AS transferred
# FROM joinboost_tmp_17,holidays
# WHERE joinboost_tmp_17.date IS NOT DISTINCT FROM holidays.date
# GROUP BY holidays.transferred
# )
# WINDOW joinboost_window AS (ORDER BY transferred)
# )
# ORDER BY criteria DESC
# LIMIT 1
# )
#
# 0.002434968948364258
# SELECT *
# FROM (SELECT f2 AS f2, CASE WHEN 3024 > c THEN (-(CAST(-14482903.751278551 AS DOUBLE)/3024)* -14482903.751278551 + (s/c)*s + (-14482903.751278551-s)/(3024-c)*(-14482903.751278551-s)) ELSE 0 END AS criteria, c AS c, s AS s
# FROM (SELECT SUM(s) OVER joinboost_window  AS s, SUM(c) OVER joinboost_window  AS c, f2 AS f2
# FROM (SELECT SUM(s) AS s, SUM(c) AS c, holidays.f2 AS f2
# FROM joinboost_tmp_17,holidays
# WHERE joinboost_tmp_17.date IS NOT DISTINCT FROM holidays.date
# GROUP BY holidays.f2
# )
# WINDOW joinboost_window AS (ORDER BY f2)
# )
# ORDER BY criteria DESC
# LIMIT 1
# )
#
# 0.0035872459411621094
# SELECT *
# FROM (SELECT dcoilwtico AS dcoilwtico, CASE WHEN 3024 > c THEN (-(CAST(-14482903.751278551 AS DOUBLE)/3024)* -14482903.751278551 + (s/c)*s + (-14482903.751278551-s)/(3024-c)*(-14482903.751278551-s)) ELSE 0 END AS criteria, c AS c, s AS s
# FROM (SELECT SUM(s) OVER joinboost_window  AS s, SUM(c) OVER joinboost_window  AS c, dcoilwtico AS dcoilwtico
# FROM (SELECT SUM(s) AS s, SUM(c) AS c, oil.dcoilwtico AS dcoilwtico
# FROM joinboost_tmp_18,oil
# WHERE joinboost_tmp_18.date IS NOT DISTINCT FROM oil.date
# GROUP BY oil.dcoilwtico
# )
# WINDOW joinboost_window AS (ORDER BY dcoilwtico)
# )
# ORDER BY criteria DESC
# LIMIT 1
# )
#
# 0.003480672836303711
# SELECT *
# FROM (SELECT f3 AS f3, CASE WHEN 3024 > c THEN (-(CAST(-14482903.751278551 AS DOUBLE)/3024)* -14482903.751278551 + (s/c)*s + (-14482903.751278551-s)/(3024-c)*(-14482903.751278551-s)) ELSE 0 END AS criteria, c AS c, s AS s
# FROM (SELECT SUM(s) OVER joinboost_window  AS s, SUM(c) OVER joinboost_window  AS c, f3 AS f3
# FROM (SELECT SUM(s) AS s, SUM(c) AS c, oil.f3 AS f3
# FROM joinboost_tmp_18,oil
# WHERE joinboost_tmp_18.date IS NOT DISTINCT FROM oil.date
# GROUP BY oil.f3
# )
# WINDOW joinboost_window AS (ORDER BY f3)
# )
# ORDER BY criteria DESC
# LIMIT 1
# )
#
# 0.004729509353637695
# SELECT *
# FROM (SELECT transactions AS transactions, CASE WHEN 3024 > c THEN (-(CAST(-14482903.751278551 AS DOUBLE)/3024)* -14482903.751278551 + (s/c)*s + (-14482903.751278551-s)/(3024-c)*(-14482903.751278551-s)) ELSE 0 END AS criteria, c AS c, s AS s
# FROM (SELECT SUM(s) OVER joinboost_window  AS s, SUM(c) OVER joinboost_window  AS c, transactions AS transactions
# FROM (SELECT SUM(s) AS s, SUM(c) AS c, transactions.transactions AS transactions
# FROM joinboost_tmp_11,joinboost_tmp_2,transactions
# WHERE joinboost_tmp_11.store_nbr IS NOT DISTINCT FROM transactions.store_nbr AND joinboost_tmp_2.tid IS NOT DISTINCT FROM transactions.tid AND transactions.f5 <= 553
# GROUP BY transactions.transactions
# )
# WINDOW joinboost_window AS (ORDER BY transactions)
# )
# ORDER BY criteria DESC
# LIMIT 1
# )
#
# 0.00995182991027832
# SELECT *
# FROM (SELECT f5 AS f5, CASE WHEN 3024 > c THEN (-(CAST(-14482903.751278551 AS DOUBLE)/3024)* -14482903.751278551 + (s/c)*s + (-14482903.751278551-s)/(3024-c)*(-14482903.751278551-s)) ELSE 0 END AS criteria, c AS c, s AS s
# FROM (SELECT SUM(s) OVER joinboost_window  AS s, SUM(c) OVER joinboost_window  AS c, f5 AS f5
# FROM (SELECT SUM(s) AS s, SUM(c) AS c, transactions.f5 AS f5
# FROM joinboost_tmp_11,joinboost_tmp_2,transactions
# WHERE joinboost_tmp_11.store_nbr IS NOT DISTINCT FROM transactions.store_nbr AND joinboost_tmp_2.tid IS NOT DISTINCT FROM transactions.tid AND transactions.f5 <= 553
# GROUP BY transactions.f5
# )
# WINDOW joinboost_window AS (ORDER BY f5)
# )
# ORDER BY criteria DESC
# LIMIT 1
# )
#
# 0.008059978485107422
# SELECT *
# FROM (SELECT city AS city, CASE WHEN 3024 > c THEN (-(CAST(-14482903.751278551 AS DOUBLE)/3024)* -14482903.751278551 + (s/c)*s + (-14482903.751278551-s)/(3024-c)*(-14482903.751278551-s)) ELSE 0 END AS criteria, c AS c, s AS s
# FROM (SELECT SUM(s) OVER joinboost_window  AS s, SUM(c) OVER joinboost_window  AS c, city AS city
# FROM (SELECT SUM(s) AS s, SUM(c) AS c, stores.city AS city
# FROM joinboost_tmp_16,stores
# WHERE joinboost_tmp_16.store_nbr IS NOT DISTINCT FROM stores.store_nbr AND stores.f4 > 496
# GROUP BY stores.city
# )
# WINDOW joinboost_window AS (ORDER BY city)
# )
# ORDER BY criteria DESC
# LIMIT 1
# )
#
# 0.002394437789916992
# SELECT *
# FROM (SELECT state AS state, CASE WHEN 3024 > c THEN (-(CAST(-14482903.751278551 AS DOUBLE)/3024)* -14482903.751278551 + (s/c)*s + (-14482903.751278551-s)/(3024-c)*(-14482903.751278551-s)) ELSE 0 END AS criteria, c AS c, s AS s
# FROM (SELECT SUM(s) OVER joinboost_window  AS s, SUM(c) OVER joinboost_window  AS c, state AS state
# FROM (SELECT SUM(s) AS s, SUM(c) AS c, stores.state AS state
# FROM joinboost_tmp_16,stores
# WHERE joinboost_tmp_16.store_nbr IS NOT DISTINCT FROM stores.store_nbr AND stores.f4 > 496
# GROUP BY stores.state
# )
# WINDOW joinboost_window AS (ORDER BY state)
# )
# ORDER BY criteria DESC
# LIMIT 1
# )
#
# 0.002294301986694336
# SELECT *
# FROM (SELECT stype AS stype, CASE WHEN 3024 > c THEN (-(CAST(-14482903.751278551 AS DOUBLE)/3024)* -14482903.751278551 + (s/c)*s + (-14482903.751278551-s)/(3024-c)*(-14482903.751278551-s)) ELSE 0 END AS criteria, c AS c, s AS s
# FROM (SELECT SUM(s) OVER joinboost_window  AS s, SUM(c) OVER joinboost_window  AS c, stype AS stype
# FROM (SELECT SUM(s) AS s, SUM(c) AS c, stores.stype AS stype
# FROM joinboost_tmp_16,stores
# WHERE joinboost_tmp_16.store_nbr IS NOT DISTINCT FROM stores.store_nbr AND stores.f4 > 496
# GROUP BY stores.stype
# )
# WINDOW joinboost_window AS (ORDER BY stype)
# )
# ORDER BY criteria DESC
# LIMIT 1
# )
#
# 0.005942583084106445
# SELECT *
# ...
# FROM joinboost_tmp_47,joinboost_tmp_2,transactions
# WHERE joinboost_tmp_47.date IS NOT DISTINCT FROM transactions.date AND joinboost_tmp_2.tid IS NOT DISTINCT FROM transactions.tid AND transactions.f5 <= 557
# GROUP BY transactions.store_nbr
#
# 0.009251594543457031
# CREATE OR REPLACE TABLE joinboost_tmp_49 AS SELECT transactions.tid AS tid
# FROM joinboost_tmp_6,joinboost_tmp_47,transactions
# WHERE joinboost_tmp_6.store_nbr IS NOT DISTINCT FROM transactions.store_nbr AND joinboost_tmp_47.date IS NOT DISTINCT FROM transactions.date AND transactions.f5 <= 557
# GROUP BY transactions.tid
#
# 0.013843774795532227
# CREATE OR REPLACE TABLE joinboost_tmp_50 AS SELECT SUM(s) AS s, SUM(c) AS c, joinboost_tmp_0.item_nbr AS item_nbr
# FROM joinboost_tmp_49,joinboost_tmp_0
# WHERE joinboost_tmp_49.tid IS NOT DISTINCT FROM joinboost_tmp_0.tid
# GROUP BY joinboost_tmp_0.item_nbr
#
# 0.003305196762084961
# CREATE OR REPLACE TABLE joinboost_tmp_51 AS SELECT oil.date AS date
# FROM oil
# WHERE oil.f3 > 475
# GROUP BY oil.date
#
# 0.0015625953674316406
# CREATE OR REPLACE TABLE joinboost_tmp_52 AS SELECT holidays.date AS date
# FROM joinboost_tmp_51,holidays
# WHERE joinboost_tmp_51.date IS NOT DISTINCT FROM holidays.date
# GROUP BY holidays.date
#
# 0.0018248558044433594
# CREATE OR REPLACE TABLE joinboost_tmp_53 AS SELECT SUM(s) AS s, SUM(c) AS c, transactions.store_nbr AS store_nbr
# FROM joinboost_tmp_52,joinboost_tmp_2,transactions
# WHERE joinboost_tmp_52.date IS NOT DISTINCT FROM transactions.date AND joinboost_tmp_2.tid IS NOT DISTINCT FROM transactions.tid AND transactions.f5 <= 557
# GROUP BY transactions.store_nbr
#
# 0.009355545043945312
# CREATE OR REPLACE TABLE joinboost_tmp_54 AS SELECT transactions.tid AS tid
# FROM joinboost_tmp_6,joinboost_tmp_52,transactions
# WHERE joinboost_tmp_6.store_nbr IS NOT DISTINCT FROM transactions.store_nbr AND joinboost_tmp_52.date IS NOT DISTINCT FROM transactions.date AND transactions.f5 <= 557
# GROUP BY transactions.tid
#
# 0.01186680793762207
# CREATE OR REPLACE TABLE joinboost_tmp_55 AS SELECT SUM(s) AS s, SUM(c) AS c, joinboost_tmp_0.item_nbr AS item_nbr
# FROM joinboost_tmp_54,joinboost_tmp_0
# WHERE joinboost_tmp_54.tid IS NOT DISTINCT FROM joinboost_tmp_0.tid
# GROUP BY joinboost_tmp_0.item_nbr
#
# 0.004296779632568359
# CREATE OR REPLACE TABLE joinboost_tmp_56 AS SELECT oil.date AS date
# FROM oil
# WHERE oil.f3 <= 450
# GROUP BY oil.date
#
# 0.0016677379608154297
# CREATE OR REPLACE TABLE joinboost_tmp_57 AS SELECT holidays.date AS date
# FROM joinboost_tmp_56,holidays
# WHERE joinboost_tmp_56.date IS NOT DISTINCT FROM holidays.date
# GROUP BY holidays.date
#
# 0.0017697811126708984
# CREATE OR REPLACE TABLE joinboost_tmp_58 AS SELECT SUM(s) AS s, SUM(c) AS c, transactions.store_nbr AS store_nbr
# FROM joinboost_tmp_57,joinboost_tmp_2,transactions
# WHERE joinboost_tmp_57.date IS NOT DISTINCT FROM transactions.date AND joinboost_tmp_2.tid IS NOT DISTINCT FROM transactions.tid AND transactions.f5 > 553
# GROUP BY transactions.store_nbr
#
# 0.005637645721435547
# CREATE OR REPLACE TABLE joinboost_tmp_59 AS SELECT transactions.tid AS tid
# FROM joinboost_tmp_11,joinboost_tmp_57,transactions
# WHERE joinboost_tmp_11.store_nbr IS NOT DISTINCT FROM transactions.store_nbr AND joinboost_tmp_57.date IS NOT DISTINCT FROM transactions.date AND transactions.f5 > 553
# GROUP BY transactions.tid
#
# 0.0070285797119140625
# CREATE OR REPLACE TABLE joinboost_tmp_60 AS SELECT SUM(s) AS s, SUM(c) AS c, joinboost_tmp_0.item_nbr AS item_nbr
# FROM joinboost_tmp_59,joinboost_tmp_0
# WHERE joinboost_tmp_59.tid IS NOT DISTINCT FROM joinboost_tmp_0.tid
# GROUP BY joinboost_tmp_0.item_nbr
#
# 0.002754688262939453
# CREATE OR REPLACE TABLE joinboost_tmp_61 AS SELECT oil.date AS date
# FROM oil
# WHERE oil.f3 > 450
# GROUP BY oil.date
#
# 0.0013856887817382812
# CREATE OR REPLACE TABLE joinboost_tmp_62 AS SELECT holidays.date AS date
# FROM joinboost_tmp_61,holidays
# WHERE joinboost_tmp_61.date IS NOT DISTINCT FROM holidays.date
# GROUP BY holidays.date
#
# 0.0017654895782470703
# CREATE OR REPLACE TABLE joinboost_tmp_63 AS SELECT SUM(s) AS s, SUM(c) AS c, transactions.store_nbr AS store_nbr
# FROM joinboost_tmp_62,joinboost_tmp_2,transactions
# WHERE joinboost_tmp_62.date IS NOT DISTINCT FROM transactions.date AND joinboost_tmp_2.tid IS NOT DISTINCT FROM transactions.tid AND transactions.f5 > 553
# GROUP BY transactions.store_nbr
#
# 0.0054738521575927734
# CREATE OR REPLACE TABLE joinboost_tmp_64 AS SELECT transactions.tid AS tid
# FROM joinboost_tmp_11,joinboost_tmp_62,transactions
# WHERE joinboost_tmp_11.store_nbr IS NOT DISTINCT FROM transactions.store_nbr AND joinboost_tmp_62.date IS NOT DISTINCT FROM transactions.date AND transactions.f5 > 553
# GROUP BY transactions.tid
#
# 0.00650787353515625
# CREATE OR REPLACE TABLE joinboost_tmp_65 AS SELECT SUM(s) AS s, SUM(c) AS c, joinboost_tmp_0.item_nbr AS item_nbr
# FROM joinboost_tmp_64,joinboost_tmp_0
# WHERE joinboost_tmp_64.tid IS NOT DISTINCT FROM joinboost_tmp_0.tid
# GROUP BY joinboost_tmp_0.item_nbr
#
# 0.003835439682006836
# CREATE OR REPLACE TABLE joinboost_tmp_66 AS SELECT oil.date AS date
# FROM oil
# WHERE oil.f3 <= 463
# GROUP BY oil.date
#
# 0.0012359619140625
# CREATE OR REPLACE TABLE joinboost_tmp_67 AS SELECT holidays.date AS date
# FROM joinboost_tmp_66,holidays
# WHERE joinboost_tmp_66.date IS NOT DISTINCT FROM holidays.date
# GROUP BY holidays.date
#
# 0.0018777847290039062
# CREATE OR REPLACE TABLE joinboost_tmp_68 AS SELECT SUM(s) AS s, SUM(c) AS c, transactions.store_nbr AS store_nbr
# FROM joinboost_tmp_67,joinboost_tmp_2,transactions
# WHERE joinboost_tmp_67.date IS NOT DISTINCT FROM transactions.date AND joinboost_tmp_2.tid IS NOT DISTINCT FROM transactions.tid AND transactions.f5 > 557
# GROUP BY transactions.store_nbr
#
# 0.005396842956542969
# CREATE OR REPLACE TABLE joinboost_tmp_69 AS SELECT transactions.tid AS tid
# FROM joinboost_tmp_6,joinboost_tmp_67,transactions
# WHERE joinboost_tmp_6.store_nbr IS NOT DISTINCT FROM transactions.store_nbr AND joinboost_tmp_67.date IS NOT DISTINCT FROM transactions.date AND transactions.f5 > 557
# GROUP BY transactions.tid
#
# 0.007074832916259766
# CREATE OR REPLACE TABLE joinboost_tmp_70 AS SELECT SUM(s) AS s, SUM(c) AS c, joinboost_tmp_0.item_nbr AS item_nbr
# FROM joinboost_tmp_69,joinboost_tmp_0
# WHERE joinboost_tmp_69.tid IS NOT DISTINCT FROM joinboost_tmp_0.tid
# GROUP BY joinboost_tmp_0.item_nbr
#
# 0.002662181854248047
# CREATE OR REPLACE TABLE joinboost_tmp_71 AS SELECT oil.date AS date
# FROM oil
# WHERE oil.f3 > 463
# GROUP BY oil.date
#
# 0.0014967918395996094
# CREATE OR REPLACE TABLE joinboost_tmp_72 AS SELECT holidays.date AS date
# FROM joinboost_tmp_71,holidays
# WHERE joinboost_tmp_71.date IS NOT DISTINCT FROM holidays.date
# GROUP BY holidays.date
#
# 0.0013878345489501953
# CREATE OR REPLACE TABLE joinboost_tmp_73 AS SELECT SUM(s) AS s, SUM(c) AS c, transactions.store_nbr AS store_nbr
# FROM joinboost_tmp_72,joinboost_tmp_2,transactions
# WHERE joinboost_tmp_72.date IS NOT DISTINCT FROM transactions.date AND joinboost_tmp_2.tid IS NOT DISTINCT FROM transactions.tid AND transactions.f5 > 557
# GROUP BY transactions.store_nbr
#
# 0.004729747772216797
# CREATE OR REPLACE TABLE joinboost_tmp_74 AS SELECT transactions.tid AS tid
# FROM joinboost_tmp_6,joinboost_tmp_72,transactions
# WHERE joinboost_tmp_6.store_nbr IS NOT DISTINCT FROM transactions.store_nbr AND joinboost_tmp_72.date IS NOT DISTINCT FROM transactions.date AND transactions.f5 > 557
# GROUP BY transactions.tid
#
# 0.005297660827636719
# CREATE OR REPLACE TABLE joinboost_tmp_75 AS SELECT SUM(s) AS s, SUM(c) AS c, joinboost_tmp_0.item_nbr AS item_nbr
# FROM joinboost_tmp_74,joinboost_tmp_0
# WHERE joinboost_tmp_74.tid IS NOT DISTINCT FROM joinboost_tmp_0.tid
# GROUP BY joinboost_tmp_0.item_nbr
#
# 0.0024924278259277344
# DROP TABLE IF EXISTS joinboost_tmp_5;
#
# 0.0008900165557861328
# DROP TABLE IF EXISTS joinboost_tmp_3;
#
# 0.0008823871612548828
# DROP TABLE IF EXISTS joinboost_tmp_4;
#
# 0.000789642333984375
# DROP TABLE IF EXISTS joinboost_tmp_1;
#
# 0.0007760524749755859
# DROP TABLE IF EXISTS joinboost_tmp_2;
#
# 0.00029921531677246094
# DROP TABLE IF EXISTS joinboost_tmp_8;
#
# 0.0012850761413574219
# DROP TABLE IF EXISTS joinboost_tmp_3;
#
# 0.0015141963958740234
# DROP TABLE IF EXISTS joinboost_tmp_7;
#
# 0.0016412734985351562
# DROP TABLE IF EXISTS joinboost_tmp_9;
#
# 0.0007586479187011719
# DROP TABLE IF EXISTS joinboost_tmp_6;
#
# 0.0007369518280029297
# DROP TABLE IF EXISTS joinboost_tmp_10;
#
# 0.0013811588287353516
# DROP TABLE IF EXISTS joinboost_tmp_2;
#
# 0.0008218288421630859
# DROP TABLE IF EXISTS joinboost_tmp_13;
#
# 0.0020956993103027344
# DROP TABLE IF EXISTS joinboost_tmp_3;
#
# 0.0008482933044433594
# DROP TABLE IF EXISTS joinboost_tmp_12;
#
# 0.0008025169372558594
# DROP TABLE IF EXISTS joinboost_tmp_14;
#
# 0.0018815994262695312
# DROP TABLE IF EXISTS joinboost_tmp_11;
#
# 0.0008478164672851562
# DROP TABLE IF EXISTS joinboost_tmp_15;
#
# 0.0010731220245361328
# DROP TABLE IF EXISTS joinboost_tmp_2;
#
# 0.0008044242858886719
# DROP TABLE IF EXISTS joinboost_tmp_18;
#
# 0.0008549690246582031
# DROP TABLE IF EXISTS joinboost_tmp_16;
#
# 0.0009279251098632812
# DROP TABLE IF EXISTS joinboost_tmp_17;
#
# 0.000911712646484375
# DROP TABLE IF EXISTS joinboost_tmp_19;
#
# 0.0010678768157958984
# DROP TABLE IF EXISTS joinboost_tmp_11;
#
# 0.0015168190002441406
# DROP TABLE IF EXISTS joinboost_tmp_20;
#
# 0.00328826904296875
# DROP TABLE IF EXISTS joinboost_tmp_2;
#
# 0.000202178955078125
# DROP TABLE IF EXISTS joinboost_tmp_23;
#
# 0.00017404556274414062
# DROP TABLE IF EXISTS joinboost_tmp_21;
#
# 0.0001308917999267578
# DROP TABLE IF EXISTS joinboost_tmp_22;
#
# 0.006514549255371094
# DROP TABLE IF EXISTS joinboost_tmp_24;
#
# 0.001171112060546875
# DROP TABLE IF EXISTS joinboost_tmp_11;
#
# 0.00017261505126953125
# DROP TABLE IF EXISTS joinboost_tmp_25;
#
# 0.0002713203430175781
# DROP TABLE IF EXISTS joinboost_tmp_2;
#
# 0.00015997886657714844
# DROP TABLE IF EXISTS joinboost_tmp_28;
#
# 0.00024318695068359375
# DROP TABLE IF EXISTS joinboost_tmp_26;
#
# 0.0001964569091796875
# DROP TABLE IF EXISTS joinboost_tmp_27;
#
# 0.0003445148468017578
# DROP TABLE IF EXISTS joinboost_tmp_29;
#
# 0.0006487369537353516
# DROP TABLE IF EXISTS joinboost_tmp_6;
#
# 0.0001621246337890625
# DROP TABLE IF EXISTS joinboost_tmp_30;
#
# 0.002674102783203125
# DROP TABLE IF EXISTS joinboost_tmp_2;
#
# 0.000225067138671875
# DROP TABLE IF EXISTS joinboost_tmp_33;
#
# 0.00015854835510253906
# DROP TABLE IF EXISTS joinboost_tmp_31;
#
# 0.00012421607971191406
# DROP TABLE IF EXISTS joinboost_tmp_32;
#
# 0.00012612342834472656
# DROP TABLE IF EXISTS joinboost_tmp_34;
#
# 0.0001270771026611328
# DROP TABLE IF EXISTS joinboost_tmp_6;
#
# 9.799003601074219e-05
# DROP TABLE IF EXISTS joinboost_tmp_35;
#
# 0.0022935867309570312
# DROP TABLE IF EXISTS joinboost_tmp_2;
#
# 0.0023779869079589844
# DROP TABLE IF EXISTS joinboost_tmp_37;
#
# 0.001354217529296875
# DROP TABLE IF EXISTS joinboost_tmp_18;
#
# 0.0023527145385742188
# DROP TABLE IF EXISTS joinboost_tmp_36;
#
# 0.0012912750244140625
# DROP TABLE IF EXISTS joinboost_tmp_38;
#
# 0.0019376277923583984
# DROP TABLE IF EXISTS joinboost_tmp_17;
#
# 0.0012974739074707031
# DROP TABLE IF EXISTS joinboost_tmp_39;
#
# 0.0012812614440917969
# DROP TABLE IF EXISTS joinboost_tmp_11;
#
# 0.001363992691040039
# DROP TABLE IF EXISTS joinboost_tmp_40;
#
# 0.0008153915405273438
# DROP TABLE IF EXISTS joinboost_tmp_2;
#
# 0.0019004344940185547
# DROP TABLE IF EXISTS joinboost_tmp_42;
#
# 0.0006823539733886719
# DROP TABLE IF EXISTS joinboost_tmp_18;
#
# 0.0012459754943847656
# DROP TABLE IF EXISTS joinboost_tmp_41;
#
# 0.0012574195861816406
# DROP TABLE IF EXISTS joinboost_tmp_43;
#
# 0.002062559127807617
# DROP TABLE IF EXISTS joinboost_tmp_17;
#
# 0.002088308334350586
# DROP TABLE IF EXISTS joinboost_tmp_44;
#
# 0.0007145404815673828
# DROP TABLE IF EXISTS joinboost_tmp_11;
#
# 0.0007131099700927734
# DROP TABLE IF EXISTS joinboost_tmp_45;
#
# 0.0007066726684570312
# DROP TABLE IF EXISTS joinboost_tmp_2;
#
# 0.0007205009460449219
# DROP TABLE IF EXISTS joinboost_tmp_47;
#
# 0.0007188320159912109
# DROP TABLE IF EXISTS joinboost_tmp_28;
#
# 0.001283407211303711
# DROP TABLE IF EXISTS joinboost_tmp_46;
#
# 0.0012960433959960938
# DROP TABLE IF EXISTS joinboost_tmp_48;
#
# 0.0019683837890625
# DROP TABLE IF EXISTS joinboost_tmp_27;
#
# 0.000209808349609375
# DROP TABLE IF EXISTS joinboost_tmp_49;
#
# 0.00263214111328125
# DROP TABLE IF EXISTS joinboost_tmp_6;
#
# 0.0010890960693359375
# DROP TABLE IF EXISTS joinboost_tmp_50;
#
# 0.001592874526977539
# DROP TABLE IF EXISTS joinboost_tmp_2;
#
# 0.0011627674102783203
# DROP TABLE IF EXISTS joinboost_tmp_52;
#
# 0.0008218288421630859
# DROP TABLE IF EXISTS joinboost_tmp_28;
#
# 0.0009713172912597656
# DROP TABLE IF EXISTS joinboost_tmp_51;
#
# 0.0007987022399902344
# DROP TABLE IF EXISTS joinboost_tmp_53;
#
# 0.0007565021514892578
# DROP TABLE IF EXISTS joinboost_tmp_27;
#
# 0.0007345676422119141
# DROP TABLE IF EXISTS joinboost_tmp_54;
#
# 0.0007617473602294922
# DROP TABLE IF EXISTS joinboost_tmp_6;
#
# 0.0010223388671875
# DROP TABLE IF EXISTS joinboost_tmp_55;
#
# 0.0010082721710205078
# DROP TABLE IF EXISTS joinboost_tmp_2;
#
# 0.001102447509765625
# DROP TABLE IF EXISTS joinboost_tmp_57;
#
# 0.0007913112640380859
# DROP TABLE IF EXISTS joinboost_tmp_23;
#
# 0.0007584095001220703
# DROP TABLE IF EXISTS joinboost_tmp_56;
#
# 0.0008711814880371094
# DROP TABLE IF EXISTS joinboost_tmp_58;
#
# 0.0012919902801513672
# DROP TABLE IF EXISTS joinboost_tmp_22;
#
# 0.0008313655853271484
# DROP TABLE IF EXISTS joinboost_tmp_59;
#
# 0.0015478134155273438
# DROP TABLE IF EXISTS joinboost_tmp_11;
#
# 0.0008900165557861328
# DROP TABLE IF EXISTS joinboost_tmp_60;
#
# 0.0001595020294189453
# DROP TABLE IF EXISTS joinboost_tmp_2;
#
# 6.341934204101562e-05
# DROP TABLE IF EXISTS joinboost_tmp_62;
#
# 0.0001227855682373047
# DROP TABLE IF EXISTS joinboost_tmp_23;
#
# 0.001998424530029297
# DROP TABLE IF EXISTS joinboost_tmp_61;
#
# 0.0013365745544433594
# DROP TABLE IF EXISTS joinboost_tmp_63;
#
# 0.000843048095703125
# DROP TABLE IF EXISTS joinboost_tmp_22;
#
# 0.002291440963745117
# DROP TABLE IF EXISTS joinboost_tmp_64;
#
# 0.0008928775787353516
# DROP TABLE IF EXISTS joinboost_tmp_11;
#
# 0.0008203983306884766
# DROP TABLE IF EXISTS joinboost_tmp_65;
#
# 0.0016341209411621094
# DROP TABLE IF EXISTS joinboost_tmp_2;
#
# 0.0009033679962158203
# DROP TABLE IF EXISTS joinboost_tmp_67;
#
# 0.0008423328399658203
# DROP TABLE IF EXISTS joinboost_tmp_33;
#
# 0.0013458728790283203
# DROP TABLE IF EXISTS joinboost_tmp_66;
#
# 0.0009026527404785156
# DROP TABLE IF EXISTS joinboost_tmp_68;
#
# 0.0016202926635742188
# DROP TABLE IF EXISTS joinboost_tmp_32;
#
# 0.0007789134979248047
# DROP TABLE IF EXISTS joinboost_tmp_69;
#
# 0.0007684230804443359
# DROP TABLE IF EXISTS joinboost_tmp_6;
#
# 0.0007777214050292969
# DROP TABLE IF EXISTS joinboost_tmp_70;
#
# 0.0022003650665283203
# DROP TABLE IF EXISTS joinboost_tmp_2;
#
# 0.001420736312866211
# DROP TABLE IF EXISTS joinboost_tmp_72;
#
# 0.007233858108520508
# DROP TABLE IF EXISTS joinboost_tmp_33;
#
# 0.0016436576843261719
# DROP TABLE IF EXISTS joinboost_tmp_71;
#
# 0.0008523464202880859
# DROP TABLE IF EXISTS joinboost_tmp_73;
#
# 0.0012843608856201172
# DROP TABLE IF EXISTS joinboost_tmp_32;
#
# 0.0010302066802978516
# DROP TABLE IF EXISTS joinboost_tmp_74;
#
# 0.0009357929229736328
# DROP TABLE IF EXISTS joinboost_tmp_6;
#
# 0.0008151531219482422
# DROP TABLE IF EXISTS joinboost_tmp_75;
#
# 0.001024007797241211
# DROP TABLE IF EXISTS joinboost_tmp_2;
#
# 0.0008475780487060547
# CREATE OR REPLACE TABLE joinboost_tmp_76 AS
# SELECT Y,-4842.635841853514+
# CASE
#  WHEN f4 > 496 AND f5 <= 553 AND f3 <= 475 THEN CAST(-2337.9228084177735 AS DOUBLE)
#  WHEN f4 > 496 AND f5 <= 553 AND f3 > 475 THEN CAST(-7160.971070371713 AS DOUBLE)
#  WHEN f4 <= 496 AND f5 <= 557 AND f3 > 475 THEN CAST(-2060.958149762831 AS DOUBLE)
#  WHEN f4 > 496 AND f5 > 553 AND f3 > 450 THEN CAST(-1953.1974409598786 AS DOUBLE)
#  WHEN f4 <= 496 AND f5 <= 557 AND f3 <= 475 THEN CAST(3039.5826387332845 AS DOUBLE)
#  WHEN f4 > 496 AND f5 > 553 AND f3 <= 450 THEN CAST(3077.0322614426113 AS DOUBLE)
#  WHEN f4 <= 496 AND f5 > 557 AND f3 <= 463 THEN CAST(8135.210187401269 AS DOUBLE)
#  WHEN f4 <= 496 AND f5 > 557 AND f3 > 463 THEN CAST(3187.9458062845265 AS DOUBLE)
# ELSE 0 END
# AS prediction FROM train
# 0.0038175582885742188
# CREATE OR REPLACE TABLE joinboost_tmp_77 AS SELECT SQRT(AVG(POW(Y - prediction,2))) AS RMSE
# FROM joinboost_tmp_76
#
# 0.0016384124755859375
# SELECT *
# FROM joinboost_tmp_77
#
# 0.0009534358978271484
# 2535.0608391585865

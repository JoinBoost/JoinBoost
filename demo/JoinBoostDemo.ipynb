# %% [markdown]
# # Install JoinBoost and databases package.
#
# To run this demo, you'll need to install the JoinBoost and databases packages. We will use DuckDB as the database in this demo.

# %%
# %pip install joinboost==0.0.1523
# %pip install duckdb
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting joinboost==0.0.1523
#   Downloading joinboost-0.0.1523-py3-none-any.whl (117 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.8/117.8 kB 2.1 MB/s eta 0:00:00
# Installing collected packages: joinboost
# Successfully installed joinboost-0.0.1523
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: duckdb in /usr/local/lib/python3.10/dist-packages (0.7.1)

# %% [markdown]
# # Download and Load Data into a Database
#
# This step is only Necessary for the Demo as pre-existing databases are unavailable. In general, JoinBoost enables direct model training over databases without data downloading or loading.

# %%
# Import required libraries
import duckdb
import urllib.request
from joinboost.executor import DuckdbExecutor
from joinboost.joingraph import JoinGraph
from joinboost.app import DecisionTree, GradientBoosting

# Define URLs
urls = {
    "holidays": "https://www.dropbox.com/s/kaovdndtevcvt83/holidays.csv?dl=1",
    "items": "https://www.dropbox.com/s/wh6amz4um7ieyqz/items.csv?dl=1",
    "oil": "https://www.dropbox.com/s/ze6of1xqwslt8jb/oil.csv?dl=1",
    "sales_small": "https://www.dropbox.com/s/uiojfrc5c20gyrl/sales_small.csv?dl=1",
    "stores": "https://www.dropbox.com/s/cwy6z0b7rhsnrxb/stores.csv?dl=1",
    "train_small": "https://www.dropbox.com/s/wwaoga17z70jb6l/train_small.csv?dl=1",
    "transactions": "https://www.dropbox.com/s/2bxto9wnetwnvqd/transactions.csv?dl=1",
}

# Download files
for name, url in urls.items():
    urllib.request.urlretrieve(url, f"{name}.csv")

# Connect to database
con = duckdb.connect(database=':memory:')

# Create tables
con.execute("CREATE OR REPLACE TABLE holidays AS SELECT * FROM 'holidays.csv';")
con.execute("CREATE OR REPLACE TABLE oil AS SELECT * FROM 'oil.csv';")
con.execute("CREATE OR REPLACE TABLE transactions AS SELECT * FROM 'transactions.csv';")
con.execute("CREATE OR REPLACE TABLE stores AS SELECT * FROM 'stores.csv';")
con.execute("CREATE OR REPLACE TABLE items AS SELECT * FROM 'items.csv';")
con.execute("CREATE OR REPLACE TABLE sales AS SELECT * FROM 'sales_small.csv';")
con.execute("CREATE OR REPLACE TABLE train AS SELECT * FROM 'train_small.csv';")

# %% [markdown]
# # Data exploration and Data Transformation
#
# You can use database SQL queries to  perform data transformations over tables.

# %%
con.execute("describe;").df()
# Out:
#      table_name                                       column_names  \
# 0      holidays  [date, htype, locale, locale_name, transferred...
# 1         items          [item_nbr, family, class, perishable, f1]
# 2           oil                             [date, dcoilwtico, f3]
# 3         sales        [item_nbr, unit_sales, onpromotion, tid, Y]
# 4        stores       [store_nbr, city, state, stype, cluster, f4]
# 5         train  [Y, onpromotion, htype, locale, locale_name, t...
# 6  transactions           [date, store_nbr, transactions, tid, f5]
#
#                                         column_types  temporary
# 0   [BIGINT, BIGINT, BIGINT, BIGINT, BIGINT, BIGINT]      False
# 1           [BIGINT, BIGINT, BIGINT, BIGINT, BIGINT]      False
# 2                           [BIGINT, BIGINT, BIGINT]      False
# 3           [BIGINT, DOUBLE, BIGINT, BIGINT, DOUBLE]      False
# 4   [BIGINT, BIGINT, BIGINT, BIGINT, BIGINT, BIGINT]      False
# 5  [DOUBLE, BIGINT, BIGINT, BIGINT, BIGINT, BIGIN...      False
# 6           [BIGINT, BIGINT, BIGINT, BIGINT, BIGINT]      False

# %% [markdown]
# # Building a Join Graph
#
# First, you need to specify the join graph, which includes the relations and features you want to use, as well as how these relations should be joined. For example,
#
# ```
# dataset.add_join("sales", "items", ["item_nbr"], ["item_nbr"])
# ```
# indicates that the join condition between the "sales" and "items" tables is based on the item_nbr attribute, where sales.item_nbr = items.item_nbr. By specifying the join conditions in this manner, you can define how the tables in your dataset are related and should be combined.

# %%
exe = DuckdbExecutor(con, debug=False)
dataset = JoinGraph(exe=exe)
dataset.add_relation("sales", [], y = 'Y')
dataset.add_relation("holidays", ["htype", "locale", "locale_name", "transferred","f2"])
dataset.add_relation("oil", ["dcoilwtico","f3"])
dataset.add_relation("transactions", ["transactions","f5"])
dataset.add_relation("stores", ["city","state","stype","cluster","f4"])
dataset.add_relation("items", ["family","class","perishable","f1"])
dataset.add_join("sales", "items", ["item_nbr"], ["item_nbr"])
dataset.add_join("sales", "transactions", ["tid"], ["tid"])
dataset.add_join("transactions", "stores", ["store_nbr"], ["store_nbr"])
dataset.add_join("transactions", "holidays", ["date"], ["date"])
dataset.add_join("holidays", "oil", ["date"], ["date"])

dataset
# Out:
# <!DOCTYPE html>
# <meta charset="utf-8">
# <style>
#     .flex-container {
#       display: flex;
#     }
#
#     .links line {
#         stroke: #aaa;
#         stroke-width: 2px;
#     }
#     .links line.highlight{
#         stroke: black;
#         stroke-width: 4px;
#     }
#     .links line.clickable_edge  {
#         opacity: 0;
#         stroke-width: 20px;
#     }
#     .links line.clickable_edge.highlight  {
#         opacity: 0;
#         stroke-width: 22px;
#     }
#
#     .markers polyline {
#       fill: none;
#       stroke: #aaa;
#       stroke-width: 2px;
#     }
#
#     .markers polyline.highlight {
#         fill: none;
#         stroke: black;
#         stroke-width: 4px;
#     }
#
#     .nodes circle {
#         fill: #bbb;
#     }
#
#     .nodes circle.highlight {
#         fill: black;
#     }
#
#     .relation {
#         background-color: #a7b7e3;
#         margin: 6px 6px;
#         padding: 3px 3px;
#         border-radius: 3px ;
#     }
#
#     .relation:hover {
#         background-color: #96a4c9;
#     }
#
#     .relationName {
#         display: flex;
#         margin: 5px 5px;
#         font-weight: bold;
#     }
#
#     .attribute {
#         display: flex;
#         background-color: white;
#         border-radius: 3px ;
#         margin: 6px 8px;
#         padding: 3px 10px;
#         display: none;
#     }
#
#     .attribute.expanded {
#         display: block;
#     }
#
#     .attribute:hover {
#         background-color: #dfdfdf;
#     }
#
#
#     .attribute.join_keys {
#         background-color: #d9f7da;
#     }
#
#     .attribute.join_keys:hover {
#         background-color: #b6ddb8;
#     }
#
#     .attribute.join_keys.highlight {
#         outline: 3px solid #499568;
#     }
#
#     .attribute.measurements {
#         background-color: #ffd9ea;
#     }
#     .attribute.measurements.highlight {
#         outline: 3px solid #a16e76;
#     }
#
#     .attribute.measurements:hover {
#         background-color: #cd97af;
#     }
#
#     div.scroll {
#         overflow-x: hidden;
#         overflow-y: auto;
#         text-align:justify;
#     }
#
#     /* custom scrollbar */
#     ::-webkit-scrollbar {
#       width: 15px;
#     }
#
#     ::-webkit-scrollbar-track {
#       background-color: transparent;
#     }
#
#     ::-webkit-scrollbar-thumb {
#       background-color: #d6dee1;
#       border-radius: 20px;
#       border: solid transparent;
#       background-clip: content-box;
#     }
#
#     ::-webkit-scrollbar-thumb:hover {
#       background-color: #a8bbbf;
#     }
#
# </style>
# <div class="flex-container" style="font-family:sans-serif;font-size:12px;">
#     <div id="session1683674230schema" class="scroll"  style="background-color:#38425D;width:220px;height:100vh"></div>
#     <div><svg id="session1683674230" width="600" height="600"></svg></div>
# </div>
# <script src="https://d3js.org/d3.v5.min.js"></script>
# <script>
#
#     graph = {
#         "nodes": [{'id': 'sales', 'name': 'sales', 'measurements': [], 'attributes': ['tid', 'item_nbr'], 'join_keys': ['tid', 'item_nbr']}, {'id': 'holidays', 'name': 'holidays', 'measurements': [], 'attributes': ['locale_name', 'htype', 'locale', 'transferred', 'f2', 'date'], 'join_keys': ['date']}, {'id': 'oil', 'name': 'oil', 'measurements': [], 'attributes': ['dcoilwtico', 'f3', 'date'], 'join_keys': ['date']}, {'id': 'transactions', 'name': 'transactions', 'measurements': [], 'attributes': ['f5', 'transactions', 'tid', 'store_nbr', 'date'], 'join_keys': ['store_nbr', 'tid', 'date']}, {'id': 'stores', 'name': 'stores', 'measurements': [], 'attributes': ['cluster', 'city', 'state', 'f4', 'store_nbr', 'stype'], 'join_keys': ['store_nbr']}, {'id': 'items', 'name': 'items', 'measurements': [], 'attributes': ['perishable', 'item_nbr', 'family', 'f1', 'class'], 'join_keys': ['item_nbr']}],
#         "links": [{'source': 'sales', 'target': 'items', 'left_keys': (['item_nbr'], ['item_nbr']), 'right_keys': (['item_nbr'], ['item_nbr']), 'multiplicity': ['M', '1'], 'missing': [920, 0]}, {'source': 'sales', 'target': 'transactions', 'left_keys': (['tid'], ['tid']), 'right_keys': (['tid'], ['tid']), 'multiplicity': ['M', '1'], 'missing': [74219, 0]}, {'source': 'holidays', 'target': 'transactions', 'left_keys': (['date'], ['date']), 'right_keys': (['date'], ['date']), 'multiplicity': ['1', 'M'], 'missing': [0, 0]}, {'source': 'holidays', 'target': 'oil', 'left_keys': (['date'], ['date']), 'right_keys': (['date'], ['date']), 'multiplicity': ['1', '1'], 'missing': [0, 0]}, {'source': 'transactions', 'target': 'stores', 'left_keys': (['store_nbr'], ['store_nbr']), 'right_keys': (['store_nbr'], ['store_nbr']), 'multiplicity': ['M', '1'], 'missing': [0, 0]}]
#     }
#
#     console.log(graph)
#
#     // height and width of the whole visualization
#     var svg = d3.select("#session1683674230")
#     svg.on("mousedown", function() {
#         //reset all highlighting if background is clicked
#         unHighlightGraph();
#     })
#     var width = +svg.attr("width")
#     var height = +svg.attr("height");
#
#
#     // attributes for Join Graph
#     var circleRadius = 30
#     var linkDistance = 120
#
#     var triangleBase = 15
#     var triangleHeight =13
#     //svg elements can be clipped and marker defs are rendered in the corner for some reason
#     //this offset will move it out of the corner
#     var verticalOffset = 5
#
#     // this is to make the edges a bit longer.
#     var edgeLengthModifier = 3
#
#     var defs = svg.append('defs')
#
#     defs.append('marker')
#         .attr('id','arrowHead').attr('markerWidth','30').attr('markerHeight','30')
#         .attr('refX', circleRadius + triangleHeight-3).attr('refY',triangleBase/2 + verticalOffset)
#         .attr('orient', 'auto-start-reverse')
#         .attr('class','markers')
#         .attr('markerUnits', 'userSpaceOnUse')
#         .append('polyline')
#         // triangle ArrowHead
#         .attr('transform', `translate(0,${verticalOffset})`)
#         .attr('points',`0 ${triangleBase/2}, ${triangleHeight +edgeLengthModifier} 0, 0 ${triangleBase/2}, ${triangleHeight +edgeLengthModifier} ${triangleBase}`)
#         // .attr('points',`0 0, ${triangleHeight} ${triangleBase/2}, 0 ${triangleBase}`)
#
#     defs .append('marker')
#         .attr('id','arrowHeadHighlight').attr('markerWidth','100px').attr('markerHeight','100px')
#         .attr('refX', circleRadius + triangleHeight-3).attr('refY',triangleBase/2 + verticalOffset)
#         .attr('orient', 'auto-start-reverse').attr('class', 'markers highlight')
#         .attr('markerUnits', 'userSpaceOnUse')
#         .attr('transform', `translate(0,${verticalOffset})`)
#         .append('polyline')
#         .attr('class', 'markers highlight')
#         // triangle ArrowHead
#         .attr('transform', `translate(0,${verticalOffset})`)
#         .attr('points',`0 ${triangleBase/2}, ${triangleHeight +edgeLengthModifier} 0, 0 ${triangleBase/2}, ${triangleHeight +edgeLengthModifier} ${triangleBase}`)
#
#
#     var schemaArea = d3.select("#session1683674230schema")
#
#     var trueTypeOf = (obj) => Object.prototype.toString.call(obj).slice(8, -1).toLowerCase()
#
#     var schema = schemaArea
#         .selectAll("div")
#         .data(graph.nodes)
#         .enter()
#         .append("div")
#         .attr('class', 'relation')
#         .attr('id', (d)=>{return 'schema_' + d.name;})
#         .on("click", function (d) {
#             d3.select(this)
#             .selectAll("span")
#             .classed('expanded', function() {return !d3.select(this).classed("expanded");})
#         });
#
#     schema
#         .append("text")
#         .attr('class', 'relationName')
#         .text((d)=>{return d.id ;})
#
#     schema
#         .append("div")
#         .selectAll("span")
#         .data((d)=>{return d.measurements;})
#         .enter()
#         .append("span")
#         .attr('id', (d)=>{return 'attribute_' + d.name;})
#         .attr('class', 'attribute measurements')
#         .text((d)=>{return d.name;})
#         .on("click", function (d) {
#             d3.event.stopPropagation();
#             unHighlightGraph()
#             unHighlightSchema()
#             d3.select(this).classed('highlight',true)
#             d.edges.map((e) => highlightRelationEdge(e.left_rel, e.right_rel, e.color))
#             d.relations.map((r) => highlightRelationNode(r.name, r.color, r.text

# %% [markdown]
# # Training a Decision Tree with JoinBoost
#
# Once you have defined the join graph, you can train a decision tree over it using JoinBoost.

# %%
depth = 3
reg = DecisionTree(learning_rate=1, max_leaves=2 ** depth, max_depth=depth)

reg.fit(dataset)
reg.compute_rmse('train')[0]
# Out:
# joinboost_tmp_76
# 2535.0608391585865

# %% [markdown]
# # Training Gradient Boosting with JoinBoost
#
# After training a decision tree, you can train a Gradient Boosting model with JoinBoost for further improvement. In this example, we train a Gradient Boosting model with 10 iterations.
#
# As demonstrated, Gradient Boosting can further reduce the RMSE.

# %%
from joinboost.app import GradientBoosting

# Set the parameters for the Gradient Boosting model
reg = GradientBoosting(learning_rate=1, max_leaves=2 ** depth, max_depth=depth, iteration=10)

# Train the Gradient Boosting model on the dataset
reg.fit(dataset)

# Compute the Root Mean Square Error (RMSE) on the training set
train_rmse = reg.compute_rmse('train')[0]
print("Training RMSE for Gradient Boosting:", train_rmse)
# Out:
# joinboost_tmp_828
# Training RMSE for Gradient Boosting: 786.8773440907672

# %% [markdown]
# # Exploring JoinBoost Internals
#
# Internally, JoinBoost translates machine learning logic into SQL and executes SQL queries directly in your database without the need for data movement.
#
# To see the SQL queries generated by JoinBoost, you can enable debug mode when creating an executor instance:

# %%
# Create SparkExecutor instance with debug mode enabled
exe = DuckdbExecutor(con, debug=True)

dataset = JoinGraph(exe=exe)
dataset.add_relation("sales", [], y = 'Y')
dataset.add_relation("holidays", ["htype", "locale", "locale_name", "transferred","f2"])
dataset.add_relation("oil", ["dcoilwtico","f3"])
dataset.add_relation("transactions", ["transactions","f5"])
dataset.add_relation("stores", ["city","state","stype","cluster","f4"])
dataset.add_relation("items", ["family","class","perishable","f1"])
dataset.add_join("sales", "items", ["item_nbr"], ["item_nbr"])
dataset.add_join("sales", "transactions", ["tid"], ["tid"])
dataset.add_join("transactions", "stores", ["store_nbr"], ["store_nbr"])
dataset.add_join("transactions", "holidays", ["date"], ["date"])
dataset.add_join("holidays", "oil", ["date"], ["date"])

# Set the parameters for the decision tree
depth = 3
reg = DecisionTree(learning_rate=1, max_leaves=2 ** depth, max_depth=depth)

# Train the decision tree on the dataset
reg.fit(dataset)

# Compute the Root Mean Square Error (RMSE) on the training set
train_rmse = reg.compute_rmse('train')[0]
print("Training RMSE:", train_rmse)
# Out:
# PRAGMA table_info(sales)
# 0.005413532257080078
# [(0, 'item_nbr', 'BIGINT', False, None, False), (1, 'unit_sales', 'DOUBLE', False, None, False), (2, 'onpromotion', 'BIGINT', False, None, False), (3, 'tid', 'BIGINT', False, None, False), (4, 'Y', 'DOUBLE', False, None, False)]
# PRAGMA table_info(holidays)
# 0.0008273124694824219
# [(0, 'date', 'BIGINT', False, None, False), (1, 'htype', 'BIGINT', False, None, False), (2, 'locale', 'BIGINT', False, None, False), (3, 'locale_name', 'BIGINT', False, None, False), (4, 'transferred', 'BIGINT', False, None, False), (5, 'f2', 'BIGINT', False, None, False)]
# PRAGMA table_info(oil)
# 0.0007359981536865234
# [(0, 'date', 'BIGINT', False, None, False), (1, 'dcoilwtico', 'BIGINT', False, None, False), (2, 'f3', 'BIGINT', False, None, False)]
# PRAGMA table_info(transactions)
# 0.0009200572967529297
# [(0, 'date', 'BIGINT', False, None, False), (1, 'store_nbr', 'BIGINT', False, None, False), (2, 'transactions', 'BIGINT', False, None, False), (3, 'tid', 'BIGINT', False, None, False), (4, 'f5', 'BIGINT', False, None, False)]
# PRAGMA table_info(stores)
# 0.0008711814880371094
# [(0, 'store_nbr', 'BIGINT', False, None, False), (1, 'city', 'BIGINT', False, None, False), (2, 'state', 'BIGINT', False, None, False), (3, 'stype', 'BIGINT', False, None, False), (4, 'cluster', 'BIGINT', False, None, False), (5, 'f4', 'BIGINT', False, None, False)]
# PRAGMA table_info(items)
# 0.0008897781372070312
# [(0, 'item_nbr', 'BIGINT', False, None, False), (1, 'family', 'BIGINT', False, None, False), (2, 'class', 'BIGINT', False, None, False), (3, 'perishable', 'BIGINT', False, None, False), (4, 'f1', 'BIGINT', False, None, False)]
# SELECT COUNT(*) AS count
# FROM ((SELECT item_nbr AS join_key
# FROM sales
# GROUP BY item_nbr
# ) EXCEPT (SELECT item_nbr AS join_key
# FROM items
# GROUP BY item_nbr
# ))
#
# 0.0015935897827148438
# [(0,)]
# SELECT COUNT(*) AS count
# FROM ((SELECT item_nbr AS join_key
# FROM items
# GROUP BY item_nbr
# ) EXCEPT (SELECT item_nbr AS join_key
# FROM sales
# GROUP BY item_nbr
# ))
#
# 0.0018086433410644531
# [(920,)]
# SELECT MAX(count) AS max_count
# FROM (SELECT COUNT(item_nbr) AS count
# FROM sales
# GROUP BY item_nbr
# )
#
# 0.0012760162353515625
# [(14,)]
# SELECT MAX(count) AS max_count
# FROM (SELECT COUNT(item_nbr) AS count
# FROM items
# GROUP BY item_nbr
# )
#
# 0.0007653236389160156
# [(1,)]
# SELECT COUNT(*) AS count
# FROM ((SELECT tid AS join_key
# FROM sales
# GROUP BY tid
# ) EXCEPT (SELECT tid AS join_key
# FROM transactions
# GROUP BY tid
# ))
#
# 0.018758058547973633
# [(0,)]
# SELECT COUNT(*) AS count
# FROM ((SELECT tid AS join_key
# FROM transactions
# GROUP BY tid
# ) EXCEPT (SELECT tid AS join_key
# FROM sales
# GROUP BY tid
# ))
#
# 0.026367664337158203
# [(74219,)]
# SELECT MAX(count) AS max_count
# FROM (SELECT COUNT(tid) AS count
# FROM sales
# GROUP BY tid
# )
#
# 0.0026121139526367188
# [(4,)]
# SELECT MAX(count) AS max_count
# FROM (SELECT COUNT(tid) AS count
# FROM transactions
# GROUP BY tid
# )
#
# 0.019703388214111328
# [(1,)]
# SELECT COUNT(*) AS count
# FROM ((SELECT store_nbr AS join_key
# FROM transactions
# GROUP BY store_nbr
# ) EXCEPT (SELECT store_nbr AS join_key
# FROM stores
# GROUP BY store_nbr
# ))
#
# 0.001524209976196289
# [(0,)]
# SELECT COUNT(*) AS count
# FROM ((SELECT store_nbr AS join_key
# FROM stores
# GROUP BY store_nbr
# ) EXCEPT (SELECT store_nbr AS join_key
# FROM transactions
# GROUP BY store_nbr
# ))
#
# 0.0014629364013671875
# [(0,)]
# SELECT MAX(count) AS max_count
# FROM (SELECT COUNT(store_nbr) AS count
# FROM transactions
# GROUP BY store_nbr
# )
#
# 0.0013375282287597656
# [(1679,)]
# SELECT MAX(count) AS max_count
# FROM (SELECT COUNT(store_nbr) AS count
# FROM stores
# GROUP BY store_nbr
# )
#
# 0.0011360645294189453
# [(1,)]
# SELECT COUNT(*) AS count
# FROM ((SELECT date AS join_key
# FROM transactions
# GROUP BY date
# ) EXCEPT (SELECT date AS join_key
# FROM holidays
# GROUP BY date
# ))
#
# 0.0016057491302490234
# [(0,)]
# SELECT COUNT(*) AS count
# FROM ((SELECT date AS join_key
# FROM holidays
# GROUP BY date
# ) EXCEPT (SELECT date AS join_key
# FROM transactions
# GROUP BY date
# ))
#
# 0.002072572708129883
# [(0,)]
# SELECT MAX(count) AS max_count
# FROM (SELECT COUNT(date) AS count
# FROM transactions
# GROUP BY date
# )
#
# 0.0016438961029052734
# [(54,)]
# SELECT MAX(count) AS max_count
# FROM (SELECT COUNT(date) AS count
# FROM holidays
# GROUP BY date
# )
#
# 0.0012340545654296875
# [(1,)]
# SELECT COUNT(*) AS count
# FROM ((SELECT date AS join_key
# FROM holidays
# GROUP BY date
# ) EXCEPT (SELECT date AS join_key
# FROM oil
# GROUP BY date
# ))
#
# 0.0013608932495117188
# [(0,)]
# SELECT COUNT(*) AS count
# FROM ((SELECT date AS join_key
# FROM oil
# GROUP BY date
# ) EXCEPT (SELECT date AS join_key
# FROM holidays
# GROUP BY date
# ))
#
# 0.001383066177368164
# [(0,)]
# SELECT MAX(count) AS max_count
# FROM (SELECT COUNT(date) AS count
# FROM holidays
# GROUP BY date
# )
#
# 0.0010521411895751953
# [(1,)]
# SELECT MAX(count) AS max_count
# FROM (SELECT COUNT(date) AS count
# FROM oil
# GROUP BY date
# )
#
# 0.001026153564453125
# [(1,)]
# PRAGMA table_info(sales)
# 0.0008935928344726562
# [(0, 'item_nbr', 'BIGINT', False, None, False), (1, 'unit_sales', 'DOUBLE', False, None, False), (2, 'onpromotion', 'BIGINT', False, None, False), (3, 'tid', 'BIGINT', False, None, False), (4, 'Y', 'DOUBLE', False, None, False)]
# PRAGMA table_info(holidays)
# 0.0009236335754394531
# [(0, 'date', 'BIGINT', False, None, False), (1, 'htype', 'BIGINT', False, None, False), (2, 'locale', 'BIGINT', False, None, False), (3, 'locale_name', 'BIGINT', False, None, False), (4, 'transferred', 'BIGINT', False, None, False), (5, 'f2', 'BIGINT', False, None, False)]
# PRAGMA table_info(oil)
# 0.0009090900421142578
# [(0, 'date', 'BIGINT', False, None, False), (1, 'dcoilwtico', 'BIGINT', False, None, False), (2, 'f3', 'BIGINT', False, None, False)]
# PRAGMA table_info(transactions)
# 0.0010576248168945312
# [(0, 'date', 'BIGINT', False, None, False), (1, 'store_nbr', 'BIGINT', False, None, False), (2, 'transactions', 'BIGINT', False, None, False), (3, 'tid', 'BIGINT', False, None, False), (4, 'f5', 'BIGINT', False, None, False)]
# PRAGMA table_info(stores)
# 0.00099945068359375
# [(0, 'store_nbr', 'BIGINT', False, None, False), (1, 'city', 'BIGINT', False, None, False), (2, 'state', 'BIGINT', False, None, False), (3, 'stype', 'BIGINT', False, None, False), (4, 'cluster', 'BIGINT', False, None, False), (5, 'f4', 'BIGINT', False, None, False)]
# PRAGMA table_info(items)
# 0.0009784698486328125
# [(0, 'item_nbr', 'BIGINT', False, None, False), (1, 'family', 'BIGINT', False, None, False), (2, 'class', 'BIGINT', False, None, False), (3, 'perishable', 'BIGINT', False, None, False), (4, 'f1', 'BIGINT', False, None, False)]
# PRAGMA table_info(sales)
# 0.0010209083557128906
# [(0, 'item_nbr', 'BIGINT', False, None, False), (1, 'unit_sales', 'DOUBLE', False, None, False), (2, 'onpromotion', 'BIGINT', False, None, False), (3, 'tid', 'BIGINT', False, None, False), (4, 'Y', 'DOUBLE', False, None, False)]
# PRAGMA table_info(holidays)
# 0.001024007797241211
# [(0, 'date', 'BIGINT', False, None, False), (1, 'htype', 'BIGINT', False, None, False), (2, 'locale', 'BIGINT', False, None, False), (3, 'locale_name', 'BIGINT', False, None, False), (4, 'transferred', 'BIGINT', False, None, False), (5, 'f2', 'BIGINT', False, None, False)]
# PRAGMA table_info(oil)
# 0.0009920597076416016
# [(0, 'date', 'BIGINT', False, None, False), (1, 'dcoilwtico', 'BIGINT', False, None, False), (2, 'f3', 'BIGINT', False, None, False)]
# PRAGMA table_info(transactions)
# 0.0009908676147460938
# [(0, 'date', 'BIGINT', False, None, False), (1, 'store_nbr', 'BIGINT', False, None, False), (2, 'transactions', 'BIGINT', False, None, False), (3, 'tid', 'BIGINT', False, None, False), (4, 'f5', 'BIGINT', False, None, False)]
# PRAGMA table_info(stores)
# 0.0009028911590576172
# [(0, 'store_nbr', 'BIGINT', False, None, False), (1, 'city', 'BIGINT', False, None, False), (2, 'state', 'BIGINT', False, None, False), (3, 'stype', 'BIGINT', False, None, False), (4, 'cluster', 'BIGINT', False, None, False), (5, 'f4', 'BIGINT', False, None, False)]
# PRAGMA table_info(items)
# 0.0005431175231933594
# [(0, 'item_nbr', 'BIGINT', False, None, False), (1, 'family', 'BIGINT', False, None, False), (2, 'class', 'BIGINT', False, None, False), (3, 'perishable', 'BIGINT', False, None, False), (4, 'f1', 'BIGINT', False, None, False)]
# PRAGMA table_info(sales)
# 0.0005502700805664062
# [(0, 'item_nbr', 'BIGINT', False, None, False), (1, 'unit_sales', 'DOUBLE', False, None, False), (2, 'onpromotion', 'BIGINT', False, None, False), (3, 'tid', 'BIGINT', False, None, False), (4, 'Y', 'DOUBLE', False, None, False)]
# PRAGMA table_info(holidays)
# 0.0008697509765625
# [(0, 'date', 'BIGINT', False, None, False), (1, 'htype', 'BIGINT', False, None, False), (2, 'locale', 'BIGINT', False, None, False), (3, 'locale_name', 'BIGINT', False, None, False), (4, 'transferred', 'BIGINT', False, None, False), (5, 'f2', 'BIGINT', False, None, False)]
# PRAGMA table_info(oil)
# 0.0008924007415771484
# [(0, 'date', 'BIGINT', False, None, False), (1, 'dcoilwtico', 'BIGINT', False, None, False), (2, 'f3', 'BIGINT', False, None, False)]
# PRAGMA table_info(transactions)
# 0.0011050701141357422
# [(0, 'date', 'BIGINT', False, None, False), (1, 'store_nbr', 'BIGINT', False, None, False), (2, 'transactions', 'BIGINT', False, None, False), (3, 'tid', 'BIGINT', False, None, False), (4, 'f5', 'BIGINT', False, None, False)]
# PRAGMA table_info(stores)
# 0.0008754730224609375
# [(0, 'store_nbr', 'BIGINT', False, None, False), (1, 'city', 'BIGINT', False, None, False), (2, 'state', 'BIGINT', False, None, False), (3, 'stype', 'BIGINT', False, None, False), (4, 'cluster', 'BIGINT', False, None, False), (5, 'f4', 'BIGINT', False, None, False)]
# PRAGMA table_info(items)
# 0.0008769035339355469
# [(0, 'item_nbr', 'BIGINT', False, None, False), (1, 'family', 'BIGINT', False, None, False), (2, 'class', 'BIGINT', False, None, False), (3, 'perishable', 'BIGINT', False, None, False), (4, 'f1', 'BIGINT', False, None, False)]
# SELECT SUM(Y) AS s, SUM(1) AS c
# FROM sales
#
# 0.0010852813720703125
# [(-48426358.418535136, 10000)]
# CREATE OR REPLACE TABLE joinboost_tmp_0 AS SELECT (Y) - (-4842.635841853514) AS s, 1 AS c, tid AS tid, item_nbr AS item_nbr
# FROM sales
#
# 0.002802133560180664
# [(10000,)]
# CREATE OR REPLACE TABLE joinboost_tmp_1 AS SELECT SUM(s) AS s, SUM(c) AS c, joinboost_tmp_0.item_nbr AS item_nbr
# FROM joinboost_tmp_0
# GROUP BY joinboost_tmp_0.item_nbr
#
# 0.002659320831298828
# [(3114,)]
# CREATE OR REPLACE TABLE joinboost_tmp_2 AS SELECT SUM(s) AS s, SUM(c) AS c, joinboost_tmp_0.tid AS tid
# FROM joinboost_tmp_0
# GROUP BY joinboost_tmp_0.tid
#
# 0.005501270294189453
# [(9387,)]
# CREATE OR REPLACE TABLE joinboost_tmp_3 AS SELECT SUM(s) AS s, SUM(c) AS c, transactions.store_nbr AS store_nbr
# FROM joinboost_tmp_2,transactions
# WHERE joinboost_tmp_2.tid IS NOT DISTINCT FROM transactions.tid
# GROUP BY transactions.store_nbr
#
# 0.00438237190246582
# [(54,)]
# CREATE OR REPLACE TABLE joinboost_tmp_4 AS SELECT SUM(s) AS s, SUM(c) AS c, transactions.date AS date
# FROM joinboost_tmp_2,transactions
# WHERE joinboost_tmp_2.tid IS NOT DISTINCT FROM transactions.tid
# GROUP BY transactions.date
#
# 0.004343986511230469
# [(1663,)]
# CREATE OR REPLACE TABLE joinboost_tmp_5 AS SELECT SUM(s) AS s, SUM(c) AS c, holidays.date AS date
# FROM joinboost_tmp_4,holidays
# WHERE joinboost_tmp_4.date IS NOT DISTINCT FROM holidays.date
# GROUP BY holidays.date
#
# 0.002187967300415039
# [(1663,)]
# SELECT htype AS htype, CASE WHEN 10000 > c THEN ((s/c)*s + (0-s)/(10000-c)*(0-s)) ELSE 0 END AS criteria, s AS s, c AS c
# FROM (SELECT SUM(s) OVER joinboost_window  AS s, SUM(c) OVER joinboost_window  AS c, htype AS htype
# FROM (SELECT SUM(s) AS s, SUM(c) AS c, holidays.htype AS htype
# FROM joinboost_tmp_4,holidays
# WHERE joinboost_tmp_4.date IS NOT DISTINCT FROM holidays.date
# GROUP BY holidays.htype
# )
# WINDOW joinboost_window AS (ORDER BY htype)
# )
# ORDER BY criteria DESC
# LIMIT 1
#
# 0.0029058456420898438
# [(1, 168736812.0120532, 200417.54076663556, 244)]
# SELECT locale AS locale, CASE WHEN 10000 > c THEN ((s/c)*s + (0-s)/(10000-c)*(0-s)) ELSE 0 END AS criteria, s AS s, c AS c
# FROM (SELECT SUM(s) OVER joinboost_window  AS s, SUM(c) OVER joinboost_window  AS c, locale AS locale
# FROM (SELECT SUM(s) AS s, SUM(c) AS c, holidays.locale AS locale
# FROM joinboost_tmp_4,holidays
# WHERE joinboost_tmp_4.date IS NOT DISTINCT FROM holidays.date
# GROUP BY holidays.locale
# )
# WINDOW joinboost_window AS (ORDER BY locale)
# )
# ORDER BY criteria DESC
# LIMIT 1
#
# 0.002443552017211914
# [(2, 118422426.374113, -117018.44053954785, 9883)]
# SELECT locale_name AS locale_name, CASE WHEN 10000 > c THEN ((s/c)*s + (0-s)/(10000-c)*(0-s)) ELSE 0 END AS criteria, s AS s, c AS c
# FROM (SELECT SUM(s) OVER joinboost_window  AS s, SUM(c) OVER joinboost_window  AS c, locale_name AS locale_name
# FROM (SELECT SUM(s) AS s, SUM(c) AS c, holidays.locale_name AS locale_name
# FROM joinboost_tmp_4,holidays
# WHERE joinboost_tmp_4.date IS NOT DISTINCT FROM holidays.date
# GROUP BY holidays.locale_name
# )
# WINDOW joinboost_window AS (ORDER BY locale_name)
# )
# ORDER BY criteria DESC
# LIMIT 1
#
# 0.004143953323364258
# [(21, 197631420.37814862, -79397.53141410653, 9968)]
# SELECT transferred AS transferred, CASE WHEN 10000 > c THEN ((s/c)*s + (0-s)/(10000-c)*(0-s)) ELSE 0 END AS criteria, s AS s, c AS c
# FROM (SELECT SUM(s) OVER joinboost_window  AS s, SUM(c) OVER joinboost_window  AS c, transferred AS transferred
# FROM (SELECT SUM(s) AS s, SUM(c) AS c, holidays.transferred AS transferred
# FROM joinboost_tmp_4,holidays
# WHERE joinboost_tmp_4.date IS NOT DISTINCT FROM holidays.date
# GROUP BY holidays.transferred
# )
# WINDOW joinboost_window AS (ORDER BY transferred)
# )
# ORDER BY criteria DESC
# LIMIT 1
#
# 0.0028815269470214844
# [(1, 466005020.6998564, -170802.10452853085, 9937)]
# SELECT f2 AS f2, CASE WHEN 10000 > c THEN ((s/c)*s + (0-s)/(10000-c)*(0-s)) ELSE 0 END AS criteria, s AS s, c AS c
# FROM (SELECT SUM(s) OVER joinboost_window  AS s, SUM(c) OVER joinboost_window  AS c, f2 AS f2
# FROM (SELECT SUM(s) AS s, SUM(c) AS c, holidays.f2 AS f2
# FROM joinboost_tmp_4,holidays
# WHERE joinboost_tmp_4.date IS NOT DISTINCT FROM holidays.date
# GROUP BY holidays.f2
# )
# WINDOW joinboost_window AS (ORDER BY f2)
# )
# ORDER BY criteria DESC
# LIMIT 1
#
# 0.010104894638061523
# [(871, 211553954.8437869, -519499.1424813168, 8499)]
# SELECT dcoilwtico AS dcoilwtico, CASE WHEN 10000 > c THEN ((s/c)*s + (0-s)/(10000-c)*(0-s)) ELSE 0 END AS criteria, s AS s, c AS c
# FROM (SELECT SUM(s) OVER joinboost_window  AS s, SUM(c) OVER joinboost_window  AS c, dcoilwtico AS dcoilwtico
# FROM (SELECT SUM(s) AS s, SUM(c) AS c, oil.dcoilwtico AS dcoilwtico
# FROM joinboost_tmp_5,oil
# WHERE joinboost_tmp_5.date IS NOT DISTINCT FROM oil.date
# GROUP BY oil.dcoilwtico
# )
# WINDOW joinboost_window AS (ORDER BY dcoilwtico)
# )
# ORDER BY criteria DESC
# LIMIT 1
#
# 0.0035681724548339844
# [(7, 142183162.96198222, 408489.6917283345, 8642)]
# SELECT f3 AS f3, CASE WHEN 10000 > c THEN ((s/c)*s + (0-s)/(10000-c)*(0-s)) ELSE 0 END AS criteria, s AS s, c AS c
# FROM (SELECT SUM(s) OVER joinboost_window  AS s, SUM(c) OVER joinboost_window  AS c, f3 AS f3
# FROM (SELECT SUM(s) AS s, SUM(c) AS c, oil.f3 AS f3
# FROM joinboost_tmp_5,oil
# WHERE joinboost_tmp_5.date IS NOT DISTINCT FROM oil.date
# GROUP BY oil.f3
# )
# WINDOW joinboost_window AS (ORDER BY f3)
# )
# ORDER BY criteria DESC
# LIMIT 1
#
# 0.003869771957397461
# [(474, 65989715683.674286, 12842936.727770234, 5071)]
# SELECT transactions AS transactions, CASE WHEN 10000 > c THEN ((s/c)*s + (0-s)/(10000-c)*(0-s)) ELSE 0 END AS criteria, s AS s, c AS c
# FROM (SELECT SUM(s) OVER joinboost_window  AS s, SUM(c) OVER joinboost_window  AS c, transactions AS transactions
# FROM (SELECT SUM(s) AS s, SUM(c) AS c, transactions.transactions AS transactions
# FROM joinboost_tmp_2,transactions
# WHERE joinboost_tmp_2.tid IS NOT DISTINCT FROM transactions.tid
# GROUP BY transactions.transactions
# )
# WINDOW joinboost_window AS (ORDER BY transactions)
# )
# ORDER BY criteria DESC
# LIMIT 1
#
# 0.004686594009399414
# [(4, 2852420719.9044833, -1981438.6849245278, 8352)]
# SELECT f5 AS f5, CASE WHEN 10000 > c THEN ((s/c)*s + (0-s)/(10000-c)*(0-s)) ELSE 0 END AS criteria, s AS s, c AS c
# FROM (SELECT SUM(s) OVER joinboost_window  AS s, SUM(c) OVER joinboost_window  AS c, f5 AS f5
# FROM (SELECT SUM(s) AS s, SUM(c) AS c, transactions.f5 AS f5
# FROM joinboost_tmp_2,transactions
# WHERE joinboost_tmp_2.tid IS NOT DISTINCT FROM transactions.tid
# GROUP BY transactions.f5
# )
# WINDOW joinboost_window AS (ORDER BY f5)
# )
# ORDER BY criteria DESC
# LIMIT 1
#
# 0.0072784423828125
# [(554, 69568693129.35388, -13107030.921443088, 5553)]
# SELECT city AS city, CASE WHEN 10000 > c THEN ((s/c)*s + (0-s)/(10000-c)*(0-s)) ELSE 0 END AS criteria, s AS s, c AS c
# FROM (SELECT SUM(s) OVER joinboost_window  AS s, SUM(c) OVER joinboost_window  AS c, city AS city
# FROM (SELECT SUM(s) AS s, SUM(c) AS c, stores.city AS city
# FROM joinboost_tmp_3,stores
# WHERE joinboost_tmp_3.store_nbr IS NOT DISTINCT FROM stores.store_nbr
# GROUP BY stores.city
# )
# WINDOW joinboost_window AS (ORDER BY city)
# )
# ORDER BY criteria DESC
# LIMIT 1
#
# 0.002306222915649414
# [(11, 5140815109.160369, -3502237.0084838388, 3932)]
# SELECT state AS state, CASE WHEN 10000 > c THEN ((s/c)*s + (0-s)/(10000-c)*(0-s)) ELSE 0 END AS criteria, s AS s, c AS c
# FROM (SELECT SUM(s) OVER joinboost_window  AS s, SUM(c) OVER joinboost_window  AS c, state AS state
# FROM (SELECT SUM(s) AS s, SUM(c) AS c, stores.state AS state
# FROM joinboost_tmp_3,stores
# WHERE joinboost_tmp_3.store_nbr IS NOT DISTINCT FROM stores.store_nbr
# GROUP BY stores.state
# )
# WINDOW joinboost_window AS (ORDER BY state)
# )
# ORDER BY criteria DESC
# LIMIT 1
#
# 0.002176046371459961
# [(2, 1130689136.1982622, -932232.0540113177, 839)]
# SELECT stype AS stype, CASE WHEN 10000 > c THEN ((s/c)*s + (0-s)/(10000-c)*(0-s)) ELSE 0 END AS criteria, s AS s, c AS c
# FROM (SELECT SUM(s) OVER joinboost_window  AS s, SUM(c) OVER joinboost_window  AS c, stype AS stype
# FROM (SELECT SUM(s) AS s, SUM(c) AS c, stores.stype AS stype
# FROM joinboost_tmp_3,stores
# WHERE joinboost_tmp_3.store_nbr IS NOT DISTINCT FROM stores.store_nbr
# GROUP BY stores.stype
# )
# WINDOW joinboost_window AS (ORDER BY stype)
# )
# ORDER BY criteria DESC
# LIMIT 1
#
# 0.0023162364959716797
# [(0, 1207307634.5501747, 1423341.0547169037, 2133)]
# SELECT cluster AS cluster, CASE WHEN 10000 > c THEN ((s/c)*s + (0-s)/(10000-c)*(0-s)) ELSE 0 END AS criteria, s AS s, c AS c
# FROM (SELECT SUM(s) OVER joinboost_window  AS s, SUM(c) OVER joinboost_window  AS c, cluster AS cluster
# FROM (SELECT SUM(s) AS s, SUM(c) AS c, stores.cluster AS cluster
# FROM joinboost_tmp_3,stores
# WHERE joinboost_tmp_3.store_nbr IS NOT DISTINCT FROM stores.store_nbr
# GROUP BY stores.cluster
# )
# WINDOW joinboost_window AS (ORDER BY cluster)
# )
# ORDER BY criteria DESC
# LIMIT 1
#
# 0.0022003650665283203
# [(11, 5052737542.110666, -3278383.5630155993, 6931)]
# SELECT f4 AS f4, CASE WHEN 10000 > c THEN ((s/c)*s + (0-s)/(10000-c)*(0-s)) ELSE 0 END AS criteria, s AS s, c AS c
# FROM (SELECT SUM(s) OVER joinboost_window  AS s, SUM(c) OVER joinboost_window  AS c, f4 AS f4
# FROM (SELECT SUM(s) AS s, SUM(c) AS c, stores.f4 AS f4
# FROM joinboost_tmp_3,stores
# WHERE joinboost_tmp_3.store_nbr IS NOT DISTINCT FROM stores.store_nbr
# GROUP BY stores.f4
# )
# WINDOW joinboost_window AS (ORDER BY f4)
# )
# ORDER BY criteria DESC
# LIMIT 1
#
# 0.002908468246459961
# [(496, 72649817168.64633, 13439060.470843477, 4626)]
# SELECT family AS family, CASE WHEN 10000 > c THEN ((s/c)*s + (0-s)/(10000-c)*(0-s)) ELSE 0 END AS criteria, s AS s, c AS c
# FROM (SELECT SUM(s) OVER joinboost_window  AS s, SUM(c) OVER joinboost_window  AS c, family AS family
# FROM (SELECT SUM(s) AS s, SUM(c) AS c, items.family AS family
# FROM joinboost_tmp_1,items
# WHERE joinboost_tmp_1.item_nbr IS NOT DISTINCT FROM items.item_nbr
# GROUP BY items.family
# )
# WINDOW joinboost_window AS (ORDER BY family)
# )
# ORDER BY criteria DESC
# LIMIT 1
#
# 0.0029044151306152344
# [(10, 51642402.53567443, -357519.37758925394, 4501)]
# SELECT class AS class, CASE WHEN 10000 > c THEN ((s/c)*s + (0-s)/(10000-c)*(0-s)) ELSE 0 END AS criteria, s AS s, c AS c
# FROM (SELECT SUM(s) OVER joinboost_window  AS s, SUM(c) OVER joinboost_window  AS c, class AS class
# FROM (SELECT SUM(s) AS s, SUM(c) AS c, items.class AS class
# FROM joinboost_tmp_1,items
# WHERE joinboost_tmp_1.item_nbr IS NOT DISTINCT FROM items.item_nbr
# GROUP BY items.class
# )
# WINDOW joinboost_window AS (ORDER BY class)
# )
# ORDER BY criteria DESC
# LIMIT 1
#
# 0.0034122467041015625
# [(163, 83642709.4781794, 427079.1146182239, 6787)]
# SELECT perishable AS perishable, CASE WHEN 10000 > c THEN ((s/c)*s + (0-s)/(10000-c)*(0-s)) ELSE 0 END AS criteria, s AS s, c AS c
# FROM (SELECT SUM(s) OVER joinboost_window  AS s, SUM(c) OVER joinboost_window  AS c, perishable AS perishable
# FROM (SELECT SUM(s) AS s, SUM(c) AS c, items.perishable AS perishable
# FROM joinboost_tmp_1,items
# WHERE joinboost_tmp_1.item_nbr IS NOT DISTINCT FROM items.item_nbr
# GROUP BY items.perishable
# )
# WINDOW joinboost_window AS (ORDER BY perishable)
# )
# ORDER BY criteria DESC
# LIMIT 1
#
# 0.0027604103088378906
# [(0, 439305.537234792, 29083.604629384827, 7397)]
# SELECT f1 AS f1, CASE WHEN 10000 > c THEN ((s/c)*s + (0-s)/(10000-c)*(0-s)) ELSE 0 END AS criteria, s AS s, c AS c
# FROM (SELECT SUM(s) OVER joinboost_window  AS s, SUM(c) OVER joinboost_window  AS c, f1 AS f1
# FROM (SELECT SUM(s) AS s, SUM(c) AS c, items.f1 AS f1
# FROM joinboost_tmp_1,items
# WHERE joinboost_tmp_1.item_nbr IS NOT DISTINCT FROM items.item_nbr
# GROUP BY items.f1
# )
# WINDOW joinboost_window AS (ORDER BY f1)
# )
# ORDER BY criteria DESC
# LIMIT 1
#
# 0.003908634185791016
# [(594, 1122915228.3785768, -1656944.2962775603, 5742)]
# CREATE OR REPLACE TABLE joinboost_tmp_6 AS SELECT stores.store_nbr AS store_nbr
# FROM joinboost_tmp_3,stores
# WHERE stores.f4 <= 496 AND joinboost_tmp_3.store_nbr IS NOT DISTINCT FROM stores.store_nbr
# GROUP BY stores.store_nbr
#
# 0.0012042522430419922
# [(25,)]
# CREATE OR REPLACE TABLE joinboost_tmp_7 AS SELECT SUM(s) AS s, SUM(c) AS c, transactions.date AS date
# FROM joinboost_tmp_6,joinboost_tmp_2,transactions
# WHERE joinboost_tmp_6.store_nbr IS NOT DISTINCT FROM transactions.store_nbr AND joinboost_tmp_2.tid IS NOT DISTINCT FROM transactions.tid
# GROUP BY transactions.date
#
# 0.005620241165161133
# [(1521,)]
# CREATE OR REPLACE TABLE joinboost_tmp_8 AS SELECT SUM(s) AS s, SUM(c) AS c, holidays.date AS date
# FROM joinboost_tmp_7,holidays
# WHERE joinboost_tmp_7.date IS NOT DISTINCT FROM holidays.date
# GROUP BY holidays.date
#
# 0.0021860599517822266
# [(1521,)]
# CREATE OR REPLACE TABLE joinboost_tmp_9 AS SELECT transactions.tid AS tid
# FROM joinboost_tmp_6,joinboost_tmp_2,transactions
# WHERE joinboost_tmp_6.store_nbr IS NOT DISTINCT FROM transactions.store_nbr AND joinboost_tmp_2.tid IS NOT DISTINCT FROM transactions.tid
# GROUP BY transactions.tid
#
# 0.004927873611450195
# [(4329,)]
# CREATE OR REPLACE TABLE joinboost_tmp_10 AS SELECT SUM(s) AS s, SUM(c) AS c, joinboost_tmp_0.item_nbr AS item_nbr
# FROM joinboost_tmp_9,joinboost_tmp_0
# WHERE joinboost_tmp_9.tid IS NOT DISTINCT FROM joinboost_tmp_0.tid
# GROUP BY joinboost_tmp_0.item_nbr
#
# 0.0025908946990966797
# [(2394,)]
# CREATE OR REPLACE TABLE joinboost_tmp_11 AS SELECT stores.store_nbr AS store_nbr
# FROM joinboost_tmp_3,stores
# WHERE stores.f4 > 496 AND joinboost_tmp_3.store_nbr IS NOT DISTINCT FROM stores.store_nbr
# GROUP BY stores.store_nbr
#
# 0.0013995170593261719
# [(29,)]
# CREATE OR REPLACE TABLE joinboost_tmp_12 AS SELECT SUM(s) AS s, SUM(c) AS c, transactions.date AS date
# FROM joinboost_tmp_11,joinboost_tmp_2,transactions
# WHERE joinboost_tmp_11.store_nbr IS NOT DISTINCT FROM transactions.store_nbr AND joinboost_tmp_2.tid IS NOT DISTINCT FROM transactions.tid
# GROUP BY transactions.date
#
# 0.004984378814697266
# [(1572,)]
# CREATE OR REPLACE TABLE joinboost_tmp_13 AS SELECT SUM(s) AS s, SUM(c) AS c, holidays.date AS date
# FROM joinboost_tmp_12,holidays
# WHERE joinboost_tmp_12.date IS NOT DISTINCT FROM holidays.date
# GROUP BY holidays.date
#
# 0.002162933349609375
# [(1572,)]
# CREATE OR REPLACE TABLE joinboost_tmp_14 AS SELECT transactions.tid AS tid
# FROM joinboost_tmp_11,joinboost_tmp_2,transactions
# WHERE joinboost_tmp_11.store_nbr IS NOT DISTINCT FROM transactions.store_nbr AND joinboost_tmp_2.tid IS NOT DISTINCT FROM transactions.tid
# GROUP BY transactions.tid
#
# 0.004725456237792969
# [(5058,)]
# CREATE OR REPLACE TABLE joinboost_tmp_15 AS SELECT SUM(s) AS s, SUM(c) AS c, joinboost_tmp_0.item_nbr AS item_nbr
# FROM joinboost_tmp_14,joinboost_tmp_0
# WHERE joinboost_tmp_14.tid IS NOT DISTINCT FROM joinboost_tmp_0.tid
# GROUP BY joinboost_tmp_0.item_nbr
#
# 0.0025784969329833984
# [(2500,)]
# SELECT htype AS htype, CASE WHEN 4626 > c THEN ((s/c)*s + (13439060.470843477-s)/(4626-c)*(13439060.470843477-s)) ELSE 0 END AS criteria, s AS s, c AS c
# FROM (SELECT SUM(s) OVER joinboost_window  AS s, SUM(c) OVER joinboost_window  AS c, htype AS htype
# FROM (SELECT SUM(s) AS s, SUM(c) AS c, holidays.htype AS htype
# FROM joinboost_tmp_7,holidays
# WHERE joinboost_tmp_7.date IS NOT DISTINCT FROM holidays.date
# GROUP BY holidays.htype
# )
# WINDOW joinboost_window AS (ORDER BY htype)
# )
# ORDER BY criteria DESC
# LIMIT 1
#
# 0.0024077892303466797
# [(1, 39102343929.19273, 429343.8198676767, 119)]
# SELECT locale AS locale, CASE WHEN 4626 > c THEN ((s/c)*s + (13439060.470843477-s)/(4626-c)*(13439060.470843477-s)) ELSE 0 END AS criteria, s AS s, c AS c
# FROM (SELECT SUM(s) OVER joinboost_window  AS s, SUM(c) OVER joinboost_window  AS c, locale AS locale
# FROM (SELECT SUM(s) AS s, SUM(c) AS c, holidays.locale AS locale
# FROM joinboost_tmp_7,holidays
# WHERE joinboost_tmp_7.date IS NOT DISTINCT FROM holidays.date
# GROUP BY holidays.locale
# )
# WINDOW joinboost_window AS (ORDER BY locale)
# )
# ORDER BY criteria DESC
# LIMIT 1
#
# 0.002456188201904297
# [(1, 39051062757.20991, 2177649.1994403386, 724)]
# SELECT locale_name AS locale_name, CASE WHEN 4626 > c THEN ((s/c)*s + (13439060.470843477-s)/(4626-c)*(13439060.470843477-s)) ELSE 0 END AS criteria, s AS s, c AS c
# FROM (SELECT SUM(s) OVER joinboost_window  AS s, SUM(c) OVER joinboost_window  AS c, locale_name AS locale_name
# FROM (SELECT SUM(s) AS s, SUM(c) AS c, holidays.locale_name AS locale_name
# FROM joinboost_tmp_7,holidays
# WHERE joinboost_tmp_7.date IS NOT DISTINCT FROM holidays.date
# GROUP BY holidays.locale_name
# )
# WINDOW joinboost_window AS (ORDER BY locale_name)
# )
# ORDER BY criteria DESC
# LIMIT 1
#
# 0.0024080276489257812
# [(21, 39130794479.57075, 13346870.149266036, 4608)]
# SELECT transferred AS transferred, CASE WHEN 4626 > c THEN ((s/c)*s + (13439060.470843477-s)/(4626-c)*(13439060.470843477-s)) ELSE 0 END AS criteria, s AS s, c AS c
# FROM (SELECT SUM(s) OVER joinboost_window  AS s, SUM(c) OVER joinboost_window  AS c, transferred AS transferred
# FROM (SELECT SUM(s) AS s, SUM(c) AS c, holidays.transferred AS transferred
# FROM joinboost_tmp_7,holidays
# WHERE joinboost_tmp_7.date IS NOT DISTINCT FROM holidays.date
# GROUP BY holidays.transferred
# )
# WINDOW joinboost_window AS (ORDER BY transferred)
# )
# ORDER BY criteria DESC
# LIMIT 1
#
# 0.0028934478759765625
# [(1, 39285598443.42965, 13237016.367131032, 4589)]
# SELECT f2 AS f2, CASE WHEN 4626 > c THEN ((s/c)*s + (13439060.470843477-s)/(4626-c)*(13439060.470843477-s)) ELSE 0 END AS criteria, s AS s, c AS c
# FROM (SELECT SUM(s) OVER joinboost_window  AS s, SUM(c) OVER joinboost_window  AS c, f2 AS f2
# FROM (SELECT SUM(s) AS s, SUM(c) AS c, holidays.f2 AS f2
# FROM joinboost_tmp_7,holidays
# WHERE joinboost_tmp_7.date IS NOT DISTINCT FROM holidays.date
# GROUP BY holidays.f2
# )
# WINDOW joinboost_window AS (ORDER BY f2)
# )
# ORDER BY criteria DESC
# LIMIT 1
#
# 0.015133380889892578
# [(128, 39191041716.181816, 1529153.2840263755, 624)]
# SELECT dcoilwtico AS dcoilwtico, CASE WHEN 4626 > c THEN ((s/c)*s + (13439060.470843477-s)/(4626-c)*(13439060.470843477-s)) ELSE 0 END AS criteria, s AS s, c AS c
# FROM (SELECT SUM(s) OVER joinboost_window  AS s, SUM(c) OVER joinboost_window  AS c, dcoilwtico AS dcoilwtico
# FROM (SELECT SUM(s) AS s, SUM(c) AS c, oil.dcoilwtico AS dcoilwtico
# FROM joinboost_tmp_8,oil
# WHERE joinboost_tmp_8.date IS NOT DISTINCT FROM oil.date
# GROUP BY oil.dcoilwtico
# )
# WINDOW joinboost_window AS (ORDER BY dcoilwtico)
# )
# ORDER BY criteria DESC
# LIMIT 1
#
# 0.004368305206298828
# [(8, 39092452528.60061, 12743530.081060432, 4347)]
# SELECT f3 AS f3, CASE WHEN 4626 > c THEN ((s/c)*s + (13439060.470843477-s)/(4626-c)*(13439060.470843477-s)) ELSE 0 END AS criteria, s AS s, c AS c
# FROM (SELECT SUM(s) OVER joinboost_window  AS s, SUM(c) OVER joinboost_window  AS c, f3 AS f3
# FROM (SELECT SUM(s) AS s, SUM(c) AS c, oil.f3 AS f3
# FROM joinboost_tmp_8,oil
# WHERE joinboost_tmp_8.date IS NOT DISTINCT FROM oil.date
# GROUP BY oil.f3
# )
# WINDOW joinboost_window AS (ORDER BY f3)
# )
# ORDER BY criteria DESC
# LIMIT 1
#
# 0.005102872848510742
# [(463, 69046856139.90582, 12754131.196806498, 2363)]
# SELECT transactions AS transactions, CASE WHEN 4626 > c THEN ((s/c)*s + (13439060.470843477-s)/(4626-c)*(13439060.470843477-s)) ELSE 0 END AS criteria, s AS s, c AS c
# FROM (SELECT SUM(s) OVER joinboost_window  AS s, SUM(c) OVER joinboost_window  AS c, transactions AS transactions
# FROM (SELECT SUM(s) AS s, SUM(c) AS c, transactions.transactions AS transactions
# FROM joinboost_tmp_6,joinboost_tmp_2,transactions
# WHERE joinboost_tmp_6.store_nbr IS NOT DISTINCT FROM transactions.store_nbr AND joinboost_tmp_2.tid IS NOT DISTINCT FROM transactions.tid
# GROUP BY transactions.transactions
# )
# WINDOW joinboost_window AS (ORDER BY transactions)
# )
# ORDER BY criteria DESC
# LIMIT 1
#
# 0.0067446231842041016
# [(3, 40372232095.24341, 10079836.74662843, 3066)]
# SELECT f5 AS f5, CASE WHEN 4626 > c THEN ((s/c)*s + (13439060.470843477-s)/(4626-c)*(13439060.470843477-s)) ELSE 0 END AS criteria, s AS s, c AS c
# FROM (SELECT SUM(s) OVER joinboost_window  AS s, SUM(c) OVER joinboost_window  AS c, f5 AS f5
# FROM (SELECT SUM(s) AS s, SUM(c) AS c, transactions.f5 AS f5
# FROM joinboost_tmp_6,joinboost_tmp_2,transactions
# WHERE joinboost_tmp_6.store_nbr IS NOT DISTINCT FROM transactions.store_nbr AND joinboost_tmp_2.tid IS NOT DISTINCT FROM transactions.tid
# GROUP BY transactions.f5
# )
# WINDOW joinboost_window AS (ORDER BY f5)
# )
# ORDER BY criteria DESC
# LIMIT 1
#
# 0.011806011199951172
# [(557, 70031955322.50102, 1424411.6112285734, 2541)]
# SELECT city AS city, CASE WHEN 4626 > c THEN ((s/c)*s + (13439060.470843477-s)/(4626-c)*(13439060.470843477-s)) ELSE 0 END AS criteria, s AS s, c AS c
# FROM (SELECT SUM(s) OVER joinboost_window  AS s, SUM(c) OVER joinboost_window  AS c, city AS city
# FROM (SELECT SUM(s) AS s, SUM(c) AS c, stores.city AS city
# FROM joinboost_tmp_3,stores
# WHERE stores.f4 <= 496 AND joinboost_tmp_3.store_nbr IS NOT DISTINCT FROM stores.store_nbr
# GROUP BY stores.city
# )
# WINDOW joinboost_window AS (ORDER BY city)
# )
# ORDER BY criteria DESC
# LIMIT 1
#
# 0.0025336742401123047
# [(0, 40090119276.71778, 214708.23139363606, 243)]
# SELECT state AS state, CASE WHEN 4626 > c THEN ((s/c)*s + (13439060.470843477-s)/(4626-c)*(13439060.470843477-s)) ELSE 0 END AS criteria, s AS s, c AS c
# FROM (SELECT SUM(s) OVER joinboost_window  AS s, SUM(c) OVER joinboost_window  AS c, state AS state
# FROM (SELECT SUM(s) AS s, SUM(c) AS c, stores.state AS state
# FROM joinboost_tmp_3,stores
# WHERE stores.f4 <= 496 AND joinboost_tmp_3.store_nbr IS NOT DISTINCT FROM stores.store_nbr
# GROUP BY stores.state
# )
# WINDOW joinboost_window AS (ORDER BY state)
# )
# ORDER BY criteria DESC
# LIMIT 1
#
# 0.004217624664306641
# [(14, 40090119276.7178, 13224352.239449844, 4383)]
# SELECT stype AS stype, CASE WHEN 4626 > c THEN ((s/c)*s + (13439060.470843477-s)/(4626-c)*(13439060.470843477-s)) ELSE 0 END AS criteria, s AS s, c AS c
# FROM (SELECT SUM(s) OVER joinboost_window  AS s, SUM(c) OVER joinboost_window  AS c, stype AS stype
# FROM (SELECT SUM(s) AS s, SUM(c) AS c, stores.stype AS stype
# FROM joinboost_tmp_3,stores
# WHERE stores.f4 <= 496 AND joinboost_tmp_3.store_nbr IS NOT DISTINCT FROM stores.store_nbr
# GROUP BY stores.stype
# )
# WINDOW joinboost_window AS (ORDER BY stype)
# )
# ORDER BY criteria DESC
# LIMIT 1
#
# 0.0023996829986572266
# [(3, 39802556391.39811, 12706998.25550817, 4485)]
# SELECT cluster AS cluster, CASE WHEN 4626 > c THEN ((s/c)*s + (13439060.470843477-s)/(4626-c)*(13439060.470843477-s)) ELSE 0 END AS criteria, s AS s, c AS c
# FROM (SELECT SUM(s) OVER joinboost_window  AS s, SUM(c) OVER joinboost_window  AS c, cluster AS cluster
# FROM (SELECT SUM(s) AS s, SUM(c) AS c, stores.cluster AS cluster
# FROM joinboost_tmp_3,stores
# WHERE stores.f4 <= 496 AND joinboost_tmp_3.store_nbr IS NOT DISTINCT FROM stores.store_nbr
# GROUP BY stores.cluster
# )
# WINDOW joinboost_window AS (ORDER BY cluster)
# )
# ORDER BY criteria DESC
# LIMIT 1
#
# 0.002398967742919922
# [(7, 40022345598.693596, 5622806.178675278, 2302)]
# SELECT f4 AS f4, CASE WHEN 4626 > c THEN ((s/c)*s + (13439060.470843477-s)/(4626-c)*(13439060.470843477-s)) ELSE 0 END AS criteria, s AS s, c AS c
# FROM (SELECT SUM(s) OVER joinboost_window  AS s, SUM(c) OVER joinboost_window  AS c, f4 AS f4
# FROM (SELECT SUM(s) AS s, SUM(c) AS c, stores.f4 AS f4
# FROM joinboost_tmp_3,stores
# WHERE stores.f4 <= 496 AND joinboost_tmp_3.store_nbr IS NOT DISTINCT FROM stores.store_nbr
# GROUP BY stores.f4
# )
# WINDOW joinboost_window AS (ORDER BY f4)
# )
# ORDER BY criteria DESC
# LIMIT 1
#
# 0.0024018287658691406
# [(166, 46751579466.82721, 8366429.573822366, 1871)]
# SELECT family AS family, CASE WHEN 4626 > c THEN ((s/c)*s + (13439060.470843477-s)/(4626-c)*(13439060.470843477-s)) ELSE 0 END AS criteria, s AS s, c AS c
# FROM (SELECT SUM(s) OVER joinboost_window  AS s, SUM(c) OVER joinboost_window  AS c, family AS family
# FROM (SELECT SUM(s) AS s, SUM(c) AS c, items.family AS family
# FROM joinboost_tmp_10,items
# WHERE joinboost_tmp_10.item_nbr IS NOT DISTINCT FROM items.item_nbr
# GROUP BY items.family
# )
# WINDOW joinboost_window AS (ORDER BY family)
# )
# ORDER BY criteria DESC
# LIMIT 1
#
# 0.0026650428771972656
# [(8, 39107657554.25464, 5098742.650681831, 1848)]
# SELECT class AS class, CASE WHEN 4626 > c THEN ((s/c)*s + (13439060.470843477-s)/(4626-c)*(13439060.470843477-s)) ELSE 0 END AS criteria, s AS s, c AS c
# FROM (SELECT SUM(s) OVER joinboost_window  AS s, SUM(c) OVER joinboost_window  AS c, class AS class
# FROM (SELECT SUM(s) AS s, SUM(c) AS c, items.class AS class
# FROM joinboost_tmp_10,items
# WHERE joinboost_tmp_10.item_nbr IS NOT DISTINCT FROM items.item_nbr
# GROUP BY items.class
# )
# WINDOW joinboost_window AS (ORDER BY class)
# )
# ORDER BY criteria DESC
# LIMIT 1
#
# 0.0031392574310302734
# [(22, 39166810693.34863, 2385491.118097749, 726)]
# SELECT perishable AS perishable, CASE WHEN 4626 > c THEN ((s/c)*s + (13439060.470843477-s)/(4626-c)*(13439060.470843477-s)) ELSE 0 END AS criteria, s AS s, c AS c
# FROM (SELECT SUM(s) OVER joinboost_window  AS s, SUM(c) OVER joinboost_window  AS c, perishable AS perishable
# FROM (SELECT SUM(s) AS s, SUM(c) AS c, items.perishable AS perishable
# FROM joinboost_tmp_10,items
# WHERE joinboost_tmp_10.item_nbr IS NOT DISTINCT FROM items.item_nbr
# GROUP BY items.perishable
# )
# WINDOW joinboost_window AS (ORDER BY perishable)
# )
# ORDER BY criteria DESC
# LIMIT 1
#
# 0.0025680065155029297
# [(0, 39042371288.60939, 10014301.782713104, 3441)]
# SELECT f1 AS f1, CASE WHEN 4626 > c THEN ((s/c)*s + (13439060.470843477-s)/(4626-c)*(13439060.470843477-s)) ELSE 0 END AS criteria, s AS s, c AS c
# FROM (SELECT SUM(s) OVER joinboost_window  AS s, SUM(c) OVER joinboost_window  AS c, f1 AS f1
# FROM (SELECT SUM(s) AS s, SUM(c) AS c, items.f1 AS f1
# FROM joinboost_tmp_10,items
# WHERE joinboost_tmp_10.item_nbr IS NOT DISTINCT FROM items.item_nbr
# GROUP BY items.f1
# )
# WINDOW joinboost_window AS (ORDER BY f1)
# )
# ORDER BY criteria DESC
# LIMIT 1
#
# 0.0047914981842041016
# [(592, 39449078818.12746, 6916619.378190668, 2615)]
# SELECT htype AS htype, CASE WHEN 5374 > c THEN ((s/c)*s + (-13439060.470843477-s)/(5374-c)*(-13439060.470843477-s)) ELSE 0 END AS criteria, s AS s, c AS c
# FROM (SELECT SUM(s) OVER joinboost_window  AS s, SUM(c) OVER joinboost_window  AS c, htype AS htype
# FROM (SELECT SUM(s) AS s, SUM(c) AS c, holidays.htype AS htype
# FROM joinboost_tmp_12,holidays
# WHERE joinboost_tmp_12.date IS NOT DISTINCT FROM holidays.date
# GROUP BY holidays.htype
# )
# WINDOW joinboost_window AS (ORDER BY htype)
# )
# ORDER BY criteria DESC
# LIMIT 1
#
# 0.002440929412841797
# [(1, 33665141977.321484, -228926.27910104088, 125)]
# SELECT locale AS locale, CASE WHEN 5374 > c THEN ((s/c)*s + (-13439060.470843477-s)/(5374-c)*(-13439060.470843477-s)) ELSE 0 END AS criteria, s AS s, c AS c
# FROM (SELECT SUM(s) OVER joinboost_window  AS s, SUM(c) OVER joinboost_window  AS c, locale AS locale
# FROM (SELECT SUM(s) AS s, SUM(c) AS c, holidays.locale AS locale
# FROM joinboost_tmp_12,holidays
# WHERE joinboost_tmp_12.date IS NOT DISTINCT FROM holidays.date
# GROUP BY holidays.locale
# )
# WINDOW joinboost_window AS (ORDER BY locale)
# )
# ORDER BY criteria DESC
# LIMIT 1
#
# 0.0027589797973632812
# [(2, 33669689158.68724, -13363507.189396134, 5321)]
# SELECT locale_name AS locale_name, CASE WHEN 5374 > c THEN ((s/c)*s + (-13439060.470843477-s)/(5374-c)*(-13439060.470843477-s)) ELSE 0 END AS criteria, s AS s, c AS c
# FROM (SELECT SUM(s) OVER joinboost_window  AS s, SUM(c) OVER joinboost_window  AS c, locale_name AS locale_name
# FROM (SELECT SUM(s) AS s, SUM(c) AS c, holidays.locale_name AS locale_name
# FROM joinboost_tmp_12,holidays
# WHERE joinboost_tmp_12.date IS NOT DISTINCT FROM holidays.date
# GROUP BY holidays.locale_name
# )
# WINDOW joinboost_window AS (ORDER BY locale_name)
# )
# ORDER BY criteria DESC
# LIMIT 1
#
# 0.0067195892333984375
# [(0, 33668292273.634895, -16945.370618370463, 21)]
# SELECT transferred AS transferred, CASE WHEN 5374 > c THEN ((s/c)*s + (-13439060.470843477-s)/(5374-c)*(-13439060.470843477-s)) ELSE 0 END AS criteria, s AS s, c AS c
# FROM (SELECT SUM(s) OVER joinboost_window  AS s, SUM(c) OVER joinboost_window  AS c, transferred AS transferred
# FROM (SELECT SUM(s) AS s, SUM(c) AS c, holidays.transferred AS transferred
# FROM joinboost_tmp_12,holidays
# WHERE joinboost_tmp_12.date IS NOT DISTINCT FROM holidays.date
# GROUP BY holidays.transferred
# )
# WINDOW joinboost_window AS (ORDER BY transferred)
# )
# ORDER BY criteria DESC
# LIMIT 1
#
# 0.004789113998413086
# [(1, 33651900658.139122, -13407818.471659577, 5348)]
# SELECT f2 AS f2, CASE WHEN 5374 > c THEN ((s/c)*s + (-13439060.470843477-s)/(5374-c)*(-13439060.470843477-s)) ELSE 0 END AS criteria, s AS s, c AS c
# FROM (SELECT SUM(s) OVER joinboost_window  AS s, SUM(c) OVER joinboost_window  AS c, f2 AS f2
# FROM (SELECT SUM(s) AS s, SUM(c) AS c, holidays.f2 AS f2
# FROM joinboost_tmp_12,holidays
# WHERE joinboost_tmp_12.date IS NOT DISTINCT FROM holidays.date
# GROUP BY holidays.f2
# )
# WINDOW joinboost_window AS (ORDER BY f2)
# )
# ORDER BY criteria DESC
# LIMIT 1
#
# 0.0050201416015625
# [(790, 33711088410.16908, -10601327.95692442, 4113)]
# SELECT dcoilwtico AS dcoilwtico, CASE WHEN 5374 > c THEN ((s/c)*s + (-13439060.470843477-s)/(5374-c)*(-13439060.470843477-s)) ELSE 0 END AS criteria, s AS s, c AS c
# FROM (SELECT SUM(s) OVER joinboost_window  AS s, SUM(c) OVER joinboost_window  AS c, dcoilwtico AS dcoilwtico
# FROM (SELECT SUM(s) AS s, SUM(c) AS c, oil.dcoilwtico AS dcoilwtico
# FROM joinboost_tmp_13,oil
# WHERE joinboost_tmp_13.date IS NOT DISTINCT FROM oil.date
# GROUP BY oil.dcoilwtico
# )
# WINDOW joinboost_window AS (ORDER BY dcoilwtico)
# )
# ORDER BY criteria DESC
# LIMIT 1
#
# 0.002347707748413086
# [(4, 33681730837.204124, -8628564.661899794, 3328)]
# SELECT f3 AS f3, CASE WHEN 5374 > c THEN ((s/c)*s + (-13439060.470843477-s)/(5374-c)*(-13439060.470843477-s)) ELSE 0 END AS criteria, s AS s, c AS c
# FROM (SELECT SUM(s) OVER joinboost_window  AS s, SUM(c) OVER joinboost_window  AS c, f3 AS f3
# FROM (SELECT SUM(s) AS s, SUM(c) AS c, oil.f3 AS f3
# FROM joinboost_tmp_13,oil
# WHERE joinboost_tmp_13.date IS NOT DISTINCT FROM oil.date
# GROUP BY oil.f3
# )
# WINDOW joinboost_window AS (ORDER BY f3)
# )
# ORDER BY criteria DESC
# LIMIT 1
#
# 0.003605365753173828
# [(512, 67132246719.156204, -438939.64789983863, 2854)]
# SELECT transactions AS transactions, CASE WHEN 5374 > c THEN ((s/c)*s + (-13439060.470843477-s)/(5374-c)*(-13439060.470843477-s)) ELSE 0 END AS criteria, s AS s, c AS c
# FROM (SELECT SUM(s) OVER joinboost_window  AS s, SUM(c) OVER joinboost_window  AS c, transactions AS transactions
# FROM (SELECT SUM(s) AS s, SUM(c) AS c, transactions.transactions AS transactions
# FROM joinboost_tmp_11,joinboost_tmp_2,transactions
# WHERE joinboost_tmp_11.store_nbr IS NOT DISTINCT FROM transactions.store_nbr AND joinboost_tmp_2.tid IS NOT DISTINCT FROM transactions.tid
# GROUP BY transactions.transactions
# )
# WINDOW joinboost_window AS (ORDER BY transactions)
# )
# ORDER BY criteria DESC
# LIMIT 1
#
# 0.005711078643798828
# [(4, 33971617952.9641, -12633233.038579632, 4892)]
# SELECT f5 AS f5, CASE WHEN 5374 > c THEN ((s/c)*s + (-13439060.470843477-s)/(5374-c)*(-13439060.470843477-s)) ELSE 0 END AS criteria, s AS s, c AS c
# FROM (SELECT SUM(s) OVER joinboost_window  AS s, SUM(c) OVER joinboost_window  AS c, f5 AS f5
# FROM (SELECT SUM(s) AS s, SUM(c) AS c, transactions.f5 AS f5
# FROM joinboost_tmp_11,joinboost_tmp_2,transactions
# WHERE joinboost_tmp_11.store_nbr IS NOT DISTINCT FROM transactions.store_nbr AND joinboost_tmp_2.tid IS NOT DISTINCT FROM transactions.tid
# GROUP BY transactions.f5
# )
# WINDOW joinboost_window AS (ORDER BY f5)
# )
# ORDER BY criteria DESC
# LIMIT 1
#
# 0.006810426712036133
# [(553, 69826924252.09149, -14482903.751278551, 3024)]
# SELECT city AS city, CASE WHEN 5374 > c THEN ((s/c)*s + (-13439060.470843477-s)/(5374-c)*(-13439060.470843477-s)) ELSE 0 END AS criteria, s AS s, c AS c
# FROM (SELECT SUM(s) OVER joinboost_window  AS s, SUM(c) OVER joinboost_window  AS c, city AS city
# FROM (SELECT SUM(s) AS s, SUM(c) AS c, stores.city AS city
# FROM joinboost_tmp_3,stores
# WHERE stores.f4 > 496 AND joinboost_tmp_3.store_nbr IS NOT DISTINCT FROM stores.store_nbr
# GROUP BY stores.city
# )
# WINDOW joinboost_window AS (ORDER BY city)
# )
# ORDER BY criteria DESC
# LIMIT 1
#
# 0.002966642379760742
# [(19, 35031547014.48369, -13236741.814356789, 5018)]
# SELECT state AS state, CASE WHEN 5374 > c THEN ((s/c)*s + (-13439060.470843477-s)/(5374-c)*(-13439060.470843477-s)) ELSE 0 END AS criteria, s AS s, c AS c
# FROM (SELECT SUM(s) OVER joinboost_window  AS s, SUM(c) OVER joinboost_window  AS c, state AS state
# FROM (SELECT SUM(s) AS s, SUM(c) AS c, stores.state AS state
# FROM joinboost_tmp_3,stores
# WHERE stores.f4 > 496 AND joinboost_tmp_3.store_nbr IS NOT DISTINCT FROM stores.store_nbr
# GROUP BY stores.state
# )
# WINDOW joinboost_window AS (ORDER BY state)
# )
# ORDER BY criteria DESC
# LIMIT 1
#
# 0.0023107528686523438
# [(12, 34986371929.474396, -12916085.161419876, 4839)]
# SELECT stype AS stype, CASE WHEN 5374 > c THEN ((s/c)*s + (-13439060.470843477-s)/(5374-c)*(-13439060.470843477-s)) ELSE 0 END AS criteria, s AS s, c AS c
# FROM (SELECT SUM(s) OVER joinboost_window  AS s, SUM(c) OVER joinboost_window  AS c, stype AS stype
# FROM (SELECT SUM(s) AS s, SUM(c) AS c, stores.stype AS stype
# FROM joinboost_tmp_3,stores
# WHERE stores.f4 > 496 AND joinboost_tmp_3.store_nbr IS NOT DISTINCT FROM stores.store_nbr
# GROUP BY stores.stype
# )
# WINDOW joinboost_window AS (ORDER BY stype)
# )
# ORDER BY criteria DESC
# LIMIT 1
#
# 0.0022199153900146484
# [(2, 34193301162.523525, -8133837.968412863, 2899)]
# SELECT cluster AS cluster, CASE WHEN 5374 > c THEN ((s/c)*s + (-13439060.470843477-s)/(5374-c)*(-13439060.470843477-s)) ELSE 0 END AS criteria, s AS s, c AS c
# FROM (SELECT SUM(s) OVER joinboost_window  AS s, SUM(c) OVER joinboost_window  AS c, cluster AS cluster
# FROM (SELECT SUM(s) AS s, SUM(c) AS c, stores.cluster AS cluster
# FROM joinboost_tmp_3,stores
# WHERE stores.f4 > 496 AND joinboost_tmp_3.store_nbr IS NOT DISTINCT FROM stores.store_nbr
# GROUP BY stores.cluster
# )
# WINDOW joinboost_window AS (ORDER BY cluster)
# )
# ORDER BY criteria DESC
# LIMIT 1
#
# 0.002386808395385742
# [(3, 34545345801.53004, -2260533.654197694, 1287)]
# SELECT f4 AS f4, CASE WHEN 5374 > c THEN ((s/c)*s + (-13439060.470843477-s)/(5374-c)*(-13439060.470843477-s)) ELSE 0 END AS criteria, s AS s, c AS c
# FROM (SELECT SUM(s) OVER joinboost_window  AS s, SUM(c) OVER joinboost_window  AS c, f4 AS f4
# FROM (SELECT SUM(s) AS s, SUM(c) AS c, stores.f4 AS f4
# FROM joinboost_tmp_3,stores
# WHERE stores.f4 > 496 AND joinboost_tmp_3.store_nbr IS NOT DISTINCT FROM stores.store_nbr
# GROUP BY stores.f4
# )
# WINDOW joinboost_window AS (ORDER BY f4)
# )
# ORDER BY criteria DESC
# LIMIT 1
#
# 0.0022826194763183594
# [(760, 44278050136.37168, -2749688.8592429133, 2613)]
# SELECT family AS family, CASE WHEN 5374 > c THEN ((s/c)*s + (-13439060.470843477-s)/(5374-c)*(-13439060.470843477-s)) ELSE 0 END AS criteria, s AS s, c AS c
# FROM (SELECT SUM(s) OVER joinboost_window  AS s, SUM(c) OVER joinboost_window  AS c, family AS family
# FROM (SELECT SUM(s) AS s, SUM(c) AS c, items.family AS family
# FROM joinboost_tmp_15,items
# WHERE joinboost_tmp_15.item_nbr IS NOT DISTINCT FROM items.item_nbr
# GROUP BY items.family
# )
# WINDOW joinboost_window AS (ORDER BY family)
# )
# ORDER BY criteria DESC
# LIMIT 1
#
# 0.002718687057495117
# [(5, 33651789997.084396, -2318830.688136954, 1003)]
# SELECT class AS class, CASE WHEN 5374 > c THEN ((s/c)*s + (-13439060.470843477-s)/(5374-c)*(-13439060.470843477-s)) ELSE 0 END AS criteria, s AS s, c AS c
# FROM (SELECT SUM(s) OVER joinboost_window  AS s, SUM(c) OVER joinboost_window  AS c, class AS class
# FROM (SELECT SUM(s) AS s, SUM(c) AS c, items.class AS class
# FROM joinboost_tmp_15,items
# WHERE joinboost_tmp_15.item_nbr IS NOT DISTINCT FROM items.item_nbr
# GROUP BY items.class
# )
# WINDOW joinboost_window AS (ORDER BY class)
# )
# ORDER BY criteria DESC
# LIMIT 1
#
# 0.0038781166076660156
# [(186, 33654197916.576767, -10015168.967053896, 4090)]
# SELECT perishable AS perishable, CASE WHEN 5374 > c THEN ((s/c)*s + (-13439060.470843477-s)/(5374-c)*(-13439060.470843477-s)) ELSE 0 END AS criteria, s AS s, c AS c
# FROM (SELECT SUM(s) OVER joinboost_window  AS s, SUM(c) OVER joinboost_window  AS c, perishable AS perishable
# FROM (SELECT SUM(s) AS s, SUM(c) AS c, items.perishable AS perishable
# FROM joinboost_tmp_15,items
# WHERE joinboost_tmp_15.item_nbr IS NOT DISTINCT FROM items.item_nbr
# GROUP BY items.perishable
# )
# WINDOW joinboost_window AS (ORDER BY perishable)
# )
# ORDER BY criteria DESC
# LIMIT 1
#
# 0.0031168460845947266
# [(0, 33615954364.37241, -9985218.178083716, 3956)]
# SELECT f1 AS f1, CASE WHEN 5374 > c THEN ((s/c)*s + (-13439060.470843477-s)/(5374-c)*(-13439060.470843477-s)) ELSE 0 END AS criteria, s AS s, c AS c
# FROM (SELECT SUM(s) OVER joinboost_window  AS s, SUM(c) OVER joinboost_window  AS c, f1 AS f1
# FROM (SELECT SUM(s) AS s, SUM(c) AS c, items.f1 AS f1
# FROM joinboost_tmp_15,items
# WHERE joinboost_tmp_15.item_nbr IS NOT DISTINCT FROM items.item_nbr
# GROUP BY items.f1
# )
# WINDOW joinboost_window AS (ORDER BY f1)
# )
# ORDER BY criteria DESC
# LIMIT 1
#
# 0.0053691864013671875
# [(589, 34055363655.235023, -8528382.279861007, 3104)]
# CREATE OR REPLACE TABLE joinboost_tmp_16 AS SELECT SUM(s) AS s, SUM(c) AS c, transactions.store_nbr AS store_nbr
# FROM joinboost_tmp_11,joinboost_tmp_2,transactions
# WHERE transactions.f5 <= 553 AND joinboost_tmp_11.store_nbr IS NOT DISTINCT FROM transactions.store_nbr AND joinboost_tmp_2.tid IS NOT DISTINCT FROM transactions.tid
# GROUP BY transactions.store_nbr
#
# 0.0053560733795166016
# [(29,)]
# CREATE OR REPLACE TABLE joinboost_tmp_17 AS SELECT SUM(s) AS s, SUM(c) AS c, transactions.date AS date
# FROM joinboost_tmp_11,joinboost_tmp_2,transactions
# WHERE transactions.f5 <= 553 AND joinboost_tmp_11.store_nbr IS NOT DISTINCT FROM transactions.store_nbr AND joinboost_tmp_2.tid IS NOT DISTINCT FROM transactions.tid
# GROUP BY transactions.date
#
# 0.005786418914794922
# [(1348,)]
# CREATE OR REPLACE TABLE joinboost_tmp_18 AS SELECT SUM(s) AS s, SUM(c) AS c, holidays.date AS date
# FROM joinboost_tmp_17,holidays
# WHERE joinboost_tmp_17.date IS NOT DISTINCT FROM holidays.date
# GROUP BY holidays.date
#
# 0.0021216869354248047
# [(1348,)]
# CREATE OR REPLACE TABLE joinboost_tmp_19 AS SELECT transactions.tid AS tid
# FROM joinboost_tmp_11,joinboost_tmp_2,transactions
# WHERE transactions.f5 <= 553 AND joinboost_tmp_11.store_nbr IS NOT DISTINCT FROM transactions.store_nbr AND joinboost_tmp_2.tid IS NOT DISTINCT FROM transactions.tid
# GROUP BY transactions.tid
#
# 0.004187345504760742
# [(2838,)]
# CREATE OR REPLACE TABLE joinboost_tmp_20 AS SELECT SUM(s) AS s, SUM(c) AS c, joinboost_tmp_0.item_nbr AS item_nbr
# FROM joinboost_tmp_19,joinboost_tmp_0
# WHERE joinboost_tmp_19.tid IS NOT DISTINCT FROM joinboost_tmp_0.tid
# GROUP BY joinboost_tmp_0.item_nbr
#
# 0.002439260482788086
# [(1874,)]
# CREATE OR REPLACE TABLE joinboost_tmp_21 AS SELECT SUM(s) AS s, SUM(c) AS c, transactions.store_nbr AS store_nbr
# FROM joinboost_tmp_11,joinboost_tmp_2,transactions
# ...
# GROUP BY transactions.tid
#
# 0.004914999008178711
# [(1179,)]
# CREATE OR REPLACE TABLE joinboost_tmp_55 AS SELECT SUM(s) AS s, SUM(c) AS c, joinboost_tmp_0.item_nbr AS item_nbr
# FROM joinboost_tmp_54,joinboost_tmp_0
# WHERE joinboost_tmp_54.tid IS NOT DISTINCT FROM joinboost_tmp_0.tid
# GROUP BY joinboost_tmp_0.item_nbr
#
# 0.0022649765014648438
# [(1012,)]
# CREATE OR REPLACE TABLE joinboost_tmp_56 AS SELECT oil.date AS date
# FROM joinboost_tmp_23,oil
# WHERE oil.f3 <= 450 AND joinboost_tmp_23.date IS NOT DISTINCT FROM oil.date
# GROUP BY oil.date
#
# 0.0013566017150878906
# [(578,)]
# CREATE OR REPLACE TABLE joinboost_tmp_57 AS SELECT holidays.date AS date
# FROM joinboost_tmp_22,joinboost_tmp_56,holidays
# WHERE joinboost_tmp_22.date IS NOT DISTINCT FROM holidays.date AND joinboost_tmp_56.date IS NOT DISTINCT FROM holidays.date
# GROUP BY holidays.date
#
# 0.0015358924865722656
# [(578,)]
# CREATE OR REPLACE TABLE joinboost_tmp_58 AS SELECT SUM(s) AS s, SUM(c) AS c, transactions.store_nbr AS store_nbr
# FROM joinboost_tmp_11,joinboost_tmp_57,joinboost_tmp_2,transactions
# WHERE transactions.f5 > 553 AND joinboost_tmp_11.store_nbr IS NOT DISTINCT FROM transactions.store_nbr AND joinboost_tmp_57.date IS NOT DISTINCT FROM transactions.date AND joinboost_tmp_2.tid IS NOT DISTINCT FROM transactions.tid
# GROUP BY transactions.store_nbr
#
# 0.004888772964477539
# [(29,)]
# CREATE OR REPLACE TABLE joinboost_tmp_59 AS SELECT transactions.tid AS tid
# FROM joinboost_tmp_11,joinboost_tmp_57,joinboost_tmp_2,transactions
# WHERE transactions.f5 > 553 AND joinboost_tmp_11.store_nbr IS NOT DISTINCT FROM transactions.store_nbr AND joinboost_tmp_57.date IS NOT DISTINCT FROM transactions.date AND joinboost_tmp_2.tid IS NOT DISTINCT FROM transactions.tid
# GROUP BY transactions.tid
#
# 0.0055429935455322266
# [(1050,)]
# CREATE OR REPLACE TABLE joinboost_tmp_60 AS SELECT SUM(s) AS s, SUM(c) AS c, joinboost_tmp_0.item_nbr AS item_nbr
# FROM joinboost_tmp_59,joinboost_tmp_0
# WHERE joinboost_tmp_59.tid IS NOT DISTINCT FROM joinboost_tmp_0.tid
# GROUP BY joinboost_tmp_0.item_nbr
#
# 0.0023157596588134766
# [(925,)]
# CREATE OR REPLACE TABLE joinboost_tmp_61 AS SELECT oil.date AS date
# FROM joinboost_tmp_23,oil
# WHERE oil.f3 > 450 AND joinboost_tmp_23.date IS NOT DISTINCT FROM oil.date
# GROUP BY oil.date
#
# 0.001645803451538086
# [(642,)]
# CREATE OR REPLACE TABLE joinboost_tmp_62 AS SELECT holidays.date AS date
# FROM joinboost_tmp_22,joinboost_tmp_61,holidays
# WHERE joinboost_tmp_22.date IS NOT DISTINCT FROM holidays.date AND joinboost_tmp_61.date IS NOT DISTINCT FROM holidays.date
# GROUP BY holidays.date
#
# 0.0018167495727539062
# [(642,)]
# CREATE OR REPLACE TABLE joinboost_tmp_63 AS SELECT SUM(s) AS s, SUM(c) AS c, transactions.store_nbr AS store_nbr
# FROM joinboost_tmp_11,joinboost_tmp_62,joinboost_tmp_2,transactions
# WHERE transactions.f5 > 553 AND joinboost_tmp_11.store_nbr IS NOT DISTINCT FROM transactions.store_nbr AND joinboost_tmp_62.date IS NOT DISTINCT FROM transactions.date AND joinboost_tmp_2.tid IS NOT DISTINCT FROM transactions.tid
# GROUP BY transactions.store_nbr
#
# 0.005205392837524414
# [(29,)]
# CREATE OR REPLACE TABLE joinboost_tmp_64 AS SELECT transactions.tid AS tid
# FROM joinboost_tmp_11,joinboost_tmp_62,joinboost_tmp_2,transactions
# WHERE transactions.f5 > 553 AND joinboost_tmp_11.store_nbr IS NOT DISTINCT FROM transactions.store_nbr AND joinboost_tmp_62.date IS NOT DISTINCT FROM transactions.date AND joinboost_tmp_2.tid IS NOT DISTINCT FROM transactions.tid
# GROUP BY transactions.tid
#
# 0.004499912261962891
# [(1170,)]
# CREATE OR REPLACE TABLE joinboost_tmp_65 AS SELECT SUM(s) AS s, SUM(c) AS c, joinboost_tmp_0.item_nbr AS item_nbr
# FROM joinboost_tmp_64,joinboost_tmp_0
# WHERE joinboost_tmp_64.tid IS NOT DISTINCT FROM joinboost_tmp_0.tid
# GROUP BY joinboost_tmp_0.item_nbr
#
# 0.0025734901428222656
# [(1010,)]
# CREATE OR REPLACE TABLE joinboost_tmp_66 AS SELECT oil.date AS date
# FROM joinboost_tmp_33,oil
# WHERE oil.f3 <= 463 AND joinboost_tmp_33.date IS NOT DISTINCT FROM oil.date
# GROUP BY oil.date
#
# 0.0013561248779296875
# [(577,)]
# CREATE OR REPLACE TABLE joinboost_tmp_67 AS SELECT holidays.date AS date
# FROM joinboost_tmp_32,joinboost_tmp_66,holidays
# WHERE joinboost_tmp_32.date IS NOT DISTINCT FROM holidays.date AND joinboost_tmp_66.date IS NOT DISTINCT FROM holidays.date
# GROUP BY holidays.date
#
# 0.0015177726745605469
# [(577,)]
# CREATE OR REPLACE TABLE joinboost_tmp_68 AS SELECT SUM(s) AS s, SUM(c) AS c, transactions.store_nbr AS store_nbr
# FROM joinboost_tmp_6,joinboost_tmp_67,joinboost_tmp_2,transactions
# WHERE transactions.f5 > 557 AND joinboost_tmp_6.store_nbr IS NOT DISTINCT FROM transactions.store_nbr AND joinboost_tmp_67.date IS NOT DISTINCT FROM transactions.date AND joinboost_tmp_2.tid IS NOT DISTINCT FROM transactions.tid
# GROUP BY transactions.store_nbr
#
# 0.011327505111694336
# [(25,)]
# CREATE OR REPLACE TABLE joinboost_tmp_69 AS SELECT transactions.tid AS tid
# FROM joinboost_tmp_6,joinboost_tmp_67,joinboost_tmp_2,transactions
# WHERE transactions.f5 > 557 AND joinboost_tmp_6.store_nbr IS NOT DISTINCT FROM transactions.store_nbr AND joinboost_tmp_67.date IS NOT DISTINCT FROM transactions.date AND joinboost_tmp_2.tid IS NOT DISTINCT FROM transactions.tid
# GROUP BY transactions.tid
#
# 0.0072286128997802734
# [(1013,)]
# CREATE OR REPLACE TABLE joinboost_tmp_70 AS SELECT SUM(s) AS s, SUM(c) AS c, joinboost_tmp_0.item_nbr AS item_nbr
# FROM joinboost_tmp_69,joinboost_tmp_0
# WHERE joinboost_tmp_69.tid IS NOT DISTINCT FROM joinboost_tmp_0.tid
# GROUP BY joinboost_tmp_0.item_nbr
#
# 0.0020389556884765625
# [(900,)]
# CREATE OR REPLACE TABLE joinboost_tmp_71 AS SELECT oil.date AS date
# FROM joinboost_tmp_33,oil
# WHERE oil.f3 > 463 AND joinboost_tmp_33.date IS NOT DISTINCT FROM oil.date
# GROUP BY oil.date
#
# 0.002003192901611328
# [(573,)]
# CREATE OR REPLACE TABLE joinboost_tmp_72 AS SELECT holidays.date AS date
# FROM joinboost_tmp_32,joinboost_tmp_71,holidays
# WHERE joinboost_tmp_32.date IS NOT DISTINCT FROM holidays.date AND joinboost_tmp_71.date IS NOT DISTINCT FROM holidays.date
# GROUP BY holidays.date
#
# 0.0016541481018066406
# [(573,)]
# CREATE OR REPLACE TABLE joinboost_tmp_73 AS SELECT SUM(s) AS s, SUM(c) AS c, transactions.store_nbr AS store_nbr
# FROM joinboost_tmp_6,joinboost_tmp_72,joinboost_tmp_2,transactions
# WHERE transactions.f5 > 557 AND joinboost_tmp_6.store_nbr IS NOT DISTINCT FROM transactions.store_nbr AND joinboost_tmp_72.date IS NOT DISTINCT FROM transactions.date AND joinboost_tmp_2.tid IS NOT DISTINCT FROM transactions.tid
# GROUP BY transactions.store_nbr
#
# 0.005223274230957031
# [(25,)]
# CREATE OR REPLACE TABLE joinboost_tmp_74 AS SELECT transactions.tid AS tid
# FROM joinboost_tmp_6,joinboost_tmp_72,joinboost_tmp_2,transactions
# WHERE transactions.f5 > 557 AND joinboost_tmp_6.store_nbr IS NOT DISTINCT FROM transactions.store_nbr AND joinboost_tmp_72.date IS NOT DISTINCT FROM transactions.date AND joinboost_tmp_2.tid IS NOT DISTINCT FROM transactions.tid
# GROUP BY transactions.tid
#
# 0.004329681396484375
# [(928,)]
# CREATE OR REPLACE TABLE joinboost_tmp_75 AS SELECT SUM(s) AS s, SUM(c) AS c, joinboost_tmp_0.item_nbr AS item_nbr
# FROM joinboost_tmp_74,joinboost_tmp_0
# WHERE joinboost_tmp_74.tid IS NOT DISTINCT FROM joinboost_tmp_0.tid
# GROUP BY joinboost_tmp_0.item_nbr
#
# 0.002248525619506836
# [(856,)]
# DROP TABLE IF EXISTS joinboost_tmp_5;
#
# 0.0012602806091308594
# []
# DROP TABLE IF EXISTS joinboost_tmp_3;
#
# 0.0014035701751708984
# []
# DROP TABLE IF EXISTS joinboost_tmp_4;
#
# 0.0005669593811035156
# []
# DROP TABLE IF EXISTS joinboost_tmp_1;
#
# 0.001617431640625
# []
# DROP TABLE IF EXISTS joinboost_tmp_2;
#
# 0.0016314983367919922
# []
# DROP TABLE IF EXISTS joinboost_tmp_8;
#
# 0.0008983612060546875
# []
# DROP TABLE IF EXISTS joinboost_tmp_3;
#
# 0.0005331039428710938
# []
# DROP TABLE IF EXISTS joinboost_tmp_7;
#
# 0.0007045269012451172
# []
# DROP TABLE IF EXISTS joinboost_tmp_9;
#
# 0.0012412071228027344
# []
# DROP TABLE IF EXISTS joinboost_tmp_6;
#
# 0.0009441375732421875
# []
# DROP TABLE IF EXISTS joinboost_tmp_10;
#
# 0.0007674694061279297
# []
# DROP TABLE IF EXISTS joinboost_tmp_2;
#
# 0.0012712478637695312
# []
# DROP TABLE IF EXISTS joinboost_tmp_13;
#
# 0.0008747577667236328
# []
# DROP TABLE IF EXISTS joinboost_tmp_3;
#
# 0.0012052059173583984
# []
# DROP TABLE IF EXISTS joinboost_tmp_12;
#
# 0.001155853271484375
# []
# DROP TABLE IF EXISTS joinboost_tmp_14;
#
# 0.0012860298156738281
# []
# DROP TABLE IF EXISTS joinboost_tmp_11;
#
# 0.0008642673492431641
# []
# DROP TABLE IF EXISTS joinboost_tmp_15;
#
# 0.0009090900421142578
# []
# DROP TABLE IF EXISTS joinboost_tmp_2;
#
# 0.0007412433624267578
# []
# DROP TABLE IF EXISTS joinboost_tmp_18;
#
# 0.0013589859008789062
# []
# DROP TABLE IF EXISTS joinboost_tmp_16;
#
# 0.0009467601776123047
# []
# DROP TABLE IF EXISTS joinboost_tmp_17;
#
# 0.0008997917175292969
# []
# DROP TABLE IF EXISTS joinboost_tmp_19;
#
# 0.003530263900756836
# []
# DROP TABLE IF EXISTS joinboost_tmp_11;
#
# 0.00023031234741210938
# []
# DROP TABLE IF EXISTS joinboost_tmp_20;
#
# 0.0059659481048583984
# []
# DROP TABLE IF EXISTS joinboost_tmp_2;
#
# 0.00019931793212890625
# []
# DROP TABLE IF EXISTS joinboost_tmp_23;
#
# 0.00016689300537109375
# []
# DROP TABLE IF EXISTS joinboost_tmp_21;
#
# 0.004258394241333008
# []
# DROP TABLE IF EXISTS joinboost_tmp_22;
#
# 0.00023365020751953125
# []
# DROP TABLE IF EXISTS joinboost_tmp_24;
#
# 0.00014829635620117188
# []
# DROP TABLE IF EXISTS joinboost_tmp_11;
#
# 0.0001380443572998047
# []
# DROP TABLE IF EXISTS joinboost_tmp_25;
#
# 0.0001742839813232422
# []
# DROP TABLE IF EXISTS joinboost_tmp_2;
#
# 0.000240325927734375
# []
# DROP TABLE IF EXISTS joinboost_tmp_28;
#
# 0.00024509429931640625
# []
# DROP TABLE IF EXISTS joinboost_tmp_26;
#
# 0.00013375282287597656
# []
# DROP TABLE IF EXISTS joinboost_tmp_27;
#
# 0.00011730194091796875
# []
# DROP TABLE IF EXISTS joinboost_tmp_29;
#
# 0.00849461555480957
# []
# DROP TABLE IF EXISTS joinboost_tmp_6;
#
# 0.001031637191772461
# []
# DROP TABLE IF EXISTS joinboost_tmp_30;
#
# 0.0006473064422607422
# []
# DROP TABLE IF EXISTS joinboost_tmp_2;
#
# 0.0013709068298339844
# []
# DROP TABLE IF EXISTS joinboost_tmp_33;
#
# 0.0008952617645263672
# []
# DROP TABLE IF EXISTS joinboost_tmp_31;
#
# 0.00104522705078125
# []
# DROP TABLE IF EXISTS joinboost_tmp_32;
#
# 0.001069784164428711
# []
# DROP TABLE IF EXISTS joinboost_tmp_34;
#
# 0.001039743423461914
# []
# DROP TABLE IF EXISTS joinboost_tmp_6;
#
# 0.0010042190551757812
# []
# DROP TABLE IF EXISTS joinboost_tmp_35;
#
# 0.0009124279022216797
# []
# DROP TABLE IF EXISTS joinboost_tmp_2;
#
# 0.0008387565612792969
# []
# DROP TABLE IF EXISTS joinboost_tmp_37;
#
# 0.0009169578552246094
# []
# DROP TABLE IF EXISTS joinboost_tmp_18;
#
# 0.0011739730834960938
# []
# DROP TABLE IF EXISTS joinboost_tmp_36;
#
# 0.0008518695831298828
# []
# DROP TABLE IF EXISTS joinboost_tmp_38;
#
# 0.0008802413940429688
# []
# DROP TABLE IF EXISTS joinboost_tmp_17;
#
# 0.0008528232574462891
# []
# DROP TABLE IF EXISTS joinboost_tmp_39;
#
# 0.0008523464202880859
# []
# DROP TABLE IF EXISTS joinboost_tmp_11;
#
# 0.0014541149139404297
# []
# DROP TABLE IF EXISTS joinboost_tmp_40;
#
# 0.001094818115234375
# []
# DROP TABLE IF EXISTS joinboost_tmp_2;
#
# 0.0005521774291992188
# []
# DROP TABLE IF EXISTS joinboost_tmp_42;
#
# 0.001192331314086914
# []
# DROP TABLE IF EXISTS joinboost_tmp_18;
#
# 0.0015156269073486328
# []
# DROP TABLE IF EXISTS joinboost_tmp_41;
#
# 0.001009225845336914
# []
# DROP TABLE IF EXISTS joinboost_tmp_43;
#
# 0.0010073184967041016
# []
# DROP TABLE IF EXISTS joinboost_tmp_17;
#
# 0.0011858940124511719
# []
# DROP TABLE IF EXISTS joinboost_tmp_44;
#
# 0.0008800029754638672
# []
# DROP TABLE IF EXISTS joinboost_tmp_11;
#
# 0.0008420944213867188
# []
# DROP TABLE IF EXISTS joinboost_tmp_45;
#
# 0.0009436607360839844
# []
# DROP TABLE IF EXISTS joinboost_tmp_2;
#
# 0.0011746883392333984
# []
# DROP TABLE IF EXISTS joinboost_tmp_47;
#
# 0.0009224414825439453
# []
# DROP TABLE IF EXISTS joinboost_tmp_28;
#
# 0.0008711814880371094
# []
# DROP TABLE IF EXISTS joinboost_tmp_46;
#
# 0.0008900165557861328
# []
# DROP TABLE IF EXISTS joinboost_tmp_48;
#
# 0.0006163120269775391
# []
# DROP TABLE IF EXISTS joinboost_tmp_27;
#
# 0.0013022422790527344
# []
# DROP TABLE IF EXISTS joinboost_tmp_49;
#
# 0.0014796257019042969
# []
# DROP TABLE IF EXISTS joinboost_tmp_6;
#
# 0.0011997222900390625
# []
# DROP TABLE IF EXISTS joinboost_tmp_50;
#
# 0.0009951591491699219
# []
# DROP TABLE IF EXISTS joinboost_tmp_2;
#
# 0.001050710678100586
# []
# DROP TABLE IF EXISTS joinboost_tmp_52;
#
# 0.0010395050048828125
# []
# DROP TABLE IF EXISTS joinboost_tmp_28;
#
# 0.001399993896484375
# []
# DROP TABLE IF EXISTS joinboost_tmp_51;
#
# 0.0010809898376464844
# []
# DROP TABLE IF EXISTS joinboost_tmp_53;
#
# 0.0006661415100097656
# []
# DROP TABLE IF EXISTS joinboost_tmp_27;
#
# 0.0008213520050048828
# []
# DROP TABLE IF EXISTS joinboost_tmp_54;
#
# 0.0012142658233642578
# []
# DROP TABLE IF EXISTS joinboost_tmp_6;
#
# 0.0008356571197509766
# []
# DROP TABLE IF EXISTS joinboost_tmp_55;
#
# 0.0011911392211914062
# []
# DROP TABLE IF EXISTS joinboost_tmp_2;
#
# 0.0008451938629150391
# []
# DROP TABLE IF EXISTS joinboost_tmp_57;
#
# 0.0008549690246582031
# []
# DROP TABLE IF EXISTS joinboost_tmp_23;
#
# 0.0008537769317626953
# []
# DROP TABLE IF EXISTS joinboost_tmp_56;
#
# 0.00021910667419433594
# []
# DROP TABLE IF EXISTS joinboost_tmp_58;
#
# 0.00023102760314941406
# []
# DROP TABLE IF EXISTS joinboost_tmp_22;
#
# 0.00016450881958007812
# []
# DROP TABLE IF EXISTS joinboost_tmp_59;
#
# 0.00016236305236816406
# []
# DROP TABLE IF EXISTS joinboost_tmp_11;
#
# 0.00019478797912597656
# []
# DROP TABLE IF EXISTS joinboost_tmp_60;
#
# 0.0001766681671142578
# []
# DROP TABLE IF EXISTS joinboost_tmp_2;
#
# 0.00018453598022460938
# []
# DROP TABLE IF EXISTS joinboost_tmp_62;
#
# 0.00795745849609375
# []
# DROP TABLE IF EXISTS joinboost_tmp_23;
#
# 0.0011708736419677734
# []
# DROP TABLE IF EXISTS joinboost_tmp_61;
#
# 0.000888824462890625
# []
# DROP TABLE IF EXISTS joinboost_tmp_63;
#
# 0.0012891292572021484
# []
# DROP TABLE IF EXISTS joinboost_tmp_22;
#
# 0.0008256435394287109
# []
# DROP TABLE IF EXISTS joinboost_tmp_64;
#
# 0.0008461475372314453
# []
# DROP TABLE IF EXISTS joinboost_tmp_11;
#
# 0.0008108615875244141
# []
# DROP TABLE IF EXISTS joinboost_tmp_65;
#
# 0.0008842945098876953
# []
# DROP TABLE IF EXISTS joinboost_tmp_2;
#
# 0.0005581378936767578
# []
# DROP TABLE IF EXISTS joinboost_tmp_67;
#
# 0.0007054805755615234
# []
# DROP TABLE IF EXISTS joinboost_tmp_33;
#
# 0.0011374950408935547
# []
# DROP TABLE IF EXISTS joinboost_tmp_66;
#
# 0.0008530616760253906
# []
# DROP TABLE IF EXISTS joinboost_tmp_68;
#
# 0.00106048583984375
# []
# DROP TABLE IF EXISTS joinboost_tmp_32;
#
# 0.0012111663818359375
# []
# DROP TABLE IF EXISTS joinboost_tmp_69;
#
# 0.0008640289306640625
# []
# DROP TABLE IF EXISTS joinboost_tmp_6;
#
# 0.0008294582366943359
# []
# DROP TABLE IF EXISTS joinboost_tmp_70;
#
# 0.0008778572082519531
# []
# DROP TABLE IF EXISTS joinboost_tmp_2;
#
# 0.0011141300201416016
# []
# DROP TABLE IF EXISTS joinboost_tmp_72;
#
# 0.0009031295776367188
# []
# DROP TABLE IF EXISTS joinboost_tmp_33;
#
# 0.0008213520050048828
# []
# DROP TABLE IF EXISTS joinboost_tmp_71;
#
# 0.0007817745208740234
# []
# DROP TABLE IF EXISTS joinboost_tmp_73;
#
# 0.0006899833679199219
# []
# DROP TABLE IF EXISTS joinboost_tmp_32;
#
# 0.0011584758758544922
# []
# DROP TABLE IF EXISTS joinboost_tmp_74;
#
# 0.0011737346649169922
# []
# DROP TABLE IF EXISTS joinboost_tmp_6;
#
# 0.0014138221740722656
# []
# DROP TABLE IF EXISTS joinboost_tmp_75;
#
# 0.00020694732666015625
# []
# DROP TABLE IF EXISTS joinboost_tmp_2;
#
# 0.00014638900756835938
# []
# CREATE OR REPLACE TABLE joinboost_tmp_76 AS
# SELECT Y, -4842.635841853514+
# CASE
#  WHEN f4 > 496 AND f5 <= 553 AND f3 <= 475 THEN CAST(-2337.9228084177735 AS DOUBLE)
#  WHEN f4 > 496 AND f5 <= 553 AND f3 > 475 THEN CAST(-7160.971070371713 AS DOUBLE)
#  WHEN f4 <= 496 AND f5 <= 557 AND f3 > 475 THEN CAST(-2060.958149762831 AS DOUBLE)
#  WHEN f4 > 496 AND f5 > 553 AND f3 > 450 THEN CAST(-1953.1974409598786 AS DOUBLE)
#  WHEN f4 <= 496 AND f5 <= 557 AND f3 <= 475 THEN CAST(3039.5826387332845 AS DOUBLE)
#  WHEN f4 > 496 AND f5 > 553 AND f3 <= 450 THEN CAST(3077.0322614426113 AS DOUBLE)
#  WHEN f4 <= 496 AND f5 > 557 AND f3 <= 463 THEN CAST(8135.210187401269 AS DOUBLE)
#  WHEN f4 <= 496 AND f5 > 557 AND f3 > 463 THEN CAST(3187.9458062845265 AS DOUBLE)
# ELSE 0 END
# AS prediction FROM train
# 0.011655569076538086
# [(10000,)]
# joinboost_tmp_76
# SELECT *
# FROM (SELECT SQRT(AVG(POW(Y - prediction, 2))) AS RMSE
# FROM joinboost_tmp_76
# )
#
# 0.0012125968933105469
# [(2535.0608391585865,)]
# Training RMSE: 2535.0608391585865
